# %%
from fastai.text import *
import numpy as np
from sklearn.model_selection import train_test_split
import pickle
import sentencepiece as spm
import re
import pdb

# %%
import fastai, torch
fastai.__version__ , torch.__version__
# Out:
# ('1.0.40', '1.0.0')

# %%
torch.cuda.set_device(0)

# %%
path = Path('/home/gaurav/Downloads/HindiClassificationModel')

# %%
df = pd.read_csv(path/'Hindi_Classification_Data.csv')
df.head()
# Out:
#                                                 text  experience
# 0  छोटे शहर की कहानियों पर आधारित कुछ फिल्में सफल...           1
# 1  टॉयलेट- एक प्रेम कथा में निर्देशक श्री नारायण ...           0
# 2  \n\nअपराध और हिंसा पर फिल्म बनाना फिल्म निर्दे...           2
# 3  \n\nसैनिक, सरहद और युद्ध फिल्मकार जे.पी. दत्ता...           1
# 4  देओल्स के साथ सबसे बड़ी समस्या यह है कि वे समय...           0

# %%
print('Positive Examples', (df['experience'] == 2).sum())
print('Neutral Examples', (df['experience'] == 1).sum())
print('Negative Examples', (df['experience'] == 0).sum())
# Out:
# Positive Examples 335
# Neutral Examples 270
# Negative Examples 293

# %%
df['text'][0]
# Out:
# "छोटे शहर की कहानियों पर आधारित कुछ फिल्में सफल रही हैं और यही कारण है कि इन दिनों लगातार इसी तरह की फिल्में बन रही हैं। 'सुई धागा' इस कड़ी में ताजा फिल्म है जिसे शरत कटारिया ने बनाया है। वे इसके पहले 'दम लगा के हईशा' बना चुके हैं।\n\n\nफिल्म देखने के पहले अहम सवाल यह था कि वरुण धवन और अनुष्का शर्मा जैसे स्टार्स निम्न मध्यमवर्गीय किरदारों के साथ क्या न्याय कर पाएंगे? इन दोनों कलाकारों ने तो अपना काम बखूबी किया, लेकिन स्क्रीनप्ले इनका साथ नहीं निभा पाया।\n\nमौजी (वरुण धवन) अपने नाम के अनुरूप मौजी हैं। तमाम अभावों में भी उसके मुंह से 'सब बढ़िया' ही निकलता है। वह अपनी पत्नी ममता (अनुष्का शर्मा) और माता-पिता के साथ रहता है। एक दुकान से वह नौकरी इसलिए छोड़ देता है क्योंकि काम के साथ-साथ उसे कुत्ता या बंदर बनाकर सेठ मजे लेता है और यह बात ममता को पसंद नहीं आती।\n\nमौजी टेलरिंग का काम शुरू करता है। दुकान न होने पर सड़क किनारे मशीन लेकर बैठ जाता है। इस काम में उसके साथ ममता कदम मिला कर चलती है।\n\nयहां तक फिल्म बहुत ही बढ़िया तरीके से चलती है। इस गंभीर बात को भी हास्य के पुट के साथ निर्देशक औ
# ...

# %%
df.shape
# Out:
# (898, 2)

# %%
df[df['text'].isnull()].shape
# Out:
# (0, 2)

# %%
label_cols = list(range(1,df.shape[1]))

# %%
print(label_cols)
# Out:
# [1]

# %%
id_to_col = list(df.columns)

# %%
col_to_id = {}
for i, col in enumerate(id_to_col):
    col_to_id[col] = i

# %%
class HindiTokenizer(BaseTokenizer):
    def __init__(self, lang:str):
        self.lang = lang
        self.sp = spm.SentencePieceProcessor()
        self.sp.Load(str('/home/gaurav/Downloads/LanguageModel/hindi_lm.model'))
        
    def tokenizer(self, t:str) -> List[str]:
        return self.sp.EncodeAsPieces(t)

# %%
sp = spm.SentencePieceProcessor()
sp.Load('/home/gaurav/Downloads/LanguageModel/hindi_lm.model')
itos = [sp.IdToPiece(int(i)) for i in range(30000)]

# %%
itos
# Out:
# ['<unk>',
#  '<s>',
#  '</s>',
#  '▁के',
#  '।',
#  '▁में',
#  '▁है',
#  ',',
#  '▁',
#  '▁की',
#  '▁और',
#  '▁से',
#  '▁का',
#  '▁को',
#  '▁हैं',
#  '▁एक',
#  '▁पर',
#  '.',
#  '-',
#  '▁भी',
#  '▁ने',
#  '▁किया',
#  '▁·',
#  '▁यह',
#  '▁था',
#  '▁लिए',
#  '▁इस',
#  '▁गया',
#  'ों',
#  '▁कि',
#  'ी',
#  '▁जाता',
#  '▁जो',
#  '▁रूप',
#  '▁ही',
#  '▁q',
#  '▁�',
#  '▁कर',
#  '▁हो',
#  '▁करने',
#  '▁तथा',
#  '▁नहीं',
#  '▁द्वारा',
#  '▁या',
#  'X',
#  '▁थे',
#  '▁साथ',
#  '▁•',
#  'ा',
#  '▁भारत',
#  '▁होता',
#  '▁बाद',
#  '▁तक',
#  ':',
#  '▁"',
#  '▁दिया',
#  '▁अपने',
#  '▁थी',
#  '▁हुआ',
#  'न',
#  '▁कुछ',
#  '"',
#  '▁जिला',
#  '�',
#  '▁एवं',
#  '▁इसके',
#  '▁वे',
#  '▁वह',
#  '▁|',
#  "'",
#  '▁नाम',
#  '▁जा',
#  '▁राज्य',
#  '▁समय',
#  '▁होती',
#  '▁करते',
#  '▁हुए',
#  '▁तो',
#  '▁कई',
#  "▁'",
#  '▁अन्य',
#  '▁अधिक',
#  '▁क्षेत्र',
#  '▁कारण',
#  'े',
#  '▁सबसे',
#  '▁प्रकार',
#  '▁होने',
#  'क',
#  '▁सकता',
#  '▁स्थित',
#  'र',
#  '▁उनके',
#  '▁भारतीय',
#  '▁उन्होंने',
# ...

# %%
# 30,000 is the vocab size that we chose in sentencepiece
hindi_vocab = Vocab(itos)

# %%
tokenizer = Tokenizer(tok_func=HindiTokenizer, lang='hi')

# %%
tokenizer.special_cases
# Out:
# ['xxunk', 'xxpad', 'xxbos', 'xxfld', 'xxmaj', 'xxup', 'xxrep', 'xxwrep']

# %%
data_lm = TextDataBunch.from_csv(path=path, csv_name='Hindi_Classification_Data.csv', text_cols=[0], label_cols=label_cols, tokenizer=tokenizer, vocab=hindi_vocab)

# %%
data_lm.save()

# %%
bs=48

# %%
data_lm = TextLMDataBunch.load(path, 'tmp', bs=bs)

# %%
data_lm.show_batch()
# Out:
# <table>  <col width='5%'>  <col width='95%'>  <tr>
#     <th>idx</th>
#     <th>text</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>▁x x bo s ▁स्त्री ▁एक ▁हॉ र र - कॉम े डी ▁फिल्म ▁है ▁जिसमें ▁कॉमेडी ▁ज्यादा ▁है । ▁यहां ▁तक ▁कि ▁ड राव ने ▁दृश्यों ▁में ▁भी ▁आप ▁हंस ते ▁रहते ▁हैं । ▁चंद ेरी ▁नामक ▁एक ▁कस्बे ▁की ▁कहानी ▁है ▁जहां ▁पर ▁हर ▁वर्ष ▁पूजा ▁के ▁खास ▁चार ▁दिनों ▁में ▁भय ▁का ▁माहौल ▁छा ▁जाता ▁है । ▁कहा ▁जाता ▁है ▁कि ▁एक ▁स्त्री ▁आती ▁है ▁और ▁रात</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>▁प्रा . लि . ▁निर्माता ▁: ▁बंट ी ▁वाल िया , ▁जस प्रीत ▁सिंह ▁वाल िया ▁निर्देशक ▁: ▁राहुल ▁ढोलकिय ा ▁संगीत ▁: ▁मिथुन ▁कलाकार ▁: ▁संजय ▁दत्त , ▁बि पाश ा ▁बसु , ▁कुणाल ▁कपूर , ▁शेर ना ज ▁पटेल , ▁अनुपम ▁खेर , ▁यशपाल ▁शर्मा ▁* ▁ए - ▁सर्टिफिकेट ▁* ▁1 ▁घंटा ▁55 ▁मिनट ▁वर्षों ▁से ▁चली ▁आ ▁रही ▁कश्मीर ▁समस्या ▁अब ▁तक ▁हल ▁नहीं ▁हो ▁पाई ▁है</th>
#   </tr>
#   <tr>
#     <th>2</th>
# ...

# %%
learn = language_model_learner(data_lm, drop_mult=0.3)

# %%
# Loading the pretrained language model on hindi wikipedia
learn.load('/home/gaurav/Downloads/LanguageModel/HindiDataset/models/third_hi_lm', with_opt=True)
# Out:
# LanguageLearner(data=TextLMDataBunch;
#
# Train: LabelList
# y: LMLabel (718 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: /home/gaurav/Downloads/HindiClassificationModel
# x: LMTextList (718 items)
# ...

# %%
# Fine tuning the prtrained LM on current dataset

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.freeze()

# %%
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7))
# Out:
# Total time: 00:22 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>4.254851</th>
#     <th>4.127534</th>
#     <th>0.314061</th>
#   </tr>
# </table>

# %%
learn.save('fit_head', with_opt=True)

# %%
learn.load('fit_head', with_opt=True);

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, 1e-3, moms=(0.8,0.7))
# Out:
# Total time: 02:12 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>3.874349</th>
#     <th>4.001045</th>
#     <th>0.328435</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>3.709277</th>
#     <th>3.864129</th>
#     <th>0.346565</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>3.455430</th>
#     <th>3.796011</th>
#     <th>0.356373</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>3.283489</th>
#     <th>3.778183</th>
#     <th>0.359790</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>3.185065</th>
#     <th>3.784327</th>
#     <th>0.359983</th>
#   </tr>
# </table>

# %%
learn.save('fine_tuned', with_opt=True)

# %%
learn.load('fine_tuned', with_opt=True);

# %%
learn.predict('जिसके लिये उन्हें',n_words=10)
# Out:
# 'जिसके लिये उन्हें ▁प्राप्त ष ू ष ▁कहा . ▁100 . ▁बता ▁राजेंद्र'

# %%
learn.save_encoder('fine_tuned_enc')

# %%
data_clas = TextClasDataBunch.from_csv(path=path, csv_name='Hindi_Classification_Data.csv', tokenizer=tokenizer, vocab=hindi_vocab, text_cols=[0], label_cols=label_cols)

# %%
data_clas.show_batch()
# Out:
# <table>  <col width='90%'>  <col width='10%'>  <tr>
#     <th>text</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁फराह ▁खान ▁के ▁परिवार ▁के ▁सदस्यों ▁ <unk> फ राह ▁/ ▁साज िद ▁/ ▁शिर ी ष ) ▁का ▁नाम ▁पोस्टर ▁पर ▁देख ▁डर ▁लगता ▁है ▁क्योंकि ▁इनके ▁द्वारा ▁' जो कर ', ▁' हम श क ल्स ', ▁' ती स ▁मार ▁खां ', ▁' हि म्म त वाला ' ▁जैसी ▁फिल्में ▁बनाई ▁गई ▁हैं ▁जो ▁अधिकांश ▁लोगों ▁के ▁लिए ▁टॉ र्च र ▁से ▁कम</th>
#     <th>1</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁के री ▁पै कर ▁का ▁नाम ▁क्रिकेट ▁की ▁दुनिया ▁में ▁भले ▁ही ▁आदर ▁के ▁साथ ▁न ▁लिया ▁जाता ▁हो , ▁लेकिन ▁इस ▁शख्स ▁ने ▁1977 ▁में ▁क्रिकेट ▁में ▁छिपे ▁व्यापार ▁की ▁संभावनाओं ▁को ▁तलाश ▁लिया ▁था । ▁उन्होंने ▁विश्व ▁के ▁नाम ी ▁खिलाड़ियों ▁को ▁मुंह मा ंगा ▁धन ▁देकर ▁ अनुबंधित ▁किया ▁और ▁वर्ल्ड ▁सी रिज ▁क्रिकेट ▁के ▁तहत ▁उन्हें ▁खिला या ▁गया । ▁इसे ▁के</th>
#     <th>2</th>
#   </tr>
#   <tr>
# ...

# %%
data_clas.sanity_check()

# %%
learn = text_classifier_learner(data_clas, drop_mult=0.5)

# %%
learn.load_encoder('fine_tuned_enc')

# %%
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.loss_func.func
# Out:
# CrossEntropyLoss()

# %%
kappa = KappaScore()

# %%
learn.metrics = [kappa, accuracy]

# %%
learn.fit_one_cycle(1, 1e-1, moms=(0.8,0.7))
# Out:
# Total time: 00:09 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>kappa_score</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.088073</th>
#     <th>1.112743</th>
#     <th>0.049984</th>
#     <th>0.338889</th>
#   </tr>
# </table>

# %%
learn.save('first-full')

# %%
learn.load('first-full');

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(5, slice(1e-2/(2.6**4),1e-2), moms=(0.8,0.7))
# Out:
# Total time: 00:53 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>kappa_score</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.975932</th>
#     <th>1.021289</th>
#     <th>0.191653</th>
#     <th>0.450000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.916680</th>
#     <th>0.926262</th>
#     <th>0.348695</th>
#     <th>0.577778</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.851736</th>
#     <th>0.922581</th>
#     <th>0.299545</th>
#     <th>0.538889</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.761178</th>
#     <th>0.987342</th>
#     <th>0.262363</th>
#     <th>0.505556</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.684395</th>
#     <th>1.014774</th>
#     <th>0.241480</th>
#     <th>0.488889</th>
#   </tr>
# </table>

# %%
learn.save('second-full')

# %%
learn.unfreeze()
learn.fit_one_cycle(5, slice(1e-3/(2.6**4),1e-3), moms=(0.8,0.7))
# Out:
# Total time: 01:35 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>kappa_score</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.564114</th>
#     <th>1.042815</th>
#     <th>0.284180</th>
#     <th>0.516667</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.555397</th>
#     <th>0.915018</th>
#     <th>0.319994</th>
#     <th>0.550000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.544805</th>
#     <th>0.935388</th>
#     <th>0.301229</th>
#     <th>0.533333</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.530665</th>
#     <th>0.935523</th>
#     <th>0.301165</th>
#     <th>0.533333</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.505913</th>
#     <th>0.958316</th>
#     <th>0.308845</th>
#     <th>0.538889</th>
#   </tr>
# </table>

# %%
learn.save('final')

# %%
np.exp(3.58)
# Out:
# 35.87354084706276

# %%
from fastai.text import *
import numpy as np
from sklearn.model_selection import train_test_split
import pickle
import sentencepiece as spm
import re
import pdb

# %%
import fastai, torch
fastai.__version__ , torch.__version__
# Out:
# ('1.0.40', '1.0.0')

# %%
torch.cuda.set_device(0)

# %%
path = Path('/home/gaurav/Downloads/ClassificationModel')

# %%
df = pd.read_csv(path/'Punjabi_Binary_Classification.csv')
df.head()
# Out:
#                                                 text  ਭਾਰਤੀ ਰਾਜਨੀਤੀ
# 0   ਪੰਜਾਬ ਵਿੱਚ ਕਾਂਗਰਸ ਨੂੰ 'ਆਪ' ਨਾਲ ਗਠਜੋੜ ਦੀ ਲੋੜ ਨ...           True
# 1   ਕਨ੍ਹਈਆ ਦੇ ਮੁਸਲਮਾਨ ਬਣਨ ਬਾਰੇ ਵਾਇਰਲ ਵੀਡੀਓ ਦਾ ਸੱਚ...           True
# 2   ਮੋਦੀ ਨੇ ਗੁਰਦਾਸਪੁਰ ’ਚ ਕਿਹਾ, 'ਇੱਕ ਪਰਿਵਾਰ ਨੇ ’84...           True
# 3   'ਜਿੰਨ੍ਹਾਂ ਲੋਕਾਂ ਕੋਲ ਸਮਾਰਟ ਫੋਨ ਨਹੀਂ ਹਨ ਕੀ ਮੋਦੀ...           True
# 4   ਕੀ ਬਾਲੀਵੁੱਡ ਨੇ ਨਰਿੰਦਰ ਮੋਦੀ ਅੱਗੇ ਅਯੁੱਧਿਆ 'ਚ ਰਾ...           True

# %%
print('Positive Examples', df['ਭਾਰਤੀ ਰਾਜਨੀਤੀ'].sum())
print('Negative Examples', df.shape[0] -df['ਭਾਰਤੀ ਰਾਜਨੀਤੀ'].sum())
# Out:
# Positive Examples 114
# Negative Examples 670

# %%
df['text'][0]
# Out:
# ' ਪੰਜਾਬ ਵਿੱਚ ਕਾਂਗਰਸ ਨੂੰ \'ਆਪ\' ਨਾਲ ਗਠਜੋੜ ਦੀ ਲੋੜ ਨਹੀਂ - ਕੈਪਟਨ      7 ਜਨਵਰੀ 2019                                              ਈਮੇਲ                                                 ਸਾਂਝਾ ਕਰੋ                                                 ਈਮੇਲ  ਈਮੇਲ    ਲਿੰਕ ਨੂੰ ਕਾਪੀ ਕਰੋ  https://www.bbc.com/punjabi/india-46781799  ਸਾਂਝਾ ਕਰਨ ਬਾਰੇ ਹੋਰ ਪੜ੍ਹੋ   ਸਾਂਝਾ ਕਰਨ ਵਾਲੇ ਪੈਨਲ ਨੂੰ ਬੰਦ ਕਰੋ              Image copyright Pradeep Gaur/Mint via Getty Images  "ਸੂਬੇ ਵਿੱਚ ਆਮ ਆਦਮੀ ਪਾਰਟੀ ਦੀ ਕੋਈ ਹੋਂਦ ਨਹੀਂ ਹੈ ਇਸ ਲਈ ਉਸ ਨਾਲ ਸਮਝੌਤੇ ਦੀ ਕੋਈ ਲੋੜ ਨਹੀਂ ਹੈ। ਹਾਲਾਂਕਿ ਆਪ ਜਾਂ ਕਿਸੇ ਵੀ ਹੋਰ ਪਾਰਟੀ ਨਾਲ ਸਮਝੌਤੇ ਬਾਰੇ ਆਖ਼ਰੀ ਫੈਸਲਾ ਹਾਈ ਕਮਾਂਡ ਹੀ ਲਵੇਗੀ।"ਇਹ ਵਿਚਾਰ ਪੰਜਾਬ ਦੇ ਮੁੱਖ ਮੰਤਰੀ ਕੈਪਟਨ ਅਮਰਿੰਦਰ ਸਿੰਘ ਨੇ ਕਾਂਗਰਸ ਪ੍ਰਧਾਨ ਰਾਹੁਲ ਗਾਂਧੀ ਨਾਲ ਮੁਲਾਕਾਤ ਤੋਂ ਬਾਅਦ ਪੱਤਰਕਾਰਾਂ ਨਾਲ ਗੱਲਬਾਤ ਦੌਰਾਨ ਪ੍ਰਗਟ ਕੀਤੇ। ਉਨ੍ਹਾਂ ਕਿਹਾ ਕਿ ਰਾਹੁਲ ਗਾਂਧੀ ਨਾਲ ਹੋਈ ਮੀਟਿੰਗ ਵਿੱਚ ਆਪ ਨਾਲ ਗਠਜੋੜ ਬਾਰੇ ਚਰਚਾ ਨਹੀਂ ਹੋਈ ਹੈ।ਆਗਾਮੀ ਲੋਕ ਸਭਾ ਚੋਣਾਂ ਵਿੱਚ ਆਮ ਆਦਮੀ ਪਾਰਟੀ ਨਾਲ ਕਿਸੇ ਸਮਝੌਤੇ ਦੀ ਲੋੜ ਤੋਂ ਇਨਕਾਰ ਕੀਤਾ ਅਤੇ ਕਿਹਾ ਕਿ ਕਾਂਗਰਸ ਸੂਬੇ ਵਿੱਚ ਆਪਣੇ ਦਮ ’ਤੇ ਹੀ ਸਾਰੀਆਂ 13 ਸੀਟਾਂ ਜਿੱਤੇਗੀ।ਸੂਬੇ ਦੀਆਂ ਸਾਰੀਆਂ ਲੋਕ ਸਭਾ ਸੀਟਾਂ ’ਤੇ ਜਿੱਤ ਹਾਸਲ ਕਰਨ ਲਈ ਸਭ ਤੋਂ ਯੋਗ ਉਮੀਦਵਾਰਾਂ ਨੂੰ ਮੈਦਾਨ ਵਿੱਚ ਉਤਾਰਿਆ ਜਾਵੇਗਾ। ਹਾਲਾਂਕਿ ਉਮੀਦਵਾਰਾਂ ਦੀ ਚੋਣ ਬਾਰੇ ਕੋਈ ਚਰਚਾ ਨਹੀਂ ਹੋਈ ਹੈ।ਇਹ ਵੀ ਪੜ੍ਹੋ:ਇੱਕ ਦਹਾਕੇ ਤੋਂ ਕੋਮਾ \'ਚ ਪਈ ਔਰਤ ਕਿਵੇਂ ਬਣ ਗਈ ਮਾਂ?ਭਾਰਤ ਅਫਗਾਨਿਸਤਾਨ ਦੇ ਵਿਕਾਸ ਵਿੱਚ ਇੰਨਾ ਪੈਸਾ ਕਿਉਂ ਲਾ ਰਿਹਾ ਹੈ \'ਰਾਵਣ ਕੋਲ 24 ਤਰ੍ਹਾਂ ਦੇ ਜਹਾਜ਼ ਸਨ\'ਪੰਜਾਬ ਕੈਬਨਿਟ ਵਿੱਚ ਸੰਭਾਵੀ ਰੱਦੋਬਦਲ ਬਾਰੇ ਪੁੱਛੇ ਸਵਾਲ ਦੇ ਜਵਾਬ ਵਿੱਚ ਉਨ੍ਹਾਂ ਕਿਹਾ ਕਿ ਇਸ ਬਾਰੇ ਰਾਹੁਲ ਗਾਂਧੀ ਨਾਲ ਮੁਲਾਕਾਤ ਵਿੱਚ ਕੋਈ ਚਰਚਾ ਨਹੀਂ ਹੋਈ ਹੈ।ਕਰਤਾਪੁਰ ਲਾਂਘੇ ਤੇ ਸਿੱਧੂ ਦੀ ਪਾਕਿਸਤਾਨ ਫੇਰੀ ਬਾਰੇ ਸਪਸ਼ਟੀਕਰਨਕਰਤਾਪੁਰ ਲਾਂਘੇ ਦਾ ਕੰਮ ਪਾਕਿਸਤਾਨ ਵਿੱਚ ਸ਼ੁਰੂ ਹੋ ਚੁੱਕਿਆ ਹੈ ਜਦਕਿ ਭਾਰਤ ਵਾਲੇ ਪਾਸੇ ਹਾਲੇ ਕੋਈ ਕੰਮ ਸ਼ੁਰੂ ਨਹੀਂ ਹੋ ਸਕਿਆ। ਇਸ ਬਾਰੇ ਮੁੱਖ ਮੰਤਰੀ ਨੇ ਕਿਹਾ, "ਕਰਤਾਰਪੁਰ ਲਾਂਘੇ ਲਈ ਜ਼ਰੂਰੀ ਵਿਕਾਸ ਕਾਰਜਾਂ ਲਈ ਜ਼ਮੀਨ ਹਾਸਲ ਕਰਨ ਲਈ ਪੰਜਾਬ ਸਰਕਾਰ ਨੂੰ ਕੋਈ ਫੰਡ ਹਾਲੇ ਪ੍ਰਾਪਤ ਨਹੀਂ ਹੋਏ ਜਿਸ ਕਾਰਨ ਲਾਂਘੇ ਨਾਲ ਵਿਕਾਸ ਕਾਰਜ ਹਾਲੇ ਤੱਕ ਇਸ ਲਈ ਸ਼ੁਰੂ ਨਹੀਂ ਹੋ ਸਕੇ।"ਮੁੱਖ ਮੰਤਰੀ ਨੇ ਪੰਜਾਬ ਵਿੱਚ ਕਿਸਾਨਾਂ ਦੀ ਕਰਜ਼ ਮਾਫੀ ਬਾਰੇ ਪ੍ਰਧਾਨ ਮੰਤਰੀ ਦੇ ਇਲਜ਼ਾਮਾਂ ਨੂੰ ਸਿਰੇ ਤੋਂ ਖਾਰਿਜ ਕੀਤਾ।   Image copyright GURINDER BAJWA/bbc   ਫੋਟੋ ਕੈਪਸ਼ਨ                     ਡੇਰਾ ਬਾਬਾ ਨਾਨਕ ਤੋਂ ਪਾਕਿਸਤਾਨ ਵਿੱਚ ਕਰੀਬ 4 ਕਿਲੋਮੀਟਰ ਅੰਦਰ ਪੈਂਦਾ ਹੈ ਗੁਰਦੁਆਰਾ ਸ੍ਰੀ ਕਰਤਾਰਪੁਰ ਸਾਹਿਬ                  ਕਿਸਾਨਾਂ ਦੀ ਕਰਜ਼ ਮਾਫੀ ਅਤੇ ਮੋਦੀ ਦੇ ਇਲਜ਼ਾਮਉਨ੍ਹਾਂ ਦੀ ਸਰਕਾਰ ਨੇ 4,14,275 ਕਿਸਾਨਾਂ ਦਾ 3,417 ਕਰੋੜ ਦਾ ਕਰਜ਼ਾ ਸਿਰਫ ਇੱਕ ਸਾਲ ਵਿੱਚ ਮਾਫ ਕਰ ਦਿੱਤਾ। ਉਨ੍ਹਾਂ ਕਿਹਾ ਕਿ ਸਰਕਾਰ ਸੂਬੇ ਦੇ ਸਾਰੇ 10.25 ਲੱਖ ਦਰਮਿਆਨੇ ਅਤੇ ਛੋਟੇ ਕਿਸਾਨਾਂ ਨੂੰ ਐਲਾਨੀ ਗਈ ਕਰਜ਼ ਮਾਫੀ ਸਕੀਮ ਦੇ ਦਾਇਰੇ ਵਿੱਚ ਲਿਆਉ ਲਈ ਵਚਨਬੱਧ ਹੈ। ਇਸ ਤੋਂ ਬਾਅਦ ਜਿਵੇਂ ਹੀ ਸੂਬੇ ਦੀ ਵਿੱਤੀ ਹਾਲਤ ਸੁਧਰਦੀ ਹੈ ਬਾਕੀ ਕਿਸਾਨਾਂ ਨੂੰ ਵੀ ਪੜਾਅਵਾਰ ਇਸ ਵਿੱਚ ਲਿਆਂਦਾ ਜਾਵੇਗਾ। ਉਨ੍ਹਾਂ ਕਿਹਾ ਕਿ ਰਹਿੰਦੇ 3 ਲੱਖ ਕਿਸਾਨਾਂ ਦਾ ਕਰਜ਼ ਵੀ ਜਲਦੀ ਹੀ ਮਾਫ ਕੀਤਾ ਜਾਵੇਗਾ।ਉਨ੍ਹਾਂ ਕਿਹਾ, "ਮੁੱਖ ਮੰਤਰੀ ਨੇ ਸਾਫ਼ ਕੀਤਾ ਕਿ ਮੋਦੀ ਜਨਤਾ ਨੂੰ ਗਲਤ ਜਾਣਕਾਰੀ ਅਤੇ ਝੂਠੇ ਇਲਜ਼ਾਮਾਂ ਨਾਲ ਭਰਮਾਉਣ ਵਿੱਚ ਯਕੀਨ ਰੱਖਦੇ ਹਨ ਪਰ ਦੇਸ ਦੇ ਵੋਟਰ ਮੁੜ ਉਨ੍ਹਾਂ ਦੀ ਜੁਮਲੇਬਾਜ਼ੀ ਨਾਲ ਪ੍ਰਭਾਵਿਤ ਨਹੀਂ ਹੋਣਗੇ।\'\'ਇਹ ਵੀ ਪੜ੍ਹੋ:ਮੋਦੀ ਕੈਬਨਿਟ ਵੱਲੋਂ ਜਨਰਲ ਵਰਗ ਲਈ ਆਰਥਿਕ ਆਧਾਰ ’ਤੇ ਰਾਖਵਾਂਕਰਨ ਪਾਸ5 ਖਿਡਾਰੀ ਜਿਨ੍ਹਾਂ ਦੇ ਪ੍ਰਦਰਸ਼ਨ ਕਰਕੇ ਭਾਰਤ ਨੇ ਰਚਿਆ ਇਤਿਹਾਸ\'ਆਪ\' ਛੱਡਣ ਤੋਂ ਬਾਅਦ ਸੁਖਪਾਲ ਖਹਿਰਾ ਦਾ ਕੀ ਬਣੇਗਾ?ਇਹ ਵੀਡੀਓ ਤੁਹਾਨੂੰ ਪਸੰਦ ਆ ਸਕਦੇ ਹਨ:   Skip Youtube post  by BBC News Punjabi  Warning: Third party content may contain adverts End of Youtube post  by BBC News Punjabi         Image Copyright BBC News Punjabi BBC News Punjabi        Skip Youtube post 2 by BBC News Punjabi  Warning: Third party content may contain adverts End of Youtube post 2 by BBC News Punjabi         Image Copyright BBC News Punjabi BBC News Punjabi     (ਬੀਬੀਸੀ ਪੰਜਾਬੀ ਨਾਲ , , ਅਤੇ  \'ਤੇ ਜੁੜੋ।) '

# %%
df.shape
# Out:
# (784, 2)

# %%
df[df['text'].isnull()].shape
# Out:
# (0, 2)

# %%
label_cols = list(range(1,df.shape[1]))

# %%
print(label_cols)
# Out:
# [1]

# %%
id_to_col = list(df.columns)

# %%
col_to_id = {}
for i, col in enumerate(id_to_col):
    col_to_id[col] = i

# %%
class PanjabiTokenizer(BaseTokenizer):
    def __init__(self, lang:str):
        self.lang = lang
        self.sp = spm.SentencePieceProcessor()
        self.sp.Load(str('/home/gaurav/Downloads/LanguageModel/panjabi_lm.model'))
        
    def tokenizer(self, t:str) -> List[str]:
        return self.sp.EncodeAsPieces(t)

# %%
sp = spm.SentencePieceProcessor()
sp.Load('/home/gaurav/Downloads/LanguageModel/panjabi_lm.model')
itos = [sp.IdToPiece(int(i)) for i in range(30000)]

# %%
itos
# Out:
# ['<unk>',
#  '<s>',
#  '</s>',
#  '।',
#  ',',
#  '▁ਹੈ',
#  '▁ਦੇ',
#  '▁',
#  '▁ਵਿੱਚ',
#  '▁ਦੀ',
#  '▁ਅਤੇ',
#  '▁ਦਾ',
#  '▁ਨੂੰ',
#  '▁ਇੱਕ',
#  '▁ਹਨ',
#  '-',
#  '▁ਤੋਂ',
#  '.',
#  '▁ਸੀ',
#  '▁ਤੇ',
#  '▁ਇਹ',
#  '▁ਇਸ',
#  '▁ਨਾਲ',
#  '▁ਨੇ',
#  '▁·',
#  '▁ਲਈ',
#  'ਾਂ',
#  '▁ਵੀ',
#  '▁ਕਿ',
#  '▁ਜੋ',
#  'ੀ',
#  '▁ਕੀਤਾ',
#  '▁q',
#  '▁ਜਾਂਦਾ',
#  '▁�',
#  '▁ਵਿਚ',
#  '▁ਗਿਆ',
#  '▁ਹੀ',
#  '▁ਉਹ',
#  '▁ਉਸ',
#  'X',
#  '▁ਤੌਰ',
#  '▁ਹੁੰਦਾ',
#  'ਾ',
#  '▁ਨਹੀਂ',
#  '▁ਉੱਤੇ',
#  '▁ਕਿਸੇ',
#  'ੇ',
#  '▁ਦੀਆਂ',
#  '▁ਕੇ',
#  '▁ਜਾਂ',
#  '▁ਕੀਤੀ',
#  '▁ਹੋ',
#  '▁ਕਰਨ',
#  ':',
#  'ਆਂ',
#  '▁ਕਰ',
#  '▁ਜਿਸ',
#  '▁ਸਨ',
#  '�',
#  '▁ਜਾ',
#  '▁ਹੁੰਦੀ',
#  '▁ਪਰ',
#  '▁ਹੋਇਆ',
#  '▁ਹੋਰ',
#  'ਕ',
#  'ਨ',
#  '▁ਤੱਕ',
#  "▁'",
#  '▁ਸਭ',
#  '▁ਤਾਂ',
#  'ਸ',
#  '▁ਸਿੰਘ',
#  '▁ਉਨ੍ਹਾਂ',
#  '▁ਆਪਣੇ',
#  '▁ਗਈ',
#  '▁ਸਮੁੰਦਰ',
#  '▁ਦੁਆਰਾ',
#  '▁।',
#  '▁ਦੋ',
#  '▁ਬਹੁਤ',
#  '▁ਦਿੱਤਾ',
#  '▁ਹੁੰਦੇ',
#  '▁ਵਾਲੇ',
#  '▁ਬਾਅਦ',
#  '▁ਸਕਦਾ',
#  '▁ਸਾਲ',
#  '▁ਰੂਪ',
#  '▁ਕੋਈ',
#  '▁ਅੰਦਰ',
#  '▁ਕੁਆਂਟਮ',
#  'ਲ',
#  '▁ਹੋਏ',
#  '▁ਕਰਦਾ',
#  'ਤੇ',
#  '▁ਭਾਰਤ',
#  '▁ਹੋਣ',
#  '▁ਪਿੰਡ',
#  '▁ਜਾਂਦੀ',
#  '▁ਸਮੇਂ',
#  '▁ਕਰਦੇ',
#  '▁ਗਏ',
#  'ਰ',
#  '▁ਇਕ',
#  '▁ਕਿਹਾ',
#  '▁ਪੰਜਾਬ',
#  '▁ਥਿਊਰੀ',
#  '▁ਭਾਰਤੀ',
#  '▁ਕਈ',
#  '▁"',
#  '▁ਕੰਮ',
#  'ਿਕ',
#  '▁ਪੰਜਾਬੀ',
#  'ਤ',
#  '▁ਜਦੋਂ',
#  '▁ਸਾਰੇ',
#  '"',
#  '▁ਜੀ',
#  '▁ਰਾਹੀਂ',
#  '▁ਜਾਣ',
#  '▁ਜਿਵੇਂ',
#  '▁ਨਾ',
#  '▁ਹੋਈ',
#  'ਿਤ',
#  '▁ਆਪਣੀ',
#  ';',
#  '▁ਵਿੱਚੋਂ',
#  "'",
#  '▁ਵੱਲ',
#  '▁ਪਹਿਲਾਂ',
#  '▁ਸ਼ੁਰੂ',
#  '▁ਸਪੇਸ',
#  '▁ਉਸਨੇ',
#  '▁ਲੋਕ',
#  '▁ਨਾਮ',
#  '▁ਕਣ',
#  'ਦੇ',
#  '▁ਰਿਹਾ',
#  '▁ਰਾਜ',
#  'ਚ',
#  '▁ਇਕੁਏਸ਼ਨ',
#  '▁ਵਾਲੀ',
#  '▁ਭਾਸ਼ਾ',
#  '▁ਇਹਨਾਂ',
#  '▁ਗੁਰੂ',
#  'ਤਾ',
#  '▁ਕੀਤੇ',
#  '▁=',
#  'ਂ',
#  'ਜ਼',
#  '▁ਲਿਆ',
#  '▁ਵਾਸਤੇ',
#  '▁ਊਰਜਾ',
#  '▁ਖੇਤਰ',
#  '▁ਜਾਂਦੇ',
#  '▁ਕਰਦੀ',
#  '▁‘',
#  '▁{\\',
#  '▁ਕਿਉਂਕਿ',
#  '▁ਜਨਮ',
#  '▁ਆਮ',
#  '▁ਕਾਰਨ',
#  '▁ਜਿੱਥੇ',
#  '▁ਕਰਕੇ',
#  '▁ਸ਼ਹਿਰ',
#  '▁ਰਹੇ',
#  '▁ਵਜੋਂ',
#  '▁ਉਹਨਾਂ',
#  '▁ਫੀਲਡ',
#  'ਈ',
#  '▁ਵਾਰ',
#  '▁ਵਾਲਾ',
#  '▁ਵਿਗਿਆਨ',
#  '▁ਮੁੱਖ',
#  'ਮ',
#  '▁ਕੁੱਝ',
#  '▁ਜਿਆਦਾ',
#  'ੀਆਂ',
#  'ਵਾਂ',
#  '▁ਹੋਵੇ',
#  '▁ਫੇਰ',
#  '▁ਤਿੰਨ',
#  'ਡ',
#  'ਏ',
#  '▁ਪ੍ਰਾਪਤ',
#  '/',
#  '▁ਪੈਦਾ',
#  '▁ਕੁਝ',
#  'ਦਾ',
#  's',
#  '▁ਬਾਰੇ',
#  '▁ਅਨੁਸਾਰ',
#  'style',
#  '▁ਦਿਨ',
#  '▁ਇਸਨੂੰ',
#  'ਣ',
#  'display',
#  '▁ਮਕੈਨਿਕਸ',
#  '▁ਲੈ',
#  '▁ਰਿਲੇਟੀਵਿਟੀ',
#  '▁ਹੁੰਦੀਆਂ',
#  '▁ਦਿੱਤੀ',
#  '▁2',
#  '▁ਪਹਿਲੀ',
#  '▁ਸਾਹਿਬ',
#  '▁ਸ਼ਬਦ',
#  '▁ਸਾਹਿਤ',
#  '▁ਲੋਕਾਂ',
#  '|',
#  'ੋ',
#  '▁ਸਦੀ',
#  '▁ਸਪਿੱਨ',
#  '▁ਦੇਸ਼',
#  '▁ਦੂਜੇ',
#  '▁ਵੇਵ',
#  '▁ਆਪ',
#  '▁ਸਿਸਟਮ',
#  '▁ਆ',
#  '▁ਕਰਨਾ',
#  '’',
#  '▁ਦੌਰਾਨ',
#  '▁ਹਿੱਸਾ',
#  '▁ਵਲੋਂ',
#  '▁ਗੈਰ',
#  '▁ਸਿਰਫ',
#  '▁ਹਰ',
#  '▁ਪ੍ਰਕਾਸ਼',
#  '▁ਇੱਥੇ',
#  'ਟ',
#  '▁ਖਾੜੀ',
#  '▁ਸ਼ਾਮਿਲ',
#  '▁ਨਾਂ',
#  '▁ਤਰ੍ਹਾਂ',
#  '▁ਯੂਨੀਵਰਸਿਟੀ',
#  '▁ਸਕਦੇ',
#  '▁ਘੱਟ',
#  '▁ਜੇਕਰ',
#  '▁ਸਪੇਸਟਾਈਮ',
#  '▁ਵੱਖ',
#  '▁ਆਦਿ',
#  '▁ਕਣਾਂ',
#  '▁ਰਹੀ',
#  'ਿਆ',
#  '▁ਬਣ',
#  '▁ਇਸਦੇ',
#  'ਿਆਂ',
#  '▁ਸੰਸਾਰ',
#  '▁ਵੱਧ',
#  '▁ਸਮਾਂ',
#  '▁ਹੁਣ',
#  '▁ਸ',
#  '▁-',
#  '▁ਫੰਕਸ਼ਨ',
#  '▁ਇਨ੍ਹਾਂ',
#  '2',
#  '▁ਵਰਤੋਂ',
#  '▁ਭੌਤਿਕ',
#  '▁ਸਕਦੀ',
#  '▁ਹੱਲ',
#  '▁ਸਥਿਤ',
#  '▁ਪ੍ਰਤਿ',
#  'ਰੀ',
#  '▁ਫਿਰ',
#  '▁ਜਿਹਨਾਂ',
#  'ਦ',
#  '▁ਉਸਨੂੰ',
#  '▁ਤਰਾਂ',
#  '▁ਉੱਪਰ',
#  'ਨਾ',
#  '▁ਸ਼ਾਮਲ',
#  '▁ਅਸੀਂ',
#  '▁ਅਰਥ',
#  '▁ਜੀਵਨ',
#  '▁ਸਕੂਲ',
#  '▁ਅ',
#  '▁ਦਰਮਿਆਨ',
#  '▁ਵਕਤ',
#  '▁ਹਾਂ',
#  '▁ਘਰ',
#  '▁1',
#  'ਜ',
#  '▁ਸਬੰਧਤ',
#  '▁ਸ਼੍ਰੋਡਿੰਜਰ',
#  '▁ਅਵਸਥਾ',
#  '▁ਏ',
#  '▁ਉਮਰ',
#  '▁ਪੇਸ਼',
#  '▁ਮੂਲ',
#  '▁ਚਾਰ',
#  '▁ਪਿਤਾ',
#  '▁ਮੋਮੈਂਟਮ',
#  '▁ਉਸਦੇ',
#  '▁ਜ਼ਿਲ੍ਹੇ',
#  '▁ਪੁੰਜ',
#  '▁ਫਿਲਮ',
#  '▁ਅਜਿਹੀ',
#  '▁ਵੈਕਟਰ',
#  'ਵੀਂ',
#  '▁ਹਰੇ',
#  '▁|',
#  '▁ਜਨਰਲ',
#  '▁ਵਿਖੇ',
#  '▁the',
#  '▁“',
#  '▁ਲਿਖਿਆ',
#  '▁ਸਿਧਾਂਤ',
#  '▁ਮੰਨਿਆ',
#  '▁ਵੱਡਾ',
#  '▁ਅਮਰੀਕਾ',
#  '▁ਧਰਮ',
#  '▁ਕੀ',
#  'ਦੀ',
#  '1',
#  'ਆ',
#  '▁ਇਸਦੀ',
#  '▁ਇਸਦਾ',
#  'ਸੀ',
#  '▁ਫ਼ਿਲਮ',
#  '▁ਧਰਤੀ',
#  '▁.',
#  '▁ਪਹਿਲਾ',
#  '▁’',
#  '▁ਗੱਲ',
#  '▁ਸਾਪੇਖਿਕ',
#  '▁ਕਲਾਸੀਕਲ',
#  '▁ਪਹਿਲੇ',
#  '▁ਅੱਗੇ',
#  'ਲੇ',
#  '▁ਉਸਦੀ',
#  'ਵ',
#  '▁ਫ੍ਰੇਮ',
#  '▁ਕਿਸਮ',
#  '▁ਗਤੀ',
#  '▁ਅਜਿਹੇ',
#  '▁ਇਸਲਈ',
#  '▁ਵਿਸ਼ੇਸ਼',
#  '▁ਈ',
#  '▁ਪਾਣੀ',
#  '▁ਮੌਤ',
#  '▁ਖਾਸ',
#  '▁ਦੱਖਣੀ',
#  '▁ਜਾਂਦੀਆਂ',
#  '▁ਉੱਤਰ',
#  '▁ਜਿਸਦਾ',
#  '▁ਗਰੁੱਪ',
#  '▁ਰੱਖਿਆ',
#  '▁ਘਟਨਾਵਾਂ',
#  '▁ਰਚਨਾ',
#  '▁ਆਪਣਾ',
#  '▁ਦਿੰਦਾ',
#  '▁ਸਥਾਨ',
#  '▁x',
#  '▁ਪ੍ਰਸਿੱਧ',
#  '▁A',
#  '▁ਕੋਲ',
#  '▁ਵਿਕਾਸ',
#  '”',
#  '▁ਟਾਪੂ',
#  '▁ਅਧੀਨ',
#  '▁ਸਰਕਾਰ',
#  '▁ਦੱਖਣ',
#  '▁ਲੇਖਕ',
#  '▁ਉਦਾਹਰਨ',
#  '▁ਅੰਗਰੇਜ਼ੀ',
#  '▁ਬਣਾਇਆ',
#  '▁ਚ',
#  '▁ਗਣਿਤ',
#  '▁ਵਿਆਹ',
#  '▁ਵੱਡੇ',
#  '▁ਵਾਲੀਆਂ',
#  '▁of',
#  '▁ਵਿਆਖਿਆ',
#  '▁ਮਾਡਲ',
#  'ਿੰਗ',
#  '▁ਆਈਨਸਟਾਈਨ',
#  '▁ਪੂਰੀ',
#  '▁ਉੱਤਰੀ',
#  'ਟੀ',
#  '▁ਇਸਤਰਾਂ',
#  '▁ਰਹਿੰਦਾ',
#  '▁ਨਿਯਮ',
#  '▁ਪਾਕਿਸਤਾਨ',
#  '▁ਮਹੱਤਵਪੂਰਨ',
#  '▁ਬਾਦ',
#  '▁ਸਾਰੀਆਂ',
#  '▁ਕਾਲਜ',
#  'ੀਆ',
#  '▁ਨਾਵਲ',
#  '▁ਕਹਿੰਦੇ',
#  '▁ਦੇਣ',
#  '▁ਵੱਲੋਂ',
#  '▁ਕੁੱਲ',
#  '▁ਇਲਾਵਾ',
#  '▁ਪ੍ਰਭਾਵ',
#  '▁ਪਰਿਵਾਰ',
#  '▁ਦ',
#  '▁ਖੋਜ',
#  '▁ਸਿੱਖ',
#  '▁ਦਿੱਤੇ',
#  '▁ਅਪਣੇ',
#  '▁ਪ੍ਰਮੁੱਖ',
#  '▁S',
#  'ਲਾ',
#  '▁ਜਾਣਿਆ',
#  '▁ਵਿਸ਼ਵ',
#  '਼',
#  '▁ਇੱਕੋ',
#  'ਕੇ',
#  '▁ਓਪਰੇਟਰ',
#  '▁ਵਰਤਿਆ',
#  '▁ਬ੍ਰਹਿਮੰਡ',
#  '▁ਅਜਿਹਾ',
#  '▁ਭੌਤਿਕੀ',
#  '▁ਜਿਸਨੂੰ',
#  '▁ਵਿਚਾਰ',
#  '▁3',
#  '▁•',
#  'ਹ',
#  '▁ਔਬਜ਼ਰਵਰ',
#  'ਅ',
#  '▁ਬਦਲ',
#  'ਗ',
#  '▁a',
#  'ਬ',
#  '▁ਡੀ',
#  '▁ਸਪੀਡ',
#  '▁ਰੇਖਾ',
#  '▁ਕਦੇ',
#  '▁ਦੂਰੀ',
#  '▁ਡਾ',
#  '▁ਭਾਵੇਂ',
#  '▁ਲ',
#  'ਵੀ',
#  '▁ਵੱਡੀ',
#  '▁ਬਿੰਦੂ',
#  '▁ਮੁੱਲ',
#  '▁ਗਿਣਤੀ',
#  '▁ਚਿੱਤਰ',
#  '▁ਮਸ਼ਹੂਰ',
#  '▁ਵੱਖਰੇ',
#  '▁ਇਤਿਹਾਸ',
#  '▁ਸਪੈਸ਼ਲ',
#  'ਨੀ',
#  '▁ਟਾਈਮ',
#  '▁ਪੱਛਮੀ',
#  '▁ਸਬੰਧ',
#  '▁ਲਾਗੂ',
#  '▁ਹਿੱਸੇ',
#  '▁ਦੋਵੇਂ',
#  'ੋਂ',
#  '▁ਬਣਾ',
#  '▁E',
#  '▁ਕਵੀ',
#  '}',
#  '▁ਪਾਸੇ',
#  '▁ਅਧਿਐਨ',
#  '▁ਬਲਾਕ',
#  '▁ਜਿਨ੍ਹਾਂ',
#  '▁ਦੂਰ',
#  '▁ਸਿੱਖਿਆ',
#  'ੂ',
#  '▁/',
#  '▁ਕਹਾਣੀ',
#  '▁ਸੰਯੁਕਤ',
#  '▁ਨਾਪ',
#  '▁ਵਿਚੋਂ',
#  '▁ਆਈ',
#  '▁ਲੌਰੰਟਜ਼',
#  '▁ਕਾਲ',
#  'ਸ਼',
#  '▁20',
#  '▁ਮਾਂ',
#  '▁\\',
#  '▁ਨਾਲ਼',
#  '▁ਸੰਭਵ',
#  '▁ਦਿੱਲੀ',
#  '▁ਪੰਜ',
#  '▁ਕੀਤੀਆਂ',
#  '▁ਇਸੇ',
#  '▁ਤਰੀਕੇ',
#  '▁ਪਰਸਪਰ',
#  '▁ਭਾਗ',
#  '▁ਬਾਕੀ',
#  '▁ਕਲਾ',
#  '▁ਹੋਣਾ',
#  '▁ਸਮਾਜ',
#  'ਲੀ',
#  '▁ਰਾਜਧਾਨੀ',
#  '▁ਥਾਂ',
#  '▁ਪ੍ਰਸਤੁਤ',
#  '▁ਅਮਰੀਕੀ',
#  '▁ਅਨੁਮਾਨ',
#  '▁ਭੂਮਿਕਾ',
#  '▁ਅਕਸਰ',
#  'ਪ',
#  '▁ਵਾਂਗ',
#  '▁ਮੌਜੂਦ',
#  '▁ਤਰੰਗਾਂ',
#  '▁ਸਪਿੱਨੌਰ',
#  '▁ਨੇੜੇ',
#  '▁ਪਤਾ',
#  '▁in',
#  '▁ਸੰਗੀਤ',
#  '▁ਲਿਖੇ',
#  '▁ਤਕ',
#  '▁ਦੂਜੀ',
#  '▁ਅਵਸਥਾਵਾਂ',
#  '▁ਸਮਝ',
#  '▁ਇ',
#  '▁ਨਿਊ',
#  '▁ਜੋੜ',
#  '▁ਚੀਨ',
#  '▁ਗਈਆਂ',
#  '▁ਚਾਹੀਦਾ',
#  '▁ਪ੍ਰਯੋਗ',
#  '▁ਬਣਤਰ',
#  'ਰਾ',
#  '▁ਦਿਸ਼ਾ',
#  '▁ਮੈਂਬਰ',
#  '▁ਉਲਟ',
#  '▁ਹੇਠ',
#  '▁ਸਹੀ',
#  '▁ਉੱਚ',
#  '▁ਕਿਤਾਬ',
#  '▁ਪਰਿਭਾਸ਼ਿਤ',
#  '▁10',
#  '▁ਮਾਤਰਾ',
#  '▁ਬਣਾਉਣ',
#  '▁ਅੱਜ',
#  '▁ਕਵਿਤਾ',
#  '▁4',
#  '▁ਰੰਗ',
#  '▁ਦੂਜਾ',
#  '▁ਪਿਆ',
#  '▁ਟੀਮ',
#  'ਓ',
#  '▁ਅੰਤ',
#  '▁15',
#  '▁ਕਾਵਿ',
#  '▁ਬਣਿਆ',
#  '▁ਨਤੀਜੇ',
#  '▁ਸਟਰਿੰਗ',
#  '▁ਗਰੈਵੀਟੇਸ਼ਨਲ',
#  '▁ਕਾਰਜ',
#  '▁ਰੱਖਦਾ',
#  '▁ਭਾਵ',
#  '▁ਉਸਦਾ',
#  '▁B',
#  'ਿ',
#  '▁ਬੋਲੀ',
#  '▁16',
#  'ਕਾ',
#  '▁ਪਦਾਰਥ',
#  '▁ਸਧਾਰਨ',
#  '▁ਗਰੈਵਿਟੀ',
#  '▁ਸੰਨ',
#  '▁p',
#  '▁ਵਰਗ',
#  '▁ਤਰੰਗ',
#  '▁ਚਾਰਜ',
#  'ਵਾ',
#  '▁ਨੰਬਰ',
#  '▁c',
#  '▁ਬਾਹਰ',
#  '▁ਸਭਾ',
#  '▁ਮਿਲ',
#  '▁ਸ੍ਰੀ',
#  '▁ਸ਼ਾਹ',
#  'ਇਸ',
#  '▁ਸ਼ਬਦਾਂ',
#  'ਵੇਂ',
#  '▁ਬ',
#  '▁ਜੇ',
#  'ਜੀ',
#  '▁ਛੋਟੇ',
#  '▁ਤਿਆਰ',
#  '▁ਕਿਲੋਮੀਟਰ',
#  '▁ਜ਼ਿਆਦਾ',
#  '▁ਲਾਲ',
#  '▁ਬਰਾਬਰ',
#  '▁ਵਿਸ਼ਾਲ',
#  '▁ਕਰਦੀਆਂ',
#  '▁ਵਿਚਕਾਰ',
#  '▁ਨਤੀਜਾ',
#  '▁ਭਰ',
#  '▁ਹਿੰਦੀ',
#  '▁5',
#  'ਤੀ',
#  'ਅਯਾਮੀ',
#  '▁ਚੀਜ਼',
#  '▁ਲੈਣ',
#  '▁ਸਥਿਰ',
#  '▁ਵਰਗੇ',
#  '▁ਸਾਲਾਂ',
#  '▁ਦੇਸ਼ਾਂ',
#  '▁ਕਲੌਕ',
#  '▁ਦੁਨੀਆਂ',
#  '▁ਸਗੋਂ',
#  '▁ਮੱਧ',
#  '▁ਸ਼ੁੱਧ',
#  '▁ਰਹਿੰਦੀ',
#  '▁ਆਇਆ',
#  '▁ਭਾਈ',
#  '▁ਥਿਊਰੀਆਂ',
#  '▁ਮਾਤਾ',
#  '▁t',
#  '▁ਪੱਧਰ',
#  'ਪਛਾਣ',
#  '▁ਯਾਤਰਾ',
#  '▁ਰੱਖਦੇ',
#  '▁ਮੇਲ',
#  '▁ਸਾਬਤ',
#  'ਪੁਰ',
#  '▁ਵਿਅਕਤੀ',
#  'E',
#  '▁ਰਹਿਣ',
#  '▁m',
#  '▁ਪਾਰਟੀ',
#  '▁ਉਪ',
#  '▁ਗੀਤ',
#  '▁ਪੂਰਬੀ',
#  '▁ਕ੍ਰਿਆ',
#  '▁ਮੁਤਾਬਕ',
#  '▁ਲੜਾਈ',
#  '▁ਸਰਵ',
#  '▁ਦਿੰਦੀ',
#  '▁12',
#  '▁ਰਹਿੰਦੇ',
#  '3',
#  '▁ਕੇਂਦਰ',
#  'ੀਅਨ',
#  '▁ਘਟਨਾ',
#  '▁ਫਾਰਮੂਲਾ',
#  '▁ਸਥਾਪਨਾ',
#  'ਵੱਖ',
#  '▁ਔਰਤਾਂ',
#  '▁ਸੰਖੇਪ',
#  '▁ਸਮਾਨ',
#  '▁ਕੰਪਲੈਕਸ',
#  '▁ਸ਼ੁਰੂਆਤੀ',
#  '▁ਲਗਭਗ',
#  '▁ਭਾਸ਼ਾਵਾਂ',
#  '▁ਸਮੇਤ',
#  '▁17',
#  '▁ਮਨੁੱਖ',
#  '▁ਸਮੀਕਰਨ',
#  '▁ਆਫ',
#  '▁ਤੋ',
#  'ਮੀ',
#  '▁ਜਾਵੇ',
#  '▁ਆਧੁਨਿਕ',
#  '▁ਜਾਣਕਾਰੀ',
#  '▁ਮਿਲਦਾ',
#  '▁ਵਾਸਤਵਿਕ',
#  '▁ਗਤੀਸ਼ੀਲ',
#  '▁ਪ੍ਰਦੇਸ਼',
#  '▁I',
#  '▁ਇਸਨੇ',
#  '▁ਕਰੋ',
#  '▁ਸੇਵਾ',
#  '▁ਦਰ',
#  '▁ਸਰਲ',
#  '▁ਪ੍ਰਕਾਰ',
#  '▁ਹੇਠਾਂ',
#  '▁ਸਮੀਕਰਨਾਂ',
#  '▁+',
#  'ਡੀ',
#  'ਂਸ',
#  '▁ਸ਼ੁਰੂਆਤ',
#  '▁ਵੇਲੇ',
#  '▁ਨਵੇਂ',
#  '▁ਛੱਡ',
#  'ਯੋਗ',
#  '▁ψ',
#  '▁ਜਾਰੀ',
#  '▁ਸੈੱਟ',
#  '▁ਕੁ',
#  '▁ਮੀਟਰ',
#  '▁ਰੱਖਣ',
#  '▁ਬੀ',
#  '▁ਸੰਚਾਰ',
#  '▁ਨਾਲੋਂ',
#  '▁ਬੁਨਿਆਦੀ',
#  '▁0',
#  '▁ਕੇਂਦਰੀ',
#  '4',
#  'ਬੀ',
#  'c',
#  '▁ਨਿਰਭਰ',
#  '▁ਪੜ੍ਹਾਈ',
#  '▁6',
#  '▁ਪ੍ਰਕਾਸ਼ਿਤ',
#  '▁ਮੰਗ',
#  '▁ਜੰਗ',
#  '▁18',
#  '▁ਇਲੈਕਟ੍ਰੌਨ',
#  '▁ਵਧ',
#  '▁ਕੇਵਲ',
#  '▁ਅਬਾਦੀ',
#  '▁ਅਪਣੀ',
#  '▁ਅਜੇ',
#  '▁ਕਾਰਣ',
#  '▁ਹਾਲਾਂਕਿ',
#  '▁ਪੈਂਦਾ',
#  '▁ਲਿਖੀ',
#  'ਕੀ',
#  '▁ਪੁਜੀਸ਼ਨ',
#  '▁ਚੰਗੀ',
#  '▁ਖੇਤਰਾਂ',
#  '▁ਹੋਂਦ',
#  '▁ਅੰਤਰਰਾਸ਼ਟਰੀ',
#  '▁ਸਮੂਹ',
#  '▁ਵਧੇਰੇ',
#  '°',
#  '▁ਸਵੈ',
#  'd',
#  '▁ਵਿਸ਼ਲੇਸ਼ਣ',
#  '▁ਡਾਲਰ',
#  '▁ਕਾ',
#  '▁ਬਣਾਈ',
#  '▁ਏਸ਼ੀਆ',
#  '▁O',
#  '▁ਇਨਾਮ',
#  'ਨੇ',
#  '▁ਮੁਤਾਬਿਕ',
#  '▁ਦਰਸਾਇਆ',
#  '▁ਰਾਮ',
#  'ੁ',
#  '▁ਕੁਦਰਤੀ',
#  'ਮਾ',
#  '▁ਰਾਸ਼ਟਰੀ',
#  '▁ਨਿਰਦੇਸ਼ਾਂਕ',
#  'k',
#  '▁ਰਾਜਾ',
#  '▁ਪ੍ਰਭਾਵਿਤ',
#  'N',
#  '▁ਮਾਰ',
#  '▁ਪਹੁੰਚ',
#  '▁ਧਾਰਮਿਕ',
#  '▁ਦਿੰਦੇ',
#  '▁ਆਉਣ',
#  '▁and',
#  '▁ਕਿਵੇਂ',
#  'ਦੀਆਂ',
#  '▁ਪੁਟੈਂਸ਼ਲ',
#  '▁ਨਾਟਕ',
#  '▁ਡਿਗਰੀ',
#  '▁ਪੁਰਸਕਾਰ',
#  '▁ਜਿਸਨੇ',
#  '▁ਆਮਤੌਰ',
#  '▁ਮਹਾਨ',
#  '▁ਅਲ',
#  '▁14',
#  'ਵੇ',
#  '▁ਪੁੱਤਰ',
#  '▁ਕੌਰ',
#  '▁ਪ੍ਰਸਤੁਤੀ',
#  '▁ਵੰਡ',
#  '▁ਪਛਾਣ',
#  '▁ਪਾ',
#  '▁ਹੈਮਿਲਟੋਨੀਅਨ',
#  '▁ਲੜੀ',
#  '▁ਆਫ਼',
#  '▁ਲੱਗ',
#  '▁ਮੈਂ',
#  '▁ਸਮਾਜਿਕ',
#  '▁ਮਿਲਦੀ',
#  '▁ਬਣੇ',
#  '▁ਯੂਰਪ',
#  '▁ਹਿੰਦੂ',
#  '▁ਸਕਦੀਆਂ',
#  'ਣਾ',
#  '▁ਸਭਿਆਚਾਰ',
#  '▁ਕ੍ਰਿਕਟ',
#  '▁ਧਿਆਨ',
#  '▁s',
#  'e',
#  '▁ਵਿਸ਼ੇਸ਼ਤਾਵਾਂ',
#  '▁ਗ੍ਰੰਥ',
#  '▁ਮ',
#  '▁19',
#  '▁ਪ੍ਰਤੀ',
#  '▁C',
#  '▁ਬਾਬਾ',
#  '▁ਸਮਰੂਪਤਾ',
#  '▁ਬੰਦ',
#  '▁ਅੰਦਰੂਨੀ',
#  'ਇਹ',
#  '▁ਧਾਰਨਾ',
#  '▁ਨਾਮਕ',
#  'ਾਤਮਿਕ',
#  '▁ਸੁਤੰਤਰ',
#  'ed',
#  '▁ਅੰਤਰ',
#  'ਕੋ',
#  '▁ਸਾਡੇ',
#  '▁ਆਰ',
#  '▁V',
#  '▁ਗੁਣਨਫਲ',
#  '▁ਕੰਪਨੀ',
#  '▁ਨਦੀ',
#  '▁ਜਨਵਰੀ',
#  'a',
#  '▁ਹੋਈਆਂ',
#  '▁11',
#  '▁to',
#  '▁ਹਾਸਲ',
#  '▁v',
#  '▁ਜਦੋਂਕਿ',
#  '▁ਐਨਰਜੀ',
#  '▁ਫੀਲਡਾਂ',
#  '▁ਮਨ',
#  '▁ਲੰਬਾਈ',
#  '▁ਓਸ',
#  'ਫ਼',
#  '▁ਆਏ',
#  '▁n',
#  '▁ਪੀ',
#  '▁ਬੇ',
#  'ਫ',
#  '▁ਰਹਿ',
#  '▁ਸਕੇ',
#  '▁ਯੋਗਦਾਨ',
#  '▁ਦਰਿਆ',
#  'ਪੀ',
#  '6',
#  '▁ਬਣੀ',
#  '▁ਬਲ',
#  '▁ਚਰਚਾ',
#  'ਬੱਧ',
#  '▁ਮਨੁੱਖੀ',
#  '▁13',
#  '▁ਯੋਗ',
#  '▁7',
#  '▁ਜ਼ਿਲ੍ਹਾ',
#  '▁ਪ੍ਰਧਾਨ',
#  '▁ਨਵੀਂ',
#  '▁ਅਗਸਤ',
#  '▁9',
#  '▁ਆਉਂਦਾ',
#  '▁ਇਸ਼ਾਰਾ',
#  '▁8',
#  '▁ਸੀਮਤ',
#  'n',
#  '▁{',
#  '▁ਪ੍ਰਾਚੀਨ',
#  '▁ਸਾਰੀ',
#  '▁ਸਪੱਸ਼ਟ',
#  '▁ਵਧੀਆ',
#  '▁ਮੰਨ',
#  '▁ਦੇਵ',
#  '▁ਹੱਦ',
#  '▁ਪੂਰਬ',
#  '▁ਜਰੂਰਤ',
#  '▁ਮੈਟ੍ਰਿਕਸ',
#  '▁ਵਿਕਸਿਤ',
#  '▁^',
#  '▁ਸ਼ਕਤੀ',
#  '▁ਇਲਾਕੇ',
#  '▁ਜਰਮਨੀ',
#  '▁2011',
#  '▁ਯੁੱਧ',
#  '▁ਦ੍ਰਿਸ਼ਟੀਕੋਣ',
#  '▁ਚੋਣ',
#  '\\',
#  'ੜ',
#  '▁ਤਬਦੀਲੀ',
#  '▁ਯੂ',
#  '▁ਮਾਰਚ',
#  '▁ਬਿਆਨ',
#  '▁ਹ',
#  '▁M',
#  '▁ਐਂਡ',
#  '▁ਬਲੈਕ',
#  '▁ਦੁਨੀਆ',
#  '▁ਵਿਗਿਆਨੀ',
#  '▁ਰੂਸੀ',
#  '▁H',
#  '▁ਅਧਾਰ',
#  '▁ਅਕਤੂਬਰ',
#  '▁ਪਾਇਆ',
#  '▁ਭਰਾ',
#  '▁}',
#  '▁ਮਿਲਿਆ',
#  '▁ਜਰੂਰ',
#  '▁:',
#  '▁ਅਸਲ',
#  '▁ਤੱਤ',
#  '▁ਮਿੰਕੋਵਸਕੀ',
#  '▁ਪਰਤੋ',
#  '▁ਐਮ',
#  '▁ਬੱਚਿਆਂ',
#  '▁ਬ੍ਰਿਟਿਸ਼',
#  '▁ਉੱਥੇ',
#  '0',
#  '▁ਅਧਿਕਾਰ',
#  '▁ਸਮੱਸਿਆ',
#  '▁30',
#  '▁ਇੰਗਲੈਂਡ',
#  '▁ਲਾ',
#  '▁ਇਲੈਕਟ੍ਰਿਕ',
#  '▁ਪੱਛਮ',
#  '▁ਰੱਖਦੀ',
#  'ਦਾਰ',
#  '▁ਸੂਚੀ',
#  '▁ਅਯਾਮ',
#  '▁ਮੰਤਰੀ',
#  '▁ਛੋਟੀ',
#  '▁ਲੱਛਣ',
#  '▁ਰੈਫ੍ਰੈ',
#  '▁ਨਵੰਬਰ',
#  'ਯ',
#  '▁ਉਦੋਂ',
#  '▁ਡੀਰਾਕ',
#  '▁ਉਰਦੂ',
#  '▁ਇਕੁਏਸ਼ਨਾਂ',
#  '▁ਵ',
#  '▁ਜੁਲਾਈ',
#  '▁ਜਰਮਨ',
#  '▁ਨੋਟ',
#  '▁ਉਸੇ',
#  '▁ਖੇਡਾਂ',
#  '▁ਰੂਸ',
#  '▁ਪ੍ਰ',
#  '▁P',
#  '5',
#  '▁ਪੁਸਤਕ',
#  '▁ਲਾਹੌਰ',
#  '▁ਕਾਫੀ',
#  '▁ਬੱਚੇ',
#  '▁ਸਰਕਾਰੀ',
#  '▁ਦਹਾਕੇ',
#  '▁ਵਿਸਥਾਰ',
#  'ing',
#  'ਕਰ',
#  '▁ਰੱਖ',
#  '▁ਚੀਜ਼ਾਂ',
#  '▁ਜਾਣਾ',
#  '▁ਦਸੰਬਰ',
#  '▁ਪੂਰਵ',
#  '▁ਸਾਮਰਾਜ',
#  'ਨੂੰ',
#  '▁ਨਿਸ਼ਚਿਤ',
#  '▁ਵਰਤੇ',
#  '▁ਐ',
#  '▁ਰਚਨਾਵਾਂ',
#  'ਸ਼ਨ',
#  '▁ਕ੍ਰਿਆਵਾਂ',
#  '▁ਪੂਰਾ',
#  '▁ਛੇ',
#  '▁ਲੇਖ',
#  '▁ਸੰਘ',
#  'ਗਾ',
#  '▁ਨਗਰ',
#  '▁ਵਾਪਸ',
#  '▁ਨਾਨਕ',
#  '▁ਪੁਨਰ',
#  '▁ਅੰਕ',
#  '▁ਹੋਵੇਗਾ',
#  '▁ਰਹੀਆਂ',
#  '▁ਵੱਖਰੀਆਂ',
#  '▁ਲੋੜ',
#  '▁ਟ',
#  'ਰੋ',
#  't',
#  '▁ਗਿਆਨ',
#  '▁ਸੰਬੰਧ',
#  '9',
#  '▁ਕੋ',
#  '▁ਪੈ',
#  '▁ਖੁਦ',
#  '▁ਆਧਾਰ',
#  '▁ਮਈ',
#  'ਇਲੈਕਟ੍ਰੋਮੈਗਨੈਟਿਕ',
#  '▁ਫਿਲਮਾਂ',
#  '▁−',
#  '▁ਦਿਲ',
#  '7',
#  '▁ਵਰਤਦੇ',
#  '▁ਪਰਿਵਰਤਨ',
#  '▁ਜਿਆਦਾਤਰ',
#  '▁ਪਟਿਆਲਾ',
#  '▁ਔਰਤ',
#  '▁ਕੰਪਿਊਟਰ',
#  '▁ਫ੍ਰੀਕੁਐਂਸੀ',
#  '▁ਹਿਸਾਬ',
#  'ਬਾ',
#  '▁ਲਹਿਰ',
#  '▁ਸਤੰਬਰ',
#  '▁ਪ੍ਰਦਾਨ',
#  '▁ਕਹਾਣੀਆਂ',
#  'ਨੋ',
#  '▁–',
#  '▁ਪਾਸ',
#  'ਫੋਰਡ',
#  '▁ਵਸਤੂ',
#  '▁ਸਾਹਿਤਕ',
#  '▁ਤਰਕ',
#  'ਕਲ',
#  '▁ਪੇਅਰਟੀ',
#  ...]

# %%
# 30,000 is the vocab size that we chose in sentencepiece
panjabi_vocab = Vocab(itos)

# %%
panjabi_tok = PanjabiTokenizer('pb')

# %%
tokenizer = Tokenizer(tok_func=PanjabiTokenizer, lang='pb')

# %%
tokenizer.special_cases
# Out:
# ['xxunk', 'xxpad', 'xxbos', 'xxfld', 'xxmaj', 'xxup', 'xxrep', 'xxwrep']

# %%
data_lm = TextDataBunch.from_csv(path=path, csv_name='Punjabi_Binary_Classification.csv', text_cols=[0], label_cols=label_cols, tokenizer=tokenizer, vocab=panjabi_vocab)

# %%
data_lm.save()

# %%
bs=48

# %%
data_lm = TextLMDataBunch.load(path, 'tmp', bs=bs)

# %%
data_lm.show_batch()
# Out:
# <table>  <col width='5%'>  <col width='95%'>  <tr>
#     <th>idx</th>
#     <th>text</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>▁x x bo s ▁ਕੀ ▁ਭਾਜਪਾ ▁ਪ੍ਰਧਾਨ ▁ਅਮਿਤ ▁ਸ਼ਾਹ ▁ਨੇ ▁' ਜੈ ▁ਹਿੰਦ ' ▁ਨਾਅਰੇ ▁ਬਾਰੇ ▁ਝੂਠ ▁ਬੋਲਿਆ ? ▁ ਫੈਕਟ ▁ਚੈੱਕ ▁ਟੀਮ ▁ਬੀਬੀਸੀ ▁ਨਿਊਜ਼ ▁24 ▁ਜਨਵਰੀ ▁ 2019 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/ ▁ punjabi ▁/ ▁ india - 46 97 37 30 ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਬਾਰੇ ▁ਹੋਰ ▁ਪੜ੍ਹ ੋ ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਵਾਲੇ</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>▁" ਚ ੈੱਕ ▁ਮਿੰਨੀ ▁ਸਕਰਟ " ▁ਨਹੀਂ ▁ਹੈ । ▁ਇਹ ▁ਲੁ ੰਗੀ ▁ਹੈ । ▁ਤੁਸੀਂ ▁ਇਸ ▁ਨੂੰ ▁ਉਹੀ ▁ਕਿਉਂ ▁ਨਹੀਂ ▁ਕਹਿੰਦੇ , ▁ਜੋ ▁ਅਸਲ ▁ਵਿੱਚ ▁ਇਹ ▁ਹੈ ? ▁ਸਭਿਆਚਾਰ ▁ਨੂੰ ▁ਢੁਕਵੀਂ ▁ਮਾਨਤਾ ▁ਦਿਓ ।" <unk> ▁i m age ▁co py right ▁ <unk> hone y c um in ▁ <unk> hone y c um in <unk> ▁i m age ▁co py right ▁ <unk> hone y c um in ▁</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>▁ਪੰਜ ▁ਦਿਨਾਂ ▁ਤੱਕ ▁ਉਨ੍ਹਾਂ ▁ਨੂੰ ▁ਨਹੀਂ ▁ਮਿਲ ▁ਸਕਣਗੇ । ▁ਰਿ ਪਨ ▁ਨੇ ▁ਲੰਡਨ ▁ਵਾਪਸ ▁ਆਉਣ ▁ਦਾ ▁ਫ਼ੈਸਲਾ ▁ਲਿਆ । ▁ਜਦੋਂ ▁ਉਨ੍ਹਾਂ ▁ਦੇ ▁ਅਧਿਕਾਰੀਆਂ ▁ਨੇ ▁ਉਨ੍ਹਾਂ ▁ਨੂੰ ▁ਸਮਝਾਇਆ ▁ਤਾਂ ▁ਚੌਥੇ ▁ਦਿਨ ▁ਅਮੀਨ ▁ਰਿ ਪਨ ▁ਨੂੰ ▁ਮਿਲਣ ▁ਲਈ ▁ਤਿਆਰ ▁ਹੋਏ ▁ਪਰ ▁ਇਸ ▁ਦਾ ▁ਕੋਈ ▁ਫਾਇਦਾ ▁ਨਹੀਂ ▁ਹੋਇਆ । ਅ ਮੀਨ ▁ਆਪਣੇ ▁ਫ਼ੈਸਲੇ ▁' ਤੇ ▁ਅ ੜੇ ▁ਰਹੇ । ▁ਭਾਰਤ ▁ਸਰਕਾਰ ▁ਨੇ ▁ਵੀ ▁ਸਥਿਤੀ ▁ਦਾ ▁ਜਾਇਜ਼ ਾ ▁ਲੈਣ ▁ਲਈ ▁ਭਾਰਤੀ ▁ਵਿਦੇਸ਼ ▁ਸੇਵਾ ▁ਦੇ</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>▁ਗ੍ਰਾਮ ੀ ਣ ▁ਖੇਤਰਾਂ ▁ਦੀ ▁ਸਿੱਖਿਆ ▁ਸੰਬੰਧੀ ▁ਰਿਪੋਰਟ ▁ਵਿੱਚ ▁ਪੰਜਾਬ ▁ਵੀ ▁ਉਨ੍ਹਾਂ ▁ਕੁਝ ▁ਸੂਬਿਆਂ ▁' ਚ ▁ਸ਼ਾਮਿਲ ▁ਹੈ , ▁ਜਿੱਥੇ ▁ਪ੍ਰਾਇਮਰੀ ▁ਸਰਕਾਰੀ ▁ਸਕੂਲਾਂ ▁' ਚ ▁ਸਿੱਖਿਆ ▁ਦਾ ▁ਮਿਆਰ ▁ਵਧਿਆ ▁ਹੈ । ▁ਪੰਜਾਬ ▁ਦੀ ▁ਮਿਸਾਲ ▁ਦਿ ੰਦ ਿਆ ▁ਕਿਹਾ ▁ਗਿਆ ▁ਹੈ ▁ਕਿ ▁' ਪੜ੍ਹ ੋ ▁ਪੰਜਾਬ ' ▁ਪ੍ਰੋਗਰਾਮ ▁ਪੰਜਾਬ ▁ਵਿੱਚ ▁ਬਹੁਤ ▁ਵਧੀਆ ▁ਮਾਡਲ ▁ਬਣ ▁ਰਿਹਾ ▁ਹੈ । <unk> ▁i m age ▁co py right ▁re ut ers ▁ਫੋਟੋ ▁ਕੈਪ ਸ਼ਨ ▁ਟੈਰੀ</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>▁ਸਕਦੀ ' ▁ਵਾਲੀ ▁ਧਾਰਨਾ ▁ਨੂੰ ▁ਜ਼ਰੂਰ ▁ਬਦਲ ▁ਦੇਣਗੇ । ▁ਨਰਿੰਦਰ ▁ਮੋਦੀ ▁ਦੇ ▁ਨਾ ▁ਹਾਰਨ ▁ਵਾਲੇ ▁ਅਕਸ ▁ਨੂੰ ▁ਢਾਹ ▁ਲੱਗੀ ▁ਹੈ । ▁ਦੂਜੇ ▁ਪਾਸੇ ▁ਕਰੀਬ ▁ਇੱਕ ▁ਸਾਲ ▁ਪਹਿਲਾਂ ▁ਹੀ ▁ਪਾਰਟੀ ▁ਪ੍ਰਧਾਨ ▁ਵਜੋਂ ▁ਕਮਾਨ ▁ਆਪਣੇ ▁ਹੱਥ ▁ਲੈਣ ▁ਵਾਲੇ ▁ਰਾਹੁਲ ▁ਗਾਂਧੀ ▁ਦੇ ▁ਲਈ ▁ਇਹ ▁ਵੱਡਾ ▁ਹੌਸਲਾ ▁ਹੈ । ▁ਇਹ ▁ਵੀ ▁ਪੜ੍ਹ ੋ : ' ਰਾਹੁਲ ▁ 2019 ▁' ਚ ▁ਦਾਅਵੇਦਾਰ ▁ਪਰ ▁ਮਾਇਆ ਵਤੀ ▁ਦੀ ▁' ਮਾਇਆ ' ▁ਜ਼ਰੂਰੀ ' ▁ਰਾਹੁਲ ▁ਨੇ ▁ਕਿਹਾ ,</th>
#   </tr>
# </table>

# %%
learn = language_model_learner(data_lm, drop_mult=0.3)

# %%
# Loading the pretrained language model on panjabi wikipedia
learn.load('/home/gaurav/Downloads/LanguageModel/PanjabiDataset/models/fourth', with_opt=True)
# Out:
# LanguageLearner(data=TextLMDataBunch;
#
# Train: LabelList
# y: LMLabel (627 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: /home/gaurav/Downloads/ClassificationModel
# x: LMTextList (627 items)
# [Text ▁x x bo s ▁ਬਲਾਗ - ▁# <unk> ▁h er c ho ice ▁ਹਰ ▁ਗਾਲ ਼ ▁ਔਰਤਾਂ ▁ਦੇ ▁ਨਾਂ ▁ਉੱਤੇ ▁ਹੀ ▁ਕੱਢੀ ▁ਕਿਉਂ ▁ਜਾਂਦੀ ▁ਹੈ ? ▁ਦਿ ਵਿਆ ▁ਆਰਿਆ ▁ਬੀਬੀਸੀ ▁ਪੱਤਰਕਾਰ ▁24 ▁ਜਨਵਰੀ ▁2018 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/ ▁ punjabi ▁/ ▁ india -4 27 93 90 9 ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਬਾਰੇ ▁ਹੋਰ ▁ਪੜ੍ਹ ੋ ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਵਾਲੇ ▁ਪੈਨਲ ▁ਨੂੰ ▁ਬੰਦ ▁ਕਰੋ ▁ਉਹ ▁ਗਾਲ ਼ਾ ▁ਐਨ ੀਆਂ ▁ਮਾੜੀ ਆਂ ▁ਮੰਨੀਆਂ ▁ਜਾਂਦੀਆਂ ▁ਹਨ ▁ਕਿ ▁ਉਨ੍ਹਾਂ ▁ਦੀ ▁ਇੱਥੇ ▁ਕੀ ▁ਗੱਲ ▁ਕਰ ਾਂ । ▁ਪਰ ▁ਜਾਣਦੇ ▁ਉਨ੍ਹਾਂ ▁ਨੂੰ ▁ਤੁਸੀਂ ▁ਵੀ ▁ਹੋ ▁ਤੇ ▁ਮੈਂ ▁ਵੀ । ▁ਦੇ ਸ ▁ਦੇ ▁ਵੱਖ - ਵੱਖ ▁ਹਿੱਸਿਆਂ ▁ਵਿੱਚ ▁ਉਸਦਾ ▁ਮਤਲਬ ▁ਬਦਲ ▁ਸਕਦਾ ▁ਹੈ ▁ਪਰ ▁ਉਸਦੀ ▁ਭਾਸ਼ਾ ▁ਨਹੀਂ ▁ਬਦਲਦੀ । ਗਾ ਲ਼ ਾਂ ▁ਦੀ ▁ਭਾਸ਼ਾ ▁ਵਿੱਚ ▁ਔਰਤ , ▁ਉਸਦੇ ▁ਸਰੀਰ ▁ਜਾਂ ▁ਉਸਦੇ ▁ਰਿਸ਼ਤੇ ▁ਦਾ ▁ਹੀ ▁ਇਸਤੇਮਾਲ ▁ਹੁੰਦਾ ▁ਹੈ । ▁ਅਕਸਰ ▁ਹਿੰਸਾ ▁ਵਿੱਚ ▁ਲਪੇਟ ▁ਕੇ ▁ਅਤੇ ▁' ਸੈਕਸ ਼ ੁਅਲ ' ▁ਤੰ ਜ ▁ਦੇ ▁ਨਾਲ । ਇਹ ▁ਗਾਲ ਼ ਾਂ ▁ਐਨ ੀਆਂ ▁ਆਮ ▁ਵਰਤੀਆਂ ▁ਜਾਂਦੀਆਂ ▁ਹਨ ▁ਕਿ ▁ਮਰਦ ▁ਅਤੇ ▁ਔਰਤ ▁ਦੋਵਾਂ ▁ਦੀ ▁ਭਾਸ਼ਾ ▁ਦਾ ▁ਹਿੱਸਾ ▁ਬਣ ▁ਜਾਂਦੀਆਂ ▁ਹਨ । ▁# <unk> ▁h er c ho ice : ▁' ਮੈਂ ▁ਇੱਕ ▁ਕੁੜੀ ▁ਨਾਲ ▁ਰਹਿਣ ▁ਦਾ ▁ਫ਼ੈਸਲਾ ▁ਕਿਉਂ ▁ਕੀਤਾ ? ' ▁# <unk> ▁h er c ho ice : ▁' ਜਦੋਂ ▁ਮੈਨੂੰ ▁ਪਤਾ ▁ਲੱਗਿਆ ▁ਮੇਰਾ ▁ਪਤੀ ▁ਨਾ - ਮਰਦ ▁ਹੈ ' ਪਰ ▁ਗਾਲ ਼ ▁ਵੀ ▁ਇੱਕ ▁ਤਰੀਕੇ ▁ਨਾਲ ▁ਔਰਤਾਂ ▁ਨੂੰ ▁ਮਰਦਾਂ ▁ਦੇ ▁ਸਾਹਮਣੇ ▁ਦੂਜਾ ▁ਦਰਜਾ ▁ਦਿੰਦੀ ▁ਹੈ ▁ਅਤੇ ▁ਕਈ ▁ਔਰਤਾਂ ▁ਨੂੰ ▁ਇਹ ▁ਰੁਝਾਨ ▁ਬਹੁਤ ▁ਪਰੇਸ਼ਾਨ ▁ਕਰਦਾ ▁ਹੈ । ▁ਸ਼ਾਇਦ ▁ਇਸੇ ▁ਲਈ ▁ਜਦੋਂ ▁ਅਸੀਂ ▁ਔਰਤਾਂ ▁ਦੀ ▁' ਮਰ ਜ਼ੀ ' ▁ਅਤੇ ▁ਅਜ਼ਾਦ ▁ਖਿਆਲ ▁ਹੋਣ ▁' ਤੇ ▁ਵਿਸ਼ੇਸ਼ ▁ਸੀਰੀਜ਼ ▁ਸ਼ੁਰੂ ▁ਕੀਤੀ ▁ਤਾਂ ▁ਔਰਤਾਂ ▁ਦੇ ▁ਮਨ ▁ਵਿੱਚ ▁ਦੱਬ ੀਆਂ ▁ਕਈ ▁ਗੱਲਾਂ ▁ਸਾਹਮਣੇ ▁ਆਈਆਂ । ' ਔਰਤ ਾਂ ▁ਦੇ ▁ਕੋਲ ▁ਵੀ ▁ਦਿਲ ▁ਅਤੇ ▁ਦਿਮਾਗ ▁ਹੁੰਦਾ ▁ਹੈ ' ਆਪਣੀ ▁ਮਰਜ਼ੀ ▁ਨਾਲ ▁ਆਪਣੀ ▁ਜ਼ਿੰਦਗੀ ▁ਅਤੇ ▁ਰਿਸ਼ਤੇ ▁ਨਿਭਾਉਂਦੀ ਆਂ ▁ਔਰਤਾਂ ▁ਦੀਆਂ ▁ਕਹਾਣੀਆਂ ▁ਦੀ ▁ਸੀਰੀਜ਼ ▁# <unk> ▁h er cho ice , ▁' ਤੇ ▁ਇੱਕ ▁ਪਾਠਕ ▁ਸੀਮਾ ▁ਰਾਏ ▁ਨੇ ▁ਸਾਡੇ ▁ਫ਼ੇਸਬੁੱਕ ▁ਪੇਜ ▁' ਤੇ ▁ਔਰਤਾਂ ▁ਨਾਲ ▁ਜੁੜੀਆਂ ▁ਗਾਲ ਼ਾ ▁ਦੀ ▁ਟਿੱਪਣੀ ▁ਕੀਤੀ । ਨਾਲ ▁ਹੀ ▁ਉਨ੍ਹਾਂ ▁ਨੇ ▁ਲਿਖਿਆ ▁ਕਿ ' ' ਔਰਤ ਾਂ ▁ਹਰ ▁ਮੁੱਦੇ ▁' ਤੇ ▁ਆਪਣਾ ▁ਪੱਖ ▁ਰੱਖ ▁ਸਕਦੀਆਂ ▁ਹਨ , ▁ਉਨ੍ਹਾਂ ▁ਦੇ ▁ਕੋਲ ▁ਵੀ ▁ਦਿਲ ▁ਅਤੇ ▁ਦਿਮਾਗ ▁ਹੁੰਦਾ ▁ਹੈ ▁ਪਰ ▁ਉਨ੍ਹਾਂ ▁ਤੋਂ ▁ਉਮੀਦ ▁ਕੀਤੀ ▁ਜਾਂਦੀ ▁ਹੈ ▁ਕਿ ▁ਉਹ ▁ਨਾ ▁ਬੋਲਣ । ' ' ਬਲਾ ਗ : ▁‘ ਲ ਵ ▁ਜੇ ਹਾਦ ’, ▁ਮੁਹੱਬਤ ▁ਅਤੇ ▁‘ ਸਪੈਸ਼ਲ ▁ਮੈਰਿਜ ▁ਐਕਟ ’ ▁ਸੀਮਾ ▁ਰਾਏ ▁ਦਾ ▁ਇਸ਼ਾਰਾ ▁ਖ਼ਾਸ ▁ਤੌਰ ▁' ਤੇ ▁ਸਾਡੀ ▁ਪਹਿਲੀ ▁ਕਹਾਣੀ ▁ਵੱਲ ▁ਸੀ ▁ਜਿੱਥੇ ▁ਇੱਕ ▁ਔਰਤ ▁ਖੁੱਲ੍ਹ ▁ਕੇ ▁ਆਪਣੀ ▁' ਸੈਕਸ ਼ ੁਅਲ ▁ਡਿ ਜ਼ਾਇਰ ' ਦੇ ▁ਬਾਰੇ ▁ਦੱਸ ▁ਰਹੀ ▁ਹੈ । ਹੁਣ ▁ਇਹ ▁ਤਾਂ ▁ਤੁਸੀਂ ▁ਵੀ ▁ਜਾਣਦੇ ▁ਹੋ ▁ਕਿ ▁ਅਜਿਹੇ ▁ਮੁੱਦੇ ▁' ਤੇ ▁ਔਰਤ ▁ਦੀ ▁ਸੋਚ ▁ਨੂੰ ▁ਤਰਜ਼ ੀਹ ▁ਨਹੀਂ ▁ਦਿੱਤੀ ▁ਜਾਂਦੀ । ▁ਅਹਿਮੀਅਤ ▁ਤਾਂ ▁ਛੱਡੋ , ▁ਆਮ ▁ਧਾਰਨਾ ▁ਇਹ ▁ਹੈ ▁ਕਿ ▁ਅਜਿਹੀ ਆਂ ▁ਇੱਛਾਵਾਂ ▁ਸਿਰਫ਼ ▁ਮਰਦਾਂ ▁ਵਿੱਚ ▁ਹੀ ▁ਹੁੰਦੀਆਂ ▁ਹਨ । ਅਸਲ ੀ ▁ਮਹਿਲਾਵਾਂ ▁ਦੀਆਂ ▁ਸੱਚ ੀਆਂ ▁ਕਹਾਣੀਆਂ ਜ਼ਾ ਹਿਰ ▁ਹੈ ▁ਬਹੁਤ ▁ਸਾਰੀਆਂ ▁ਮਹਿਲਾਵਾਂ ▁ਨੂੰ ▁ਉਸ ▁ਔਰਤ ▁ਦੀ ▁ਕਹਾਣੀ ▁ਵਿੱਚ ▁ਆਪਣਾ ▁ਅਕਸ ▁ਨਜ਼ਰ ▁ਆਇਆ । ▁ਇੱਕ ▁ਪਾਸੇ ▁ਪਾਠਕ , ▁ਵੀ ਰਾਸ ਨੀ ▁ਬਘੇਲ ▁ਨੇ ▁ਲਿਖਿਆ ▁ਕਿ ▁'' ਇਹ ▁ਜਿਸ ▁ਵੀ ▁ਔਰਤ ▁ਦੀ ▁ਕਹਾਣੀ ▁ਹੈ , ▁ਉਹ ▁ਸਮਾਜ ▁ਦੀ ▁ਇੱਕ ▁ਵੱਖਰੀ ▁ਤਸਵੀਰ ▁ਦਿਖਾਉਂਦੀ ▁ਹੈ । ▁ਵੀਰ ਸਾਨੀ ▁ਅੱਗੇ ▁ਲਿਖਦੀ ▁ਹੈ , ' ' ਇਹ ▁ਸਾਬਤ ▁ਹੁੰਦਾ ▁ਹੈ ▁ਕਿ ▁ਘਾਟ ▁ਹਮੇਸ਼ਾ ▁ਔਰਤਾਂ ▁ਵਿੱਚ ▁ਹੀ ▁ਨਹੀਂ ▁ਹੁੰਦੀ , ▁ਕਮੀ ▁ਮਰਦਾਂ ▁ਵਿੱਚ ▁ਵੀ ▁ਹੁੰਦੀ ▁ਹੈ ▁ਅਤੇ ▁ਸਮਾਜ ▁ਨੂੰ ▁ਆਪਣੇ ▁ਗ਼ਲਤ ▁ਨਜ਼ਰੀਏ ▁ਦਾ ▁ਚਸ਼ਮਾ ▁ਉਤਾਰਨ ▁ਦੀ ▁ਲੋੜ ▁ਹੈ । ' ' ਸਾਡੀ ▁ਕਹਾਣੀਆਂ ▁ਸੱਚ ੀਆਂ ▁ਹਨ ▁ਪਰ ▁ਔਰਤਾਂ ▁ਦੀ ▁ਪਛਾਣ ▁ਲੁਕਾ ਈ ▁ਗਈ ▁ਹੈ ▁ਕਿਉਂਕਿ ▁ਡਰ ▁ਹੈ ▁ਕਿ ▁ਉਨ੍ਹਾਂ ▁ਦੇ ▁ਜਾਣ ▁ਵਾਲੇ ▁ਅਤੇ ▁ਸਮਾਜ ▁ਵੱਲੋਂ ▁ਕਿ ਹੋ ▁ਜਿਹੀ ਆਂ ▁ਪ੍ਰਤੀਕਿਰਿਆਵ ਾਂ ▁ਆਉਣ ਗੀਆਂ । ਪਰ ▁ਇਨ੍ਹਾਂ ▁ਗੁਮ ਨਾਮ ▁ਕਹਾਣੀਆਂ ▁ਨੂੰ ▁ਪੜ੍ਹਨ ▁ਵਾਲੀਆਂ ▁ਔਰਤਾਂ ▁ਬੇਬਾਕ ੀ ▁ਨਾਲ ▁ਲਿਖ ▁ਰਹੀਆਂ ▁ਹਨ । ਪੁ ਨਮ ▁ਕੁਮਾਰੀ ▁ਗੁਪਤਾ ▁ਕਹਿੰਦੀ ▁ਹੈ , ' ' ਲੋਕ ▁ਕਿੰਨਾ ▁ਬਦਲਣ ਗੇ ▁ਇਹ ▁ਤਾਂ ▁ਪਤਾ ▁ਨਹੀਂ ▁ਪਰ ▁ਸ਼ਾਇਦ ▁ਔਰਤਾਂ ▁ਦੀ ▁ਖ਼ੁਦ ▁ਦੀ ▁ਭ ੜਾ ਸ ▁ਨਿਕਲ ▁ਜਾਵੇ । ' ' 30 ▁ਔਰਤਾਂ ▁ਨੂੰ <unk> ▁h <unk> <unk> ▁ਪੀੜਤ ▁ਬਣਾਉਣ ▁ਵਾਲੇ ▁ਨੂੰ ▁ਜੇਲ੍ਹ ▁ਇਹ ▁ਕਹਾਣੀਆਂ ▁ਦੁਖ ਼ ▁ਅਤੇ ▁ਸ਼ਿਕਾਇਤ ▁ਦੀਆਂ ▁ਨਹੀਂ ▁ਹਨ । ▁ਸਮਾਜਿਕ ▁ਦਬਾਅ , ▁ਪਰਿਵਾਰਕ ▁ਦਾਇਰੇ ▁ਅਤੇ ▁ਔਰਤ ▁ਹੋਣ ▁ਦੇ ▁ਨਾਤੇ ▁ਤੈਅ ▁ਭੂਮਿਕਾਵਾਂ ▁ਨੂੰ ▁ਤੋੜ ▁ਕੇ ▁ਆਪਣੇ ▁ਮਨ ▁ਨੂੰ ▁ਸੁਣਨ ▁ਦੀ ▁ਹੈ । ਇਸ ▁ਲਈ ▁ਇਸਨੂੰ ▁ਪੜ੍ਹ ▁ਕੇ ▁ਕਿਸੇ ▁ਦੀ ▁ਭ ੜਾ ਸ ▁ਨਿਕਲ ▁ਰਹੀ ▁ਹੈ ▁ , ▁ਤਾਂ ▁ਕਿਸੇ ▁ਨੂੰ ▁ਵੱਖਰੇ ▁ਤਰੀਕੇ ▁ਨਾਲ ▁ਜੀ ਣ ▁ਦਾ ▁ਹੌਸਲਾ ▁ਮਿਲ ▁ਰਿਹਾ ▁ਹੈ । ਔਰਤ ਾਂ ▁ਦੇ ▁ਦਿਲ - ਦਿਮਾਗ ▁ਨੂੰ ▁ਜਾਣਨ ▁ਦਾ ▁ਮੌਕਾ ਬਿਨ ਾਂ ▁ਕਿਸੇ ▁ਸਰੀਰਕ ▁ਰਿਸ਼ਤੇ ▁ਵਿੱਚ ▁ਬੱਝੇ , ▁2 ▁ਔਰਤਾਂ ▁ਦੇ ▁ਇਕੱਠ ੇ ▁ਰਹਿਣ ▁ਦੀ ▁ਸਾਡੀ ▁ਦੂਜੀ ▁ਕਹਾਣੀ ▁' ਤੇ ▁ਇੱਕ ▁ਪਾਠਕ ▁ਮੀਨਾਕਸ਼ੀ ▁ਠਾਕੁਰ ▁ਲਿਖਦੀ ▁ਹੈ , ' ' ਆਪਣੇ ▁ਤਰੀਕੇ ▁ਨਾਲ ▁ਜੀ ਣ ▁ਦੀ ▁ਹਿੰਮਤ ▁ ਸਾਰਿਆਂ ▁' ਚ ▁ਨਹੀਂ ▁ਹੁੰਦੀ , ▁ਜੋ ▁ਇਨ੍ਹਾਂ ▁ਦੋਵਾਂ ▁ਨੇ ▁ਕਰ ▁ਕੇ ▁ਦਿਖਾਇਆ । ' ' ▁ਅਤਿ ਆ ▁ਰਹਿਮਾਨ ▁ਨੇ ▁ਲਿਖਿਆ ' ' ਜਦੋਂ ▁ਤੁਹਾਨੂੰ ▁ਸੱਚ ▁ਵਿੱਚ ▁ਪਤਾ ▁ਹੁੰਦਾ ▁ਹੈ ▁ਕਿ ▁ਤੁਸੀਂ ▁ਜੋ ▁ਕਰ ▁ਰਹੇ ▁ਹੋ ▁ਉਸਦਾ ▁ਕਾਰਨ ▁ਕੀ ▁ਹੈ ▁ਅਤੇ ▁ਤੁਸੀਂ ▁ਸੱਚਮੁ ਚ ▁ਚਾਹੁੰਦੇ ▁ਕੀ ▁ਹੋ , ▁ਉਦੋਂ ▁ਅਜਿਹੀ ਆਂ ▁ਕਹਾਣੀਆਂ ▁ਬਣਦੀਆਂ ▁ਹਨ । ' ' ਸਾਡੇ ▁ਸਮਾਜ ...
# Path: /home/gaurav/Downloads/ClassificationModel;
#
# Valid: LabelList
# y: LMLabel (157 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: /home/gaurav/Downloads/ClassificationModel
# x: LMTextList (157 items)
# [Text ▁x x bo s ▁ਪੁਲਾੜ ▁' ਚੋਂ ▁7 500 ▁ਟਨ ▁ਕੂੜ ਾ ▁ਇਸ ▁ਤਰ੍ਹਾਂ ▁ਸਾਫ਼ ▁ਕਰੇਗਾ ▁ਇਹ ▁ਜਾਲ ▁1 ▁ਅਕਤੂਬਰ ▁2018 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/ ▁ punjabi ▁/ ▁in tern ational - 45 69 95 49 ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਬਾਰੇ ▁ਹੋਰ ▁ਪੜ੍ਹ ੋ ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਵਾਲੇ ▁ਪੈਨਲ ▁ਨੂੰ ▁ਬੰਦ ▁ਕਰੋ <unk> ▁i m age ▁co py right ▁ <unk> <unk> <unk> ▁p ho to ▁library ▁ਫੋਟੋ ▁ਕੈਪ ਸ਼ਨ ▁ਇਹ ▁ਜਾਲ ▁ਧਰਤੀ ▁ਤੋਂ ▁300 ▁ਕਿੱਲੋਮੀਟਰ ▁ਤੋਂ ▁ਵੱਧ ▁ਉੱਚਾਈ ▁' ਤੇ ▁ਲਗਾਇਆ ▁ਗਿਆ ▁ਹੈ ▁ਬ੍ਰਿਟੇਨ ▁ਦੀ ▁ਇੱਕ ▁ਸੈਟੇਲਾਈਟ ▁ਨੇ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁( ਓਰ ਬਿਟ ) ▁ਵਿੱਚ ▁ਇੱਕ ▁ਜਾਲ ▁ਲਗਾਇਆ ▁ਹੈ ▁ਜਿਹੜਾ ▁ਸਪੇਸ ▁ਦੇ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਇਕੱਠਾ ▁ਕਰੇਗਾ । ਪ੍ਰਯੋਗ ▁ਦੇ ▁ਤੌਰ ▁' ਤੇ ▁ਸ਼ੁਰੂ ▁ਕੀਤੀ ▁ਇਹ ▁ਕੋਸ਼ਿਸ਼ ▁ਉਨ੍ਹਾਂ ▁ਯੋਜਨਾਵਾਂ ▁ਦਾ ▁ਹਿੱਸਾ ▁ਹੈ , ▁ਜਿਸ ਦੇ ▁ਜ਼ਰੀਏ ▁ਅੰਤਰਿਕਸ਼ ▁ਨੂੰ ▁ਕੂੜ ਾ ▁ਮੁਕਤ ▁ਬਣਾਉਣ ▁ਦੀ ▁ਯੋਜਨਾ ▁ਹੈ । ▁ਇਹ ▁ਜਾਲ ▁ਧਰਤੀ ▁ਤੋਂ ▁300 ▁ਕਿੱਲੋਮੀਟਰ ▁ਤੋਂ ▁ਵੱਧ ▁ਉੱਚਾਈ ▁' ਤੇ ▁ਲਗਾਇਆ ▁ਗਿਆ ▁ਹੈ । ▁ਇਹ ▁ਵੀ ▁ਪੜ੍ਹ ੋ : 9 ▁ਤੱਥ ▁ਜਿਨ੍ਹਾਂ ▁ਕਾਰਨ ▁ਵਧਿਆ ▁ਸੈਕਸ ▁ਟੁ ਆ ਏ ਜ਼ ▁ਦਾ ▁ਵਪਾਰ ▁ਦੁਨੀਆਂ ▁ਦੀਆਂ ▁ਪੰਜ ▁ ਖ਼ਤਰਨਾਕ ▁ਜਾਸੂਸ ▁ਔਰਤਾਂ ▁ਜਦੋਂ ▁ਇੱਕ ▁ਇੰਜੀਨੀਅਰ ▁ਮਜਬੂਰ ੀ ▁ਕਾਰਨ ▁ਔਰਤਾਂ ▁ਲਈ ▁‘ ਮਾਲ ’ ▁ਬਣਿਆ ਇਹ ▁ਸਮਝਿਆ ▁ਜਾਂਦਾ ▁ਹੈ ▁ਕਿ ▁ਕਰੀਬ ▁ਸਾਢ ੇ ▁ਸੱਤ ▁ਹਜ਼ਾਰ ▁ਟਨ ▁ਕੂੜ ਾ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਤੈਰ ▁ਰਿਹਾ ▁ਹੈ , ▁ਜਿਹੜਾ ▁ਉਨ੍ਹਾਂ ▁ਸੈਟ ਲਾਈਟ ਾਂ ▁ਲਈ ▁ਖ਼ਤਰਾ ▁ਹੈ , ▁ਜਿਨ੍ਹਾਂ ▁ਨੂੰ ▁ਕਿਸੇ ▁ਖਾਸ ▁ਮਕਸਦ ▁ਨਾਲ ▁ਲਾਂਚ ▁ਕੀਤਾ ▁ਗਿਆ ▁ਹੈ । ▁ਜਾਲ ▁ਦੇ ▁ਪ੍ਰਯੋਗ ▁ਦਾ ▁ਸੈਟੇਲਾਈਟ ▁ਦੇ ▁ਜ਼ਰੀਏ ▁ਵੀਡੀਓ ▁ਵੀ ▁ਬਣਾਇਆ ▁ਗਿਆ ▁ਹੈ ▁ਜਿਸ ▁ਵਿੱਚ ▁ਇੱਕ ▁ਜੁੱਤੀ ▁ਦੇ ▁ਡੱਬੇ ▁ਦੇ ▁ਆਕਾਰ ▁ਦੇ ▁ਪੁਲਾੜ ▁ਦੇ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਇਕੱਠਾ ▁ਕਰਦਾ ▁ਹੋਇਆ ▁ਦਿਖ ▁ਰਿਹਾ ▁ਹੈ । <unk> ▁i m age ▁co py right ▁ <unk> <unk> c ▁ਫੋਟੋ ▁ਕੈਪ ਸ਼ਨ ▁ਇ ੰਝ ▁ਕੀਤਾ ▁ਜਾਵੇਗਾ ▁ਜਾਲ ▁ਦਾ ▁ਪ੍ਰਯੋਗ ▁ਸੂਰ ੇ ▁ਸਪੇਸ ▁ਸੈਂਟਰ ▁ਦੇ ▁ਡਾਇਰੈਕਟਰ ▁ਪ੍ਰੋਫੈਸਰ ▁ਗੁ ਗ ਲਾਈ ਮ ਲੋ ▁ਅਗਲੀ ਤੀ ▁ਕਹਿੰਦੇ ▁ਹਨ , ▁" ਜਿਸ ▁ਤਰ੍ਹਾਂ ▁ਦੀਆਂ ▁ਸਾਡੀ ਆਂ ▁ਉਮੀਦ ਾਂ ▁ਸੀ , ▁ਇਹ ▁ਉਸ ▁ਤਰ੍ਹਾਂ ▁ਦਾ ▁ਹੀ ▁ਕੰਮ ▁ਕਰ ▁ਰਿਹਾ ▁ਹੈ ।" " ਤੁਸੀਂ ▁ਸਾਫ਼ ▁ਤੌਰ ▁' ਤੇ ▁ਦੇਖ ▁ਸਕਦੇ ▁ਹੋ ▁ਕਿ ▁ਇਹ ▁ਕਿਵੇਂ ▁ਜਾਲ ▁ਵਿੱਚ ▁ਫਸ ਿਆ । ▁ਅਸੀਂ ▁ਇਸ ▁ਪ੍ਰਯੋਗ ▁ਨਾਲ ▁ਖੁਸ਼ ▁ਹਾਂ ।" ਅੱਗ ੇ ▁ਕੀ ▁ਹੋਵੇਗਾ ਇਹ ▁ਸਿਰਫ਼ ▁ਇੱਕ ▁ਪ੍ਰਯੋਗ ▁ਸੀ , ▁ਜਿਸ ▁ਵਿੱਚ ▁ਇੱਕ ▁ਜੁੱਤੀ ▁ਦੇ ▁ਡੱਬੇ ▁ਦੇ ▁ਆਕਾਰ ▁ਦੇ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਦੂਜੇ ▁ਸੈਟੇਲਾਈਟ ▁ਨਾਲ ▁ਧਰਤੀ ▁ਵੱਲ ▁ਡਿਗ ਾਇਆ ▁ਗਿਆ ▁ਸੀ , ▁ਜਿਸ ▁ਨੂੰ ▁ਬਾਅਦ ▁ਵਿੱਚ ▁ਜਾਲ ▁ਵਿੱਚ ▁ਫਸ ਾਇਆ ▁ਗਿਆ । ▁ਜੇਕਰ ▁ਅਸਲ ▁ਵਿੱਚ ▁ਅਜਿਹਾ ▁ਹੋ ▁ਸਕੇਗਾ ▁ਤਾਂ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਫਸ ਾਉਣ ▁ਤੋਂ ▁ਬਾਅਦ ▁ਸੈਟੇਲਾਈਟ ▁ਦੀ ▁ਮਦਦ ▁ਨਾਲ ▁ਜਾਲ ▁ਇਸ ▁ਨੂੰ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਤੋਂ ▁ਬਾਹਰ ▁ਕਰ ▁ਦੇਵੇਗਾ । <unk> ▁i m age ▁co py right <unk> ▁a i r b <unk> us ▁ਫੋਟੋ ▁ਕੈਪ ਸ਼ਨ ▁ਕੁਝ ▁ਇਸ ▁ਤਰ੍ਹਾਂ ▁ਤਿਆਰ ▁ਕੀਤਾ ▁ਗਿਆ ▁ਹੈ ▁ਸਪੇਸ ▁ਜਾਲ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਤੈਰ ▁ਰਹੇ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਹਟਾਉਣ ▁ਦੀ ▁ਗੱਲ ▁ਹੁੰਦੀ ▁ਰਹੀ ▁ਹੈ । ▁ਕਈ ▁ਪ੍ਰਯੋਗ ▁ਵੀ ▁ਇਸ ▁' ਤੇ ▁ਚੱਲ ▁ਰਹੇ ▁ਹਨ ▁ਪਰ ▁ਦਾਅਵਾ ▁ਕੀਤਾ ▁ਜਾ ▁ਰਿਹਾ ▁ਹੈ ▁ਕਿ ▁ਇਹ ▁ਪਹਿਲੀ ▁ਵਾਰ ▁ਹੈ ▁ਕਿ ▁ਜਦੋਂ ▁ਇਸ ▁ਤਰ੍ਹਾਂ ▁ਦਾ ▁ਸਫ਼ਲ ▁ਪ੍ਰਯੋਗ ▁ਕੀਤਾ ▁ਗਿਆ ▁ਹੋਵੇ । ▁ਜਲਦੀ ▁ਹੀ ▁ਹੁਣ ▁ਇਸ ▁ਕੋਸ਼ਿਸ਼ ▁ਦੇ ▁ਤਹਿਤ ▁ਦੂਜੇ ▁ਪੜ੍ਹਾ ਅ ▁ਦਾ ▁ਪ੍ਰਯੋਗ ▁ਕੀਤਾ ▁ਜਾਵੇਗਾ , ▁ਜਿਸ ▁ਵਿੱਚ ▁ਇੱਕ ▁ਕੈਮਰਾ ▁ਲਗਾਇਆ ▁ਜਾਵੇਗਾ ▁ਜਿਹੜਾ ▁ਸਪੇਸ ▁ਦੇ ▁ਅਸਲ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਕੈਦ ▁ਕਰ ▁ਸਕੇ ▁ਤਾਂ ▁ਕਿ ▁ਉਨ੍ਹਾਂ ▁ਨੂੰ ▁ਹਟਾਉਣ ਾ ▁ਸੌਖਾ ▁ਹੋਵੇ । ▁ਇਹ ▁ਉਮੀਦ ▁ਕੀਤੀ ▁ਜਾ ▁ਰਹੀ ▁ਹੈ ▁ਕਿ ▁ਨਵੇਂ ▁ਸਾਲ ▁ਦੀ ▁ਸ਼ੁਰੂਆਤ ▁ਤੱਕ ▁ਇਸ ▁ਤੋਂ ▁ਹੋਰ ▁ਬਿ ਹਤ ਕ ▁ਤਰੀਕੇ ▁ਨਾਲ ▁ਕੰਮ ▁ਲਿਆ ▁ਜਾ ▁ਸਕੇਗਾ । ▁ਸਪੇਸ ▁ਕੂੜੇ ▁ਤੋਂ ▁ਕਿੰਨਾ ▁ਖਤਰਾ ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਲੱਖਾਂ ▁ਟੁ ੱਕੜ ੇ ▁ਤੈਰ ▁ਰਹੇ ▁ਹਨ । ▁ਇਹ ▁ਟੁ ੱਕੜ ੇ ▁ਪੁਰਾਣੇ ▁ਅਤੇ ▁ਸੇਵਾ ▁ਤੋਂ ▁ਬਾਹਰ ▁ਹੋ ▁ਚੁੱਕੇ ▁ਸੈਟ ਲਾਈਟ ਾਂ ▁ਦੇ ▁ਅੰਸ਼ ▁ਅਤੇ ▁ਅੰਤਰਿਕਸ਼ ▁ਯਾਤਰੀਆਂ ▁ਵੱਲੋਂ ▁ਗ਼ਲਤੀ ▁ਨਾਲ ▁ਰਹਿ ▁ਗਏ ▁ਕੁਝ ▁ਉਪਕਰਣ ▁ਹਨ । <unk> ▁i m age ▁co py right ▁ <unk> <unk> ▁/ ▁ <unk> na n o <unk> ra c k s ▁ਫੋਟੋ ▁ਕੈਪ ਸ਼ਨ ▁ਆਉਣ ▁ਵਾਲੇ ▁ਸਮੇਂ ▁ਵਿੱਚ ▁ਲੋੜਾਂ ▁ਦੇ ▁ਹਿਸਾਬ ▁ਨਾਲ ▁ਕਈ ▁ਸੈਟ ੇ ਲਾਈ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਲਾਂਚ ▁ਕੀਤੇ ▁ਜਾਣਗੇ ▁ਡਰ ▁ਇਹ ▁ਹੈ ▁ਕਿ ▁ਜੇ ▁ਇਨ੍ਹਾਂ ▁ਕੂੜ ਿਆਂ ▁ਨੂੰ ▁ਹਟਾਇਆ ▁ਨਹੀਂ ▁ਗਿਆ ▁ਤਾਂ ▁ਇਹ ▁ਕੰਮ ▁ਵਿੱਚ ▁ਆ ▁ਰਹੀਆਂ ▁ਸੈਟ ਲਾਈਟ ਾਂ ▁ਨੂੰ ▁ਨਸ਼ਟ ▁ਕਰ ▁ਦੇਵੇਗਾ । ਇਸ ▁ਪ੍ਰਾਜੈਕਟ ▁' ਤੇ ▁ਕੰਮ ▁ਕਰ ▁ਰਹੇ ▁ਇੰਜੀਨੀਅਰ ▁ਅਲ ਸ ਟੇਅਰ ▁ਵੇ ਮੈਨ ▁ਕਹਿੰਦੇ ▁ਹਨ , ▁" ਜੇਕਰ ▁ਇਹ ▁ਟੁ ੱਕੜ ੇ ▁ਆਪਸ ▁ਵਿੱਚ ▁ਟਕਰਾਉਂਦ ੇ ▁ਹਨ ▁ਤਾਂ ▁ਹੋਰ ▁ਕੂੜ ਾ ▁ਇਕੱਠਾ ▁ਹੋਵੇਗਾ । ▁ਜ਼ਿਆਦਾ ▁ਕੂੜ ਾ ▁ਬਣਨ ▁ਨਾਲ ▁ਟਕਰਾਉਣ ▁ਦਾ ▁ਖ ਦ ਸ਼ਾ ▁ਲਗਾਤਾਰ ▁ਵਧਦਾ ▁ਰਹੇਗਾ ▁ਅਤੇ ▁ਇੱਕ ▁ਦਿਨ ▁ਇਹ ▁ਵੱਡੀ ▁ਪ੍ਰੇਸ਼ਾਨ ੀ ▁ਖੜ੍ਹੀ ▁ਕਰ ▁ਸਕਦਾ ▁ਹੈ ।" ਇਹ ▁ਵੀ ▁ਪੜ੍ਹ ੋ : ਇੰਡੋ ਨੇਸ਼ੀਆ : ▁ਸੁਨਾਮੀ ▁ਦੀ ▁ਤਬਾਹੀ ▁' ਚ ▁83 2 ▁ਲੋਕਾਂ ▁ਦੀ ▁ਮੌਤ ਪਹਿਲ ੂ ▁ਖ਼ਾਨ ▁ਮੌ ਬ ▁ ਲਿੰ ਚਿੰਗ ▁ਕੇਸ ▁ਦੇ ▁ਗਵਾਹ ਾਂ ▁' ਤੇ ▁ਹਮਲਾ ' ਮੇਰੇ ▁ਵਿਆਹ ▁ਨਾ ▁ਕਰਨ ▁ਦੇ ▁ਫ਼ੈਸਲੇ ▁' ਤੇ ▁ਇੰਨ ੇ ▁ਸਵਾਲ ▁ਕਿਉਂ ' ਆ ਉਣ ▁ਵਾਲੇ ▁ਸਮੇਂ ▁ਵਿੱਚ ▁ਲੋੜਾਂ ▁ਦੇ ▁ਹਿਸਾਬ ▁ਨਾਲ ▁ਕਈ ▁ਸੈਟ ੇ ਲਾਈ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਲਾਂਚ ▁ਕੀਤੇ ▁ਜਾਣਗੇ । ▁ਜੇਕਰ ▁ਸਪੇਸ ▁ਕੂੜੇ ▁ਨਾਲ ▁ਨਿਪਟ ਾ ▁ ...
# Path: /home/gaurav/Downloads/ClassificationModel;
#
# Test: None, model=SequentialRNN(
#   (0): RNNCore(
#     (encoder): Embedding(30000, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(30000, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1150, batch_first=True)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1150, 1150, batch_first=True)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1150, 400, batch_first=True)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=30000, bias=True)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<fastai.layers.FlattenedLoss object at 0x7f9e294d8828>, metrics=[<function accuracy at 0x7f9e321f5268>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/home/gaurav/Downloads/ClassificationModel'), model_dir='models', callback_fns=[<class 'fastai.basic_train.Recorder'>], callbacks=[RNNTrainer
# learn: LanguageLearner(data=TextLMDataBunch;
#
# Train: LabelList
# y: LMLabel (627 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: /home/gaurav/Downloads/ClassificationModel
# x: LMTextList (627 items)
# [Text ▁x x bo s ▁ਬਲਾਗ - ▁# <unk> ▁h er c ho ice ▁ਹਰ ▁ਗਾਲ ਼ ▁ਔਰਤਾਂ ▁ਦੇ ▁ਨਾਂ ▁ਉੱਤੇ ▁ਹੀ ▁ਕੱਢੀ ▁ਕਿਉਂ ▁ਜਾਂਦੀ ▁ਹੈ ? ▁ਦਿ ਵਿਆ ▁ਆਰਿਆ ▁ਬੀਬੀਸੀ ▁ਪੱਤਰਕਾਰ ▁24 ▁ਜਨਵਰੀ ▁2018 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/ ▁ punjabi ▁/ ▁ india -4 27 93 90 9 ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਬਾਰੇ ▁ਹੋਰ ▁ਪੜ੍ਹ ੋ ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਵਾਲੇ ▁ਪੈਨਲ ▁ਨੂੰ ▁ਬੰਦ ▁ਕਰੋ ▁ਉਹ ▁ਗਾਲ ਼ਾ ▁ਐਨ ੀਆਂ ▁ਮਾੜੀ ਆਂ ▁ਮੰਨੀਆਂ ▁ਜਾਂਦੀਆਂ ▁ਹਨ ▁ਕਿ ▁ਉਨ੍ਹਾਂ ▁ਦੀ ▁ਇੱਥੇ ▁ਕੀ ▁ਗੱਲ ▁ਕਰ ਾਂ । ▁ਪਰ ▁ਜਾਣਦੇ ▁ਉਨ੍ਹਾਂ ▁ਨੂੰ ▁ਤੁਸੀਂ ▁ਵੀ ▁ਹੋ ▁ਤੇ ▁ਮੈਂ ▁ਵੀ । ▁ਦੇ ਸ ▁ਦੇ ▁ਵੱਖ - ਵੱਖ ▁ਹਿੱਸਿਆਂ ▁ਵਿੱਚ ▁ਉਸਦਾ ▁ਮਤਲਬ ▁ਬਦਲ ▁ਸਕਦਾ ▁ਹੈ ▁ਪਰ ▁ਉਸਦੀ ▁ਭਾਸ਼ਾ ▁ਨਹੀਂ ▁ਬਦਲਦੀ । ਗਾ ਲ਼ ਾਂ ▁ਦੀ ▁ਭਾਸ਼ਾ ▁ਵਿੱਚ ▁ਔਰਤ , ▁ਉਸਦੇ ▁ਸਰੀਰ ▁ਜਾਂ ▁ਉਸਦੇ ▁ਰਿਸ਼ਤੇ ▁ਦਾ ▁ਹੀ ▁ਇਸਤੇਮਾਲ ▁ਹੁੰਦਾ ▁ਹੈ । ▁ਅਕਸਰ ▁ਹਿੰਸਾ ▁ਵਿੱਚ ▁ਲਪੇਟ ▁ਕੇ ▁ਅਤੇ ▁' ਸੈਕਸ ਼ ੁਅਲ ' ▁ਤੰ ਜ ▁ਦੇ ▁ਨਾਲ । ਇਹ ▁ਗਾਲ ਼ ਾਂ ▁ਐਨ ੀਆਂ ▁ਆਮ ▁ਵਰਤੀਆਂ ▁ਜਾਂਦੀਆਂ ▁ਹਨ ▁ਕਿ ▁ਮਰਦ ▁ਅਤੇ ▁ਔਰਤ ▁ਦੋਵਾਂ ▁ਦੀ ▁ਭਾਸ਼ਾ ▁ਦਾ ▁ਹਿੱਸਾ ▁ਬਣ ▁ਜਾਂਦੀਆਂ ▁ਹਨ । ▁# <unk> ▁h er c ho ice : ▁' ਮੈਂ ▁ਇੱਕ ▁ਕੁੜੀ ▁ਨਾਲ ▁ਰਹਿਣ ▁ਦਾ ▁ਫ਼ੈਸਲਾ ▁ਕਿਉਂ ▁ਕੀਤਾ ? ' ▁# <unk> ▁h er c ho ice : ▁' ਜਦੋਂ ▁ਮੈਨੂੰ ▁ਪਤਾ ▁ਲੱਗਿਆ ▁ਮੇਰਾ ▁ਪਤੀ ▁ਨਾ - ਮਰਦ ▁ਹੈ ' ਪਰ ▁ਗਾਲ ਼ ▁ਵੀ ▁ਇੱਕ ▁ਤਰੀਕੇ ▁ਨਾਲ ▁ਔਰਤਾਂ ▁ਨੂੰ ▁ਮਰਦਾਂ ▁ਦੇ ▁ਸਾਹਮਣੇ ▁ਦੂਜਾ ▁ਦਰਜਾ ▁ਦਿੰਦੀ ▁ਹੈ ▁ਅਤੇ ▁ਕਈ ▁ਔਰਤਾਂ ▁ਨੂੰ ▁ਇਹ ▁ਰੁਝਾਨ ▁ਬਹੁਤ ▁ਪਰੇਸ਼ਾਨ ▁ਕਰਦਾ ▁ਹੈ । ▁ਸ਼ਾਇਦ ▁ਇਸੇ ▁ਲਈ ▁ਜਦੋਂ ▁ਅਸੀਂ ▁ਔਰਤਾਂ ▁ਦੀ ▁' ਮਰ ਜ਼ੀ ' ▁ਅਤੇ ▁ਅਜ਼ਾਦ ▁ਖਿਆਲ ▁ਹੋਣ ▁' ਤੇ ▁ਵਿਸ਼ੇਸ਼ ▁ਸੀਰੀਜ਼ ▁ਸ਼ੁਰੂ ▁ਕੀਤੀ ▁ਤਾਂ ▁ਔਰਤਾਂ ▁ਦੇ ▁ਮਨ ▁ਵਿੱਚ ▁ਦੱਬ ੀਆਂ ▁ਕਈ ▁ਗੱਲਾਂ ▁ਸਾਹਮਣੇ ▁ਆਈਆਂ । ' ਔਰਤ ਾਂ ▁ਦੇ ▁ਕੋਲ ▁ਵੀ ▁ਦਿਲ ▁ਅਤੇ ▁ਦਿਮਾਗ ▁ਹੁੰਦਾ ▁ਹੈ ' ਆਪਣੀ ▁ਮਰਜ਼ੀ ▁ਨਾਲ ▁ਆਪਣੀ ▁ਜ਼ਿੰਦਗੀ ▁ਅਤੇ ▁ਰਿਸ਼ਤੇ ▁ਨਿਭਾਉਂਦੀ ਆਂ ▁ਔਰਤਾਂ ▁ਦੀਆਂ ▁ਕਹਾਣੀਆਂ ▁ਦੀ ▁ਸੀਰੀਜ਼ ▁# <unk> ▁h er cho ice , ▁' ਤੇ ▁ਇੱਕ ▁ਪਾਠਕ ▁ਸੀਮਾ ▁ਰਾਏ ▁ਨੇ ▁ਸਾਡੇ ▁ਫ਼ੇਸਬੁੱਕ ▁ਪੇਜ ▁' ਤੇ ▁ਔਰਤਾਂ ▁ਨਾਲ ▁ਜੁੜੀਆਂ ▁ਗਾਲ ਼ਾ ▁ਦੀ ▁ਟਿੱਪਣੀ ▁ਕੀਤੀ । ਨਾਲ ▁ਹੀ ▁ਉਨ੍ਹਾਂ ▁ਨੇ ▁ਲਿਖਿਆ ▁ਕਿ ' ' ਔਰਤ ਾਂ ▁ਹਰ ▁ਮੁੱਦੇ ▁' ਤੇ ▁ਆਪਣਾ ▁ਪੱਖ ▁ਰੱਖ ▁ਸਕਦੀਆਂ ▁ਹਨ , ▁ਉਨ੍ਹਾਂ ▁ਦੇ ▁ਕੋਲ ▁ਵੀ ▁ਦਿਲ ▁ਅਤੇ ▁ਦਿਮਾਗ ▁ਹੁੰਦਾ ▁ਹੈ ▁ਪਰ ▁ਉਨ੍ਹਾਂ ▁ਤੋਂ ▁ਉਮੀਦ ▁ਕੀਤੀ ▁ਜਾਂਦੀ ▁ਹੈ ▁ਕਿ ▁ਉਹ ▁ਨਾ ▁ਬੋਲਣ । ' ' ਬਲਾ ਗ : ▁‘ ਲ ਵ ▁ਜੇ ਹਾਦ ’, ▁ਮੁਹੱਬਤ ▁ਅਤੇ ▁‘ ਸਪੈਸ਼ਲ ▁ਮੈਰਿਜ ▁ਐਕਟ ’ ▁ਸੀਮਾ ▁ਰਾਏ ▁ਦਾ ▁ਇਸ਼ਾਰਾ ▁ਖ਼ਾਸ ▁ਤੌਰ ▁' ਤੇ ▁ਸਾਡੀ ▁ਪਹਿਲੀ ▁ਕਹਾਣੀ ▁ਵੱਲ ▁ਸੀ ▁ਜਿੱਥੇ ▁ਇੱਕ ▁ਔਰਤ ▁ਖੁੱਲ੍ਹ ▁ਕੇ ▁ਆਪਣੀ ▁' ਸੈਕਸ ਼ ੁਅਲ ▁ਡਿ ਜ਼ਾਇਰ ' ਦੇ ▁ਬਾਰੇ ▁ਦੱਸ ▁ਰਹੀ ▁ਹੈ । ਹੁਣ ▁ਇਹ ▁ਤਾਂ ▁ਤੁਸੀਂ ▁ਵੀ ▁ਜਾਣਦੇ ▁ਹੋ ▁ਕਿ ▁ਅਜਿਹੇ ▁ਮੁੱਦੇ ▁' ਤੇ ▁ਔਰਤ ▁ਦੀ ▁ਸੋਚ ▁ਨੂੰ ▁ਤਰਜ਼ ੀਹ ▁ਨਹੀਂ ▁ਦਿੱਤੀ ▁ਜਾਂਦੀ । ▁ਅਹਿਮੀਅਤ ▁ਤਾਂ ▁ਛੱਡੋ , ▁ਆਮ ▁ਧਾਰਨਾ ▁ਇਹ ▁ਹੈ ▁ਕਿ ▁ਅਜਿਹੀ ਆਂ ▁ਇੱਛਾਵਾਂ ▁ਸਿਰਫ਼ ▁ਮਰਦਾਂ ▁ਵਿੱਚ ▁ਹੀ ▁ਹੁੰਦੀਆਂ ▁ਹਨ । ਅਸਲ ੀ ▁ਮਹਿਲਾਵਾਂ ▁ਦੀਆਂ ▁ਸੱਚ ੀਆਂ ▁ਕਹਾਣੀਆਂ ਜ਼ਾ ਹਿਰ ▁ਹੈ ▁ਬਹੁਤ ▁ਸਾਰੀਆਂ ▁ਮਹਿਲਾਵਾਂ ▁ਨੂੰ ▁ਉਸ ▁ਔਰਤ ▁ਦੀ ▁ਕਹਾਣੀ ▁ਵਿੱਚ ▁ਆਪਣਾ ▁ਅਕਸ ▁ਨਜ਼ਰ ▁ਆਇਆ । ▁ਇੱਕ ▁ਪਾਸੇ ▁ਪਾਠਕ , ▁ਵੀ ਰਾਸ ਨੀ ▁ਬਘੇਲ ▁ਨੇ ▁ਲਿਖਿਆ ▁ਕਿ ▁'' ਇਹ ▁ਜਿਸ ▁ਵੀ ▁ਔਰਤ ▁ਦੀ ▁ਕਹਾਣੀ ▁ਹੈ , ▁ਉਹ ▁ਸਮਾਜ ▁ਦੀ ▁ਇੱਕ ▁ਵੱਖਰੀ ▁ਤਸਵੀਰ ▁ਦਿਖਾਉਂਦੀ ▁ਹੈ । ▁ਵੀਰ ਸਾਨੀ ▁ਅੱਗੇ ▁ਲਿਖਦੀ ▁ਹੈ , ' ' ਇਹ ▁ਸਾਬਤ ▁ਹੁੰਦਾ ▁ਹੈ ▁ਕਿ ▁ਘਾਟ ▁ਹਮੇਸ਼ਾ ▁ਔਰਤਾਂ ▁ਵਿੱਚ ▁ਹੀ ▁ਨਹੀਂ ▁ਹੁੰਦੀ , ▁ਕਮੀ ▁ਮਰਦਾਂ ▁ਵਿੱਚ ▁ਵੀ ▁ਹੁੰਦੀ ▁ਹੈ ▁ਅਤੇ ▁ਸਮਾਜ ▁ਨੂੰ ▁ਆਪਣੇ ▁ਗ਼ਲਤ ▁ਨਜ਼ਰੀਏ ▁ਦਾ ▁ਚਸ਼ਮਾ ▁ਉਤਾਰਨ ▁ਦੀ ▁ਲੋੜ ▁ਹੈ । ' ' ਸਾਡੀ ▁ਕਹਾਣੀਆਂ ▁ਸੱਚ ੀਆਂ ▁ਹਨ ▁ਪਰ ▁ਔਰਤਾਂ ▁ਦੀ ▁ਪਛਾਣ ▁ਲੁਕਾ ਈ ▁ਗਈ ▁ਹੈ ▁ਕਿਉਂਕਿ ▁ਡਰ ▁ਹੈ ▁ਕਿ ▁ਉਨ੍ਹਾਂ ▁ਦੇ ▁ਜਾਣ ▁ਵਾਲੇ ▁ਅਤੇ ▁ਸਮਾਜ ▁ਵੱਲੋਂ ▁ਕਿ ਹੋ ▁ਜਿਹੀ ਆਂ ▁ਪ੍ਰਤੀਕਿਰਿਆਵ ਾਂ ▁ਆਉਣ ਗੀਆਂ । ਪਰ ▁ਇਨ੍ਹਾਂ ▁ਗੁਮ ਨਾਮ ▁ਕਹਾਣੀਆਂ ▁ਨੂੰ ▁ਪੜ੍ਹਨ ▁ਵਾਲੀਆਂ ▁ਔਰਤਾਂ ▁ਬੇਬਾਕ ੀ ▁ਨਾਲ ▁ਲਿਖ ▁ਰਹੀਆਂ ▁ਹਨ । ਪੁ ਨਮ ▁ਕੁਮਾਰੀ ▁ਗੁਪਤਾ ▁ਕਹਿੰਦੀ ▁ਹੈ , ' ' ਲੋਕ ▁ਕਿੰਨਾ ▁ਬਦਲਣ ਗੇ ▁ਇਹ ▁ਤਾਂ ▁ਪਤਾ ▁ਨਹੀਂ ▁ਪਰ ▁ਸ਼ਾਇਦ ▁ਔਰਤਾਂ ▁ਦੀ ▁ਖ਼ੁਦ ▁ਦੀ ▁ਭ ੜਾ ਸ ▁ਨਿਕਲ ▁ਜਾਵੇ । ' ' 30 ▁ਔਰਤਾਂ ▁ਨੂੰ <unk> ▁h <unk> <unk> ▁ਪੀੜਤ ▁ਬਣਾਉਣ ▁ਵਾਲੇ ▁ਨੂੰ ▁ਜੇਲ੍ਹ ▁ਇਹ ▁ਕਹਾਣੀਆਂ ▁ਦੁਖ ਼ ▁ਅਤੇ ▁ਸ਼ਿਕਾਇਤ ▁ਦੀਆਂ ▁ਨਹੀਂ ▁ਹਨ । ▁ਸਮਾਜਿਕ ▁ਦਬਾਅ , ▁ਪਰਿਵਾਰਕ ▁ਦਾਇਰੇ ▁ਅਤੇ ▁ਔਰਤ ▁ਹੋਣ ▁ਦੇ ▁ਨਾਤੇ ▁ਤੈਅ ▁ਭੂਮਿਕਾਵਾਂ ▁ਨੂੰ ▁ਤੋੜ ▁ਕੇ ▁ਆਪਣੇ ▁ਮਨ ▁ਨੂੰ ▁ਸੁਣਨ ▁ਦੀ ▁ਹੈ । ਇਸ ▁ਲਈ ▁ਇਸਨੂੰ ▁ਪੜ੍ਹ ▁ਕੇ ▁ਕਿਸੇ ▁ਦੀ ▁ਭ ੜਾ ਸ ▁ਨਿਕਲ ▁ਰਹੀ ▁ਹੈ ▁ , ▁ਤਾਂ ▁ਕਿਸੇ ▁ਨੂੰ ▁ਵੱਖਰੇ ▁ਤਰੀਕੇ ▁ਨਾਲ ▁ਜੀ ਣ ▁ਦਾ ▁ਹੌਸਲਾ ▁ਮਿਲ ▁ਰਿਹਾ ▁ਹੈ । ਔਰਤ ਾਂ ▁ਦੇ ▁ਦਿਲ - ਦਿਮਾਗ ▁ਨੂੰ ▁ਜਾਣਨ ▁ਦਾ ▁ਮੌਕਾ ਬਿਨ ਾਂ ▁ਕਿਸੇ ▁ਸਰੀਰਕ ▁ਰਿਸ਼ਤੇ ▁ਵਿੱਚ ▁ਬੱਝੇ , ▁2 ▁ਔਰਤਾਂ ▁ਦੇ ▁ਇਕੱਠ ੇ ▁ਰਹਿਣ ▁ਦੀ ▁ਸਾਡੀ ▁ਦੂਜੀ ▁ਕਹਾਣੀ ▁' ਤੇ ▁ਇੱਕ ▁ਪਾਠਕ ▁ਮੀਨਾਕਸ਼ੀ ▁ਠਾਕੁਰ ▁ਲਿਖਦੀ ▁ਹੈ , ' ' ਆਪਣੇ ▁ਤਰੀਕੇ ▁ਨਾਲ ▁ਜੀ ਣ ▁ਦੀ ▁ਹਿੰਮਤ ▁ ਸਾਰਿਆਂ ▁' ਚ ▁ਨਹੀਂ ▁ਹੁੰਦੀ , ▁ਜੋ ▁ਇਨ੍ਹਾਂ ▁ਦੋਵਾਂ ▁ਨੇ ▁ਕਰ ▁ਕੇ ▁ਦਿਖਾਇਆ । ' ' ▁ਅਤਿ ਆ ▁ਰਹਿਮਾਨ ▁ਨੇ ▁ਲਿਖਿਆ ' ' ਜਦੋਂ ▁ਤੁਹਾਨੂੰ ▁ਸੱਚ ▁ਵਿੱਚ ▁ਪਤਾ ▁ਹੁੰਦਾ ▁ਹੈ ▁ਕਿ ▁ਤੁਸੀਂ ▁ਜੋ ▁ਕਰ ▁ਰਹੇ ▁ਹੋ ▁ਉਸਦਾ ▁ਕਾਰਨ ▁ਕੀ ▁ਹੈ ▁ਅਤੇ ▁ਤੁਸੀਂ ▁ਸੱਚਮੁ ਚ ▁ਚਾਹੁੰਦੇ ▁ਕੀ ▁ਹੋ , ▁ਉਦੋਂ ▁ਅਜਿਹੀ ਆਂ ▁ਕਹਾਣੀਆਂ ▁ਬਣਦੀਆਂ ▁ਹਨ । ' ' ਸਾਡੇ ▁ਸਮਾਜ ...
# Path: /home/gaurav/Downloads/ClassificationModel;
#
# Valid: LabelList
# y: LMLabel (157 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: /home/gaurav/Downloads/ClassificationModel
# x: LMTextList (157 items)
# [Text ▁x x bo s ▁ਪੁਲਾੜ ▁' ਚੋਂ ▁7 500 ▁ਟਨ ▁ਕੂੜ ਾ ▁ਇਸ ▁ਤਰ੍ਹਾਂ ▁ਸਾਫ਼ ▁ਕਰੇਗਾ ▁ਇਹ ▁ਜਾਲ ▁1 ▁ਅਕਤੂਬਰ ▁2018 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/ ▁ punjabi ▁/ ▁in tern ational - 45 69 95 49 ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਬਾਰੇ ▁ਹੋਰ ▁ਪੜ੍ਹ ੋ ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਵਾਲੇ ▁ਪੈਨਲ ▁ਨੂੰ ▁ਬੰਦ ▁ਕਰੋ <unk> ▁i m age ▁co py right ▁ <unk> <unk> <unk> ▁p ho to ▁library ▁ਫੋਟੋ ▁ਕੈਪ ਸ਼ਨ ▁ਇਹ ▁ਜਾਲ ▁ਧਰਤੀ ▁ਤੋਂ ▁300 ▁ਕਿੱਲੋਮੀਟਰ ▁ਤੋਂ ▁ਵੱਧ ▁ਉੱਚਾਈ ▁' ਤੇ ▁ਲਗਾਇਆ ▁ਗਿਆ ▁ਹੈ ▁ਬ੍ਰਿਟੇਨ ▁ਦੀ ▁ਇੱਕ ▁ਸੈਟੇਲਾਈਟ ▁ਨੇ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁( ਓਰ ਬਿਟ ) ▁ਵਿੱਚ ▁ਇੱਕ ▁ਜਾਲ ▁ਲਗਾਇਆ ▁ਹੈ ▁ਜਿਹੜਾ ▁ਸਪੇਸ ▁ਦੇ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਇਕੱਠਾ ▁ਕਰੇਗਾ । ਪ੍ਰਯੋਗ ▁ਦੇ ▁ਤੌਰ ▁' ਤੇ ▁ਸ਼ੁਰੂ ▁ਕੀਤੀ ▁ਇਹ ▁ਕੋਸ਼ਿਸ਼ ▁ਉਨ੍ਹਾਂ ▁ਯੋਜਨਾਵਾਂ ▁ਦਾ ▁ਹਿੱਸਾ ▁ਹੈ , ▁ਜਿਸ ਦੇ ▁ਜ਼ਰੀਏ ▁ਅੰਤਰਿਕਸ਼ ▁ਨੂੰ ▁ਕੂੜ ਾ ▁ਮੁਕਤ ▁ਬਣਾਉਣ ▁ਦੀ ▁ਯੋਜਨਾ ▁ਹੈ । ▁ਇਹ ▁ਜਾਲ ▁ਧਰਤੀ ▁ਤੋਂ ▁300 ▁ਕਿੱਲੋਮੀਟਰ ▁ਤੋਂ ▁ਵੱਧ ▁ਉੱਚਾਈ ▁' ਤੇ ▁ਲਗਾਇਆ ▁ਗਿਆ ▁ਹੈ । ▁ਇਹ ▁ਵੀ ▁ਪੜ੍ਹ ੋ : 9 ▁ਤੱਥ ▁ਜਿਨ੍ਹਾਂ ▁ਕਾਰਨ ▁ਵਧਿਆ ▁ਸੈਕਸ ▁ਟੁ ਆ ਏ ਜ਼ ▁ਦਾ ▁ਵਪਾਰ ▁ਦੁਨੀਆਂ ▁ਦੀਆਂ ▁ਪੰਜ ▁ ਖ਼ਤਰਨਾਕ ▁ਜਾਸੂਸ ▁ਔਰਤਾਂ ▁ਜਦੋਂ ▁ਇੱਕ ▁ਇੰਜੀਨੀਅਰ ▁ਮਜਬੂਰ ੀ ▁ਕਾਰਨ ▁ਔਰਤਾਂ ▁ਲਈ ▁‘ ਮਾਲ ’ ▁ਬਣਿਆ ਇਹ ▁ਸਮਝਿਆ ▁ਜਾਂਦਾ ▁ਹੈ ▁ਕਿ ▁ਕਰੀਬ ▁ਸਾਢ ੇ ▁ਸੱਤ ▁ਹਜ਼ਾਰ ▁ਟਨ ▁ਕੂੜ ਾ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਤੈਰ ▁ਰਿਹਾ ▁ਹੈ , ▁ਜਿਹੜਾ ▁ਉਨ੍ਹਾਂ ▁ਸੈਟ ਲਾਈਟ ਾਂ ▁ਲਈ ▁ਖ਼ਤਰਾ ▁ਹੈ , ▁ਜਿਨ੍ਹਾਂ ▁ਨੂੰ ▁ਕਿਸੇ ▁ਖਾਸ ▁ਮਕਸਦ ▁ਨਾਲ ▁ਲਾਂਚ ▁ਕੀਤਾ ▁ਗਿਆ ▁ਹੈ । ▁ਜਾਲ ▁ਦੇ ▁ਪ੍ਰਯੋਗ ▁ਦਾ ▁ਸੈਟੇਲਾਈਟ ▁ਦੇ ▁ਜ਼ਰੀਏ ▁ਵੀਡੀਓ ▁ਵੀ ▁ਬਣਾਇਆ ▁ਗਿਆ ▁ਹੈ ▁ਜਿਸ ▁ਵਿੱਚ ▁ਇੱਕ ▁ਜੁੱਤੀ ▁ਦੇ ▁ਡੱਬੇ ▁ਦੇ ▁ਆਕਾਰ ▁ਦੇ ▁ਪੁਲਾੜ ▁ਦੇ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਇਕੱਠਾ ▁ਕਰਦਾ ▁ਹੋਇਆ ▁ਦਿਖ ▁ਰਿਹਾ ▁ਹੈ । <unk> ▁i m age ▁co py right ▁ <unk> <unk> c ▁ਫੋਟੋ ▁ਕੈਪ ਸ਼ਨ ▁ਇ ੰਝ ▁ਕੀਤਾ ▁ਜਾਵੇਗਾ ▁ਜਾਲ ▁ਦਾ ▁ਪ੍ਰਯੋਗ ▁ਸੂਰ ੇ ▁ਸਪੇਸ ▁ਸੈਂਟਰ ▁ਦੇ ▁ਡਾਇਰੈਕਟਰ ▁ਪ੍ਰੋਫੈਸਰ ▁ਗੁ ਗ ਲਾਈ ਮ ਲੋ ▁ਅਗਲੀ ਤੀ ▁ਕਹਿੰਦੇ ▁ਹਨ , ▁" ਜਿਸ ▁ਤਰ੍ਹਾਂ ▁ਦੀਆਂ ▁ਸਾਡੀ ਆਂ ▁ਉਮੀਦ ਾਂ ▁ਸੀ , ▁ਇਹ ▁ਉਸ ▁ਤਰ੍ਹਾਂ ▁ਦਾ ▁ਹੀ ▁ਕੰਮ ▁ਕਰ ▁ਰਿਹਾ ▁ਹੈ ।" " ਤੁਸੀਂ ▁ਸਾਫ਼ ▁ਤੌਰ ▁' ਤੇ ▁ਦੇਖ ▁ਸਕਦੇ ▁ਹੋ ▁ਕਿ ▁ਇਹ ▁ਕਿਵੇਂ ▁ਜਾਲ ▁ਵਿੱਚ ▁ਫਸ ਿਆ । ▁ਅਸੀਂ ▁ਇਸ ▁ਪ੍ਰਯੋਗ ▁ਨਾਲ ▁ਖੁਸ਼ ▁ਹਾਂ ।" ਅੱਗ ੇ ▁ਕੀ ▁ਹੋਵੇਗਾ ਇਹ ▁ਸਿਰਫ਼ ▁ਇੱਕ ▁ਪ੍ਰਯੋਗ ▁ਸੀ , ▁ਜਿਸ ▁ਵਿੱਚ ▁ਇੱਕ ▁ਜੁੱਤੀ ▁ਦੇ ▁ਡੱਬੇ ▁ਦੇ ▁ਆਕਾਰ ▁ਦੇ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਦੂਜੇ ▁ਸੈਟੇਲਾਈਟ ▁ਨਾਲ ▁ਧਰਤੀ ▁ਵੱਲ ▁ਡਿਗ ਾਇਆ ▁ਗਿਆ ▁ਸੀ , ▁ਜਿਸ ▁ਨੂੰ ▁ਬਾਅਦ ▁ਵਿੱਚ ▁ਜਾਲ ▁ਵਿੱਚ ▁ਫਸ ਾਇਆ ▁ਗਿਆ । ▁ਜੇਕਰ ▁ਅਸਲ ▁ਵਿੱਚ ▁ਅਜਿਹਾ ▁ਹੋ ▁ਸਕੇਗਾ ▁ਤਾਂ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਫਸ ਾਉਣ ▁ਤੋਂ ▁ਬਾਅਦ ▁ਸੈਟੇਲਾਈਟ ▁ਦੀ ▁ਮਦਦ ▁ਨਾਲ ▁ਜਾਲ ▁ਇਸ ▁ਨੂੰ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਤੋਂ ▁ਬਾਹਰ ▁ਕਰ ▁ਦੇਵੇਗਾ । <unk> ▁i m age ▁co py right <unk> ▁a i r b <unk> us ▁ਫੋਟੋ ▁ਕੈਪ ਸ਼ਨ ▁ਕੁਝ ▁ਇਸ ▁ਤਰ੍ਹਾਂ ▁ਤਿਆਰ ▁ਕੀਤਾ ▁ਗਿਆ ▁ਹੈ ▁ਸਪੇਸ ▁ਜਾਲ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਤੈਰ ▁ਰਹੇ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਹਟਾਉਣ ▁ਦੀ ▁ਗੱਲ ▁ਹੁੰਦੀ ▁ਰਹੀ ▁ਹੈ । ▁ਕਈ ▁ਪ੍ਰਯੋਗ ▁ਵੀ ▁ਇਸ ▁' ਤੇ ▁ਚੱਲ ▁ਰਹੇ ▁ਹਨ ▁ਪਰ ▁ਦਾਅਵਾ ▁ਕੀਤਾ ▁ਜਾ ▁ਰਿਹਾ ▁ਹੈ ▁ਕਿ ▁ਇਹ ▁ਪਹਿਲੀ ▁ਵਾਰ ▁ਹੈ ▁ਕਿ ▁ਜਦੋਂ ▁ਇਸ ▁ਤਰ੍ਹਾਂ ▁ਦਾ ▁ਸਫ਼ਲ ▁ਪ੍ਰਯੋਗ ▁ਕੀਤਾ ▁ਗਿਆ ▁ਹੋਵੇ । ▁ਜਲਦੀ ▁ਹੀ ▁ਹੁਣ ▁ਇਸ ▁ਕੋਸ਼ਿਸ਼ ▁ਦੇ ▁ਤਹਿਤ ▁ਦੂਜੇ ▁ਪੜ੍ਹਾ ਅ ▁ਦਾ ▁ਪ੍ਰਯੋਗ ▁ਕੀਤਾ ▁ਜਾਵੇਗਾ , ▁ਜਿਸ ▁ਵਿੱਚ ▁ਇੱਕ ▁ਕੈਮਰਾ ▁ਲਗਾਇਆ ▁ਜਾਵੇਗਾ ▁ਜਿਹੜਾ ▁ਸਪੇਸ ▁ਦੇ ▁ਅਸਲ ▁ਕੂੜੇ ▁ਨੂੰ ▁ਕੈਦ ▁ਕਰ ▁ਸਕੇ ▁ਤਾਂ ▁ਕਿ ▁ਉਨ੍ਹਾਂ ▁ਨੂੰ ▁ਹਟਾਉਣ ਾ ▁ਸੌਖਾ ▁ਹੋਵੇ । ▁ਇਹ ▁ਉਮੀਦ ▁ਕੀਤੀ ▁ਜਾ ▁ਰਹੀ ▁ਹੈ ▁ਕਿ ▁ਨਵੇਂ ▁ਸਾਲ ▁ਦੀ ▁ਸ਼ੁਰੂਆਤ ▁ਤੱਕ ▁ਇਸ ▁ਤੋਂ ▁ਹੋਰ ▁ਬਿ ਹਤ ਕ ▁ਤਰੀਕੇ ▁ਨਾਲ ▁ਕੰਮ ▁ਲਿਆ ▁ਜਾ ▁ਸਕੇਗਾ । ▁ਸਪੇਸ ▁ਕੂੜੇ ▁ਤੋਂ ▁ਕਿੰਨਾ ▁ਖਤਰਾ ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਲੱਖਾਂ ▁ਟੁ ੱਕੜ ੇ ▁ਤੈਰ ▁ਰਹੇ ▁ਹਨ । ▁ਇਹ ▁ਟੁ ੱਕੜ ੇ ▁ਪੁਰਾਣੇ ▁ਅਤੇ ▁ਸੇਵਾ ▁ਤੋਂ ▁ਬਾਹਰ ▁ਹੋ ▁ਚੁੱਕੇ ▁ਸੈਟ ਲਾਈਟ ਾਂ ▁ਦੇ ▁ਅੰਸ਼ ▁ਅਤੇ ▁ਅੰਤਰਿਕਸ਼ ▁ਯਾਤਰੀਆਂ ▁ਵੱਲੋਂ ▁ਗ਼ਲਤੀ ▁ਨਾਲ ▁ਰਹਿ ▁ਗਏ ▁ਕੁਝ ▁ਉਪਕਰਣ ▁ਹਨ । <unk> ▁i m age ▁co py right ▁ <unk> <unk> ▁/ ▁ <unk> na n o <unk> ra c k s ▁ਫੋਟੋ ▁ਕੈਪ ਸ਼ਨ ▁ਆਉਣ ▁ਵਾਲੇ ▁ਸਮੇਂ ▁ਵਿੱਚ ▁ਲੋੜਾਂ ▁ਦੇ ▁ਹਿਸਾਬ ▁ਨਾਲ ▁ਕਈ ▁ਸੈਟ ੇ ਲਾਈ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਲਾਂਚ ▁ਕੀਤੇ ▁ਜਾਣਗੇ ▁ਡਰ ▁ਇਹ ▁ਹੈ ▁ਕਿ ▁ਜੇ ▁ਇਨ੍ਹਾਂ ▁ਕੂੜ ਿਆਂ ▁ਨੂੰ ▁ਹਟਾਇਆ ▁ਨਹੀਂ ▁ਗਿਆ ▁ਤਾਂ ▁ਇਹ ▁ਕੰਮ ▁ਵਿੱਚ ▁ਆ ▁ਰਹੀਆਂ ▁ਸੈਟ ਲਾਈਟ ਾਂ ▁ਨੂੰ ▁ਨਸ਼ਟ ▁ਕਰ ▁ਦੇਵੇਗਾ । ਇਸ ▁ਪ੍ਰਾਜੈਕਟ ▁' ਤੇ ▁ਕੰਮ ▁ਕਰ ▁ਰਹੇ ▁ਇੰਜੀਨੀਅਰ ▁ਅਲ ਸ ਟੇਅਰ ▁ਵੇ ਮੈਨ ▁ਕਹਿੰਦੇ ▁ਹਨ , ▁" ਜੇਕਰ ▁ਇਹ ▁ਟੁ ੱਕੜ ੇ ▁ਆਪਸ ▁ਵਿੱਚ ▁ਟਕਰਾਉਂਦ ੇ ▁ਹਨ ▁ਤਾਂ ▁ਹੋਰ ▁ਕੂੜ ਾ ▁ਇਕੱਠਾ ▁ਹੋਵੇਗਾ । ▁ਜ਼ਿਆਦਾ ▁ਕੂੜ ਾ ▁ਬਣਨ ▁ਨਾਲ ▁ਟਕਰਾਉਣ ▁ਦਾ ▁ਖ ਦ ਸ਼ਾ ▁ਲਗਾਤਾਰ ▁ਵਧਦਾ ▁ਰਹੇਗਾ ▁ਅਤੇ ▁ਇੱਕ ▁ਦਿਨ ▁ਇਹ ▁ਵੱਡੀ ▁ਪ੍ਰੇਸ਼ਾਨ ੀ ▁ਖੜ੍ਹੀ ▁ਕਰ ▁ਸਕਦਾ ▁ਹੈ ।" ਇਹ ▁ਵੀ ▁ਪੜ੍ਹ ੋ : ਇੰਡੋ ਨੇਸ਼ੀਆ : ▁ਸੁਨਾਮੀ ▁ਦੀ ▁ਤਬਾਹੀ ▁' ਚ ▁83 2 ▁ਲੋਕਾਂ ▁ਦੀ ▁ਮੌਤ ਪਹਿਲ ੂ ▁ਖ਼ਾਨ ▁ਮੌ ਬ ▁ ਲਿੰ ਚਿੰਗ ▁ਕੇਸ ▁ਦੇ ▁ਗਵਾਹ ਾਂ ▁' ਤੇ ▁ਹਮਲਾ ' ਮੇਰੇ ▁ਵਿਆਹ ▁ਨਾ ▁ਕਰਨ ▁ਦੇ ▁ਫ਼ੈਸਲੇ ▁' ਤੇ ▁ਇੰਨ ੇ ▁ਸਵਾਲ ▁ਕਿਉਂ ' ਆ ਉਣ ▁ਵਾਲੇ ▁ਸਮੇਂ ▁ਵਿੱਚ ▁ਲੋੜਾਂ ▁ਦੇ ▁ਹਿਸਾਬ ▁ਨਾਲ ▁ਕਈ ▁ਸੈਟ ੇ ਲਾਈ ▁ਧਰਤੀ ▁ਦੇ ▁ਗ੍ਰਹਿ - ਪਥ ▁ਵਿੱਚ ▁ਲਾਂਚ ▁ਕੀਤੇ ▁ਜਾਣਗੇ । ▁ਜੇਕਰ ▁ਸਪੇਸ ▁ਕੂੜੇ ▁ਨਾਲ ▁ਨਿਪਟ ਾ ▁ ...
# Path: /home/gaurav/Downloads/ClassificationModel;
#
# Test: None, model=SequentialRNN(
#   (0): RNNCore(
#     (encoder): Embedding(30000, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(30000, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1150, batch_first=True)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1150, 1150, batch_first=True)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1150, 400, batch_first=True)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=30000, bias=True)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<fastai.layers.FlattenedLoss object at 0x7f9e294d8828>, metrics=[<function accuracy at 0x7f9e321f5268>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/home/gaurav/Downloads/ClassificationModel'), model_dir='models', callback_fns=[<class 'fastai.basic_train.Recorder'>], callbacks=[...], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(30000, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(30000, 400, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=30000, bias=True)
#     (output_dp): RNNDropout()
#   )
# )])
# bptt: 70
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(30000, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(30000, 400, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=30000, bias=True)
#     (output_dp): RNNDropout()
#   )
# )])

# %%
# Fine tuning the prtrained LM on current dataset

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.freeze()

# %%
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7))
# Out:
# Total time: 00:23 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>4.320559</th>
#     <th>4.156694</th>
#     <th>0.345858</th>
#   </tr>
# </table>

# %%
learn.save('fit_head', with_opt=True)

# %%
learn.load('fit_head', with_opt=True);

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, 1e-3, moms=(0.8,0.7))
# Out:
# Total time: 02:21 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>3.898279</th>
#     <th>4.032889</th>
#     <th>0.358197</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>3.717018</th>
#     <th>3.914392</th>
#     <th>0.373195</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>3.484484</th>
#     <th>3.866841</th>
#     <th>0.381281</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>3.319473</th>
#     <th>3.854770</th>
#     <th>0.384879</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>3.254846</th>
#     <th>3.862355</th>
#     <th>0.385331</th>
#   </tr>
# </table>

# %%
learn.save('fine_tuned', with_opt=True)

# %%
learn.load('fine_tuned', with_opt=True);

# %%
learn.predict('ਜੋ ਉਹਨਾਂ ਦੇ ਰੱਬਾਂ ਨੂੰ ਪ੍ਰਸਤੁਤ ਕਰਦੇ',n_words=10)
# Out:
# 'ਜੋ ਉਹਨਾਂ ਦੇ ਰੱਬਾਂ ਨੂੰ ਪ੍ਰਸਤੁਤ ਕਰਦੇ ▁ pa e ▁ਪ੍ਰੋਡਕਟ ▁ਸਿਖਾਉਣ na na ਸੰਗੀਤ ਉਨ੍ਹਾਂ ▁ਨੇ'

# %%
learn.save_encoder('fine_tuned_enc')

# %%
data_clas = TextClasDataBunch.from_csv(path=path, csv_name='Punjabi_Binary_Classification.csv', tokenizer=tokenizer, vocab=panjabi_vocab, text_cols=[0], label_cols=label_cols)

# %%
data_clas.show_batch()
# Out:
# <table>  <col width='90%'>  <col width='10%'>  <tr>
#     <th>text</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁ਕਿਸਾਨਾਂ ▁ਦੀਆਂ ▁ਖੁਦਕੁਸ਼ੀ ਆਂ ▁ਤੇਲੰਗਾਨਾ ▁' ਚ ▁ਰੁਕ ▁ਸਕਦੀਆਂ ▁ਤਾਂ ▁ਪੰਜਾਬ ▁' ਚ ▁ਕਿਉਂ ▁ਨਹੀਂ ▁: <unk> ▁b b c <unk> ▁s p e c i <unk> al ▁ਪ੍ਰਿ ਅੰਕ ਾ ▁ਦੂ ਬੇ ▁ਬੀਬੀਸੀ ▁ਪੱਤਰਕਾਰ , ▁ਤੇਲੰਗਾਨਾ ▁ਤੋਂ ▁ਵਾਪਸ ▁ਆ ▁ਕੇ ▁3 ▁ਸਤੰਬਰ ▁2018 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/</th>
#     <th>False</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁ਦਿ ▁ਐਕਸੀਡੈਂਟ ਲ ▁ਪ੍ਰਾਈਮ ▁ਮਿਨਿਸਟਰ : ▁ ਮਨਮੋਹਨ ▁ਸਿੰਘ ▁ਦੇ ▁ਸਲਾਹਕਾਰ ▁ਨੇ ▁ਅਸਲ ▁' ਚ ▁ਉਨ੍ਹਾਂ ▁ਤੇ ▁ਸੋਨੀਆ ▁ਗਾਂਧੀ ▁ਬਾਰੇ ▁ਆਪਣੀ ▁ਕਿਤਾਬ ▁' ਚ ▁ਕੀ ▁ਲਿਖਿਆ ▁ਰੇ ਹਾਨ ▁ਫ਼ਜ਼ਲ ▁ਬੀਬੀਸੀ ▁ਪੱਤਰਕਾਰ ▁8 ▁ਜਨਵਰੀ ▁ 2019 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/ ▁ punjabi ▁/ ▁ india -4 67 86 362</th>
#     <th>False</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁1984 ▁ਦਿੱਲੀ ▁ਸਿੱਖ ▁ਕਤਲੇਆਮ ▁ਜਾਂ ▁ਗੁਜਰਾਤ ▁ਵਰਗਾ ▁ਕਾਂਡ ▁ਦੁਬਾਰਾ ▁ਨਹੀਂ ▁ਵਾਪਰੇ ਗਾ , ▁ਕੀ ▁ਅਸੀਂ ▁ਇਹ ▁ਕਹਿ ▁ਸਕਦੇ ▁ਹਾਂ ▁- ▁ਨਜ਼ਰੀਆ ▁ਸ਼ਮੀ ਲ ▁ਸੀਨੀਅਰ ▁ਪੱਤਰਕਾਰ ▁14 ▁ਜਨਵਰੀ ▁ 2019 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/ ▁ punjabi ▁/ ▁ india - 46 82 97 91 ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਬਾਰੇ ▁ਹੋਰ ▁ਪੜ੍ਹ</th>
#     <th>False</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁ਕਰਤਾਰਪੁਰ ▁ਸਮਾਗਮ ▁' ਚ ▁ਸਿੱਧੂ ▁ਤੇ ▁ਲੌਂਗੋਵਾਲ ▁ਨਾਲ ▁ਦਿਖ ਿਆ ▁ਖਾਲਿਸਤਾਨ ੀ ▁ਗੋਪਾਲ ▁ਚਾਵਲਾ ▁ਆਖਰ ▁ਹੈ ▁ਕੌਣ ▁ਦਲਜੀਤ ▁ਅਮੀ ▁ਪੱਤਰਕਾਰ , ▁ਬੀਬੀਸੀ ▁ਪੰਜਾਬੀ ▁3 ▁ਦਸੰਬਰ ▁2018 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/ ▁ punjabi ▁/ ▁ india - 46 40 32 74 ▁ਸਾਂਝਾ ▁ਕਰਨ ▁ਬਾਰੇ ▁ਹੋਰ ▁ਪੜ੍ਹ ੋ ▁ਸਾਂਝਾ ▁ਕਰਨ</th>
#     <th>False</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁ਆਈ ਵੀ ਐਫ਼ ▁ਬਾਰੇ ▁ਸੋਚ ▁ਰਹੀ ▁ਮਾਂ ▁ਜਿਸ ਦੇ ▁ਤਿੰਨ ▁ਬੱਚਿਆਂ ▁ਦੀ ▁ਮੌਤ ▁ਸ਼ਾਇਦ ▁' ਕ ਜ਼ਨ ' ▁ਨਾਲ ▁ਵਿਆਹ ▁ਕਾਰਨ ▁ਹੋਈ ▁ਸੂ ▁ਸਿ ਸ਼ੇਲ ▁ਬੀਬੀਸੀ ▁ਨਿਊਜ਼ ▁ਬ੍ਰੈਡ ਫੋਰਡ ▁19 ▁ਦਸੰਬਰ ▁2018 ▁ਈਮੇਲ ▁ਸਾਂਝਾ ▁ਕਰੋ ▁ਈਮੇਲ ▁ਈਮੇਲ ▁ਲਿੰਕ ▁ਨੂੰ ▁ਕਾਪੀ ▁ਕਰੋ ▁http s : ▁/ ▁/ ▁w ww . bb c . com ▁/ ▁ punjabi ▁/ ▁in tern ational - 46 59 18 15 ▁ਸਾਂਝਾ</th>
#     <th>False</th>
#   </tr>
# </table>

# %%
data_clas.sanity_check()

# %%
learn = text_classifier_learner(data_clas, drop_mult=0.5)

# %%
learn.load_encoder('fine_tuned_enc')

# %%
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.loss_func.func
# Out:
# CrossEntropyLoss()

# %%
kappa = KappaScore()

# %%
learn.metrics = [kappa]

# %%
learn.fit_one_cycle(1, 1e-1, moms=(0.8,0.7))
# Out:
# Total time: 00:11 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>kappa_score</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.287705</th>
#     <th>0.280379</th>
#     <th>0.393271</th>
#   </tr>
# </table>

# %%
learn.save('first-full')

# %%
learn.load('first-full');

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(1, slice(1e-2/(2.6**4),1e-2), moms=(0.8,0.7))
# Out:
# Total time: 00:13 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>kappa_score</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.263351</th>
#     <th>0.231576</th>
#     <th>0.424908</th>
#   </tr>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(5, slice(1e-3/(2.6**4),1e-3), moms=(0.8,0.7))
# Out:
# Total time: 01:48 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>kappa_score</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.222138</th>
#     <th>0.233904</th>
#     <th>0.406552</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.206140</th>
#     <th>0.266204</th>
#     <th>0.524158</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.208257</th>
#     <th>0.538404</th>
#     <th>0.485058</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.209039</th>
#     <th>0.244574</th>
#     <th>0.479219</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.199351</th>
#     <th>0.292407</th>
#     <th>0.494689</th>
#   </tr>
# </table>

# %%
# Todos: Clean the input text a little

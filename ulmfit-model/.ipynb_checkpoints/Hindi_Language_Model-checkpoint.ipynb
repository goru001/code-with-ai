# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.text import *
import numpy as np
from sklearn.model_selection import train_test_split
import pickle
import sentencepiece as spm

# %%
import fastai, torch
fastai.__version__ , torch.__version__
# Out:
# ('1.0.40', '1.0.0')

# %%
torch.cuda.set_device(0)

# %%
path = Path('/home/gaurav/Downloads/LanguageModel')

# %%
p = path.glob('HindiWikipediaArticles/*')
files = [x for x in p if x.is_file()]

# %%
len(files)
# Out:
# 55000

# %%
train_files, test_files = train_test_split(files, test_size=0.2)

# %%
len(train_files), len(test_files)
# Out:
# (44000, 11000)

# %%
str(train_files[0]).split('/')[-1][:-4]
# Out:
# '118223'

# %%
# Preparing dataset for fastai
for file in train_files:
    with open(file, 'rb') as f:
        text = pickle.load(f)
    with open(path/'HindiDataset'/'train'/(str(file).split('/')[-1][:-4]+'.txt'), "w") as text_file:
        text_file.write(text)

# %%
for file in test_files:
    with open(file, 'rb') as f:
        text = pickle.load(f)
    with open(path/'HindiDataset'/'valid'/(str(file).split('/')[-1][:-4]+'.txt'), "w") as text_file:
        text_file.write(text)

# %%
class HindiTokenizer(BaseTokenizer):
    def __init__(self, lang:str):
        self.lang = lang
        self.sp = spm.SentencePieceProcessor()
        self.sp.Load(str(path/"hindi_lm.model"))
        
    def tokenizer(self, t:str) -> List[str]:
        return self.sp.EncodeAsPieces(t)

# %%
sp = spm.SentencePieceProcessor()
sp.Load(str(path/"hindi_lm.model"))
itos = [sp.IdToPiece(int(i)) for i in range(30000)]

# %%
itos
# Out:
# ['<unk>',
#  '<s>',
#  '</s>',
#  '▁के',
#  '।',
#  '▁में',
#  '▁है',
#  ',',
#  '▁',
#  '▁की',
#  '▁और',
#  '▁से',
#  '▁का',
#  '▁को',
#  '▁हैं',
#  '▁एक',
#  '▁पर',
#  '.',
#  '-',
#  '▁भी',
#  '▁ने',
#  '▁किया',
#  '▁·',
#  '▁यह',
#  '▁था',
#  '▁लिए',
#  '▁इस',
#  '▁गया',
#  'ों',
#  '▁कि',
#  'ी',
#  '▁जाता',
#  '▁जो',
#  '▁रूप',
#  '▁ही',
#  '▁q',
#  '▁�',
#  '▁कर',
#  '▁हो',
#  '▁करने',
#  '▁तथा',
#  '▁नहीं',
#  '▁द्वारा',
#  '▁या',
#  'X',
#  '▁थे',
#  '▁साथ',
#  '▁•',
#  'ा',
#  '▁भारत',
#  '▁होता',
#  '▁बाद',
#  '▁तक',
#  ':',
#  '▁"',
#  '▁दिया',
#  '▁अपने',
#  '▁थी',
#  '▁हुआ',
#  'न',
#  '▁कुछ',
#  '"',
#  '▁जिला',
#  '�',
#  '▁एवं',
#  '▁इसके',
#  '▁वे',
#  '▁वह',
#  '▁|',
#  "'",
#  '▁नाम',
#  '▁जा',
#  '▁राज्य',
#  '▁समय',
#  '▁होती',
#  '▁करते',
#  '▁हुए',
#  '▁तो',
#  '▁कई',
#  "▁'",
#  '▁अन्य',
#  '▁अधिक',
#  '▁क्षेत्र',
#  '▁कारण',
#  'े',
#  '▁सबसे',
#  '▁प्रकार',
#  '▁होने',
#  'क',
#  '▁सकता',
#  '▁स्थित',
#  'र',
#  '▁उनके',
#  '▁भारतीय',
#  '▁उन्होंने',
#  '▁किसी',
#  '▁वर्ष',
#  '▁जाती',
#  '▁वाले',
#  '▁बहुत',
#  '▁होते',
#  '▁करता',
#  'ता',
#  '▁दो',
#  '▁व',
#  'ं',
#  '▁अपनी',
#  '▁कहा',
#  '▁पूर्व',
#  '▁पहले',
#  '▁गए',
#  '▁इन',
#  '▁हुई',
#  '▁जैसे',
#  '▁जब',
#  '▁ये',
#  '▁कम',
#  'ल',
#  'स',
#  '▁/',
#  '▁गई',
#  'ो',
#  '▁न',
#  '▁लेकिन',
#  'म',
#  '▁उन्हें',
#  '▁आदि',
#  '▁अनुसार',
#  '▁भाषा',
#  '▁इसका',
#  '▁प्राप्त',
#  '▁रहे',
#  '▁उत्तर',
#  '▁लिये',
#  '▁-',
#  '▁रहा',
#  '▁शामिल',
#  ';',
#  '▁उसके',
#  '▁सभी',
#  '▁जाने',
#  '▁इसे',
#  '▁बीच',
#  '▁तरह',
#  '▁उस',
#  '▁लिया',
#  '▁गाँव',
#  '▁जाते',
#  '▁उनकी',
#  '▁कोई',
#  '▁प्रमुख',
#  '▁भाग',
#  '▁प्रयोग',
#  '▁जिले',
#  '्स',
#  'ित',
#  '▁देश',
#  '▁कार्य',
#  '▁करना',
#  '▁जिसमें',
#  '▁प्रदेश',
#  '▁मुख्य',
#  '▁यहाँ',
#  '▁निर्माण',
#  '▁ओर',
#  '▁जन्म',
#  '▁दी',
#  '▁लगभग',
#  '▁लोगों',
#  'ने',
#  '▁दोनों',
#  'ना',
#  '▁काम',
#  '▁स्थान',
#  '▁उपयोग',
#  '▁उसे',
#  '▁सकते',
#  '▁विश्व',
#  '▁अ',
#  '▁शहर',
#  '▁सरकार',
#  'ियों',
#  '▁इसकी',
#  's',
#  '▁बार',
#  'पुर',
#  '▁विकास',
#  '▁इसी',
#  '▁वाली',
#  '▁दक्षिण',
#  '▁नगर',
#  '▁तीन',
#  '▁आ',
#  'E',
#  '▁केवल',
#  'N',
#  '▁कहते',
#  '▁धर्म',
#  '▁2',
#  'ई',
#  '▁माना',
#  '▁करती',
#  '▁विशेष',
#  '▁फिर',
#  '▁लोग',
#  'ीय',
#  'त',
#  '▁फिल्म',
#  '▁जीवन',
#  '▁प्राचीन',
#  '्',
#  '▁दौरान',
#  '▁अलग',
#  '▁इसमें',
#  '▁मे',
#  '▁1',
#  '▁जिसे',
#  'कर',
#  '▁आधार',
#  'िक',
#  '▁बना',
#  '▁विभिन्न',
#  '°',
#  '▁ई',
#  '▁अब',
#  '▁द',
#  '▁मंदिर',
#  '▁उनका',
#  '▁प्रसिद्ध',
#  '▁जी',
#  '▁प्रति',
#  '▁शब्द',
#  '▁दिन',
#  '▁क्योंकि',
#  '▁राष्ट्रीय',
#  '▁यहां',
#  '▁शुरू',
#  '▁अनेक',
#  '▁काल',
#  '▁पास',
#  '0',
#  '▁रही',
#  '▁संवत',
#  '▁जाना',
#  '▁युद्ध',
#  'ए',
#  '▁अन्तर्गत',
#  '▁बन',
#  '▁तब',
#  '▁अपना',
#  '▁जिसके',
#  '▁हालांकि',
#  '▁ईसा',
#  'ज',
#  '▁अलावा',
#  '▁नदी',
#  '▁व्यक्ति',
#  '▁मध्य',
#  '▁गयी',
#  '▁सन्',
#  '▁महत्वपूर्ण',
#  '▁राजा',
#  'द',
#  '▁जल',
#  'ि',
#  '▁मूल',
#  '▁बड़े',
#  '▁संख्या',
#  '▁कभी',
#  'ट',
#  '▁विज्ञान',
#  '/',
#  '▁अध्ययन',
#  '▁उन',
#  '▁ले',
#  '▁साल',
#  '▁प्रथम',
#  '▁किए',
#  '▁ए',
#  '▁the',
#  '▁नामक',
#  '▁हिन्दी',
#  'ओं',
#  'प',
#  '▁साहित्य',
#  'व',
#  '▁प्रदान',
#  '▁सकती',
#  '▁जिसका',
#  '▁अमेरिका',
#  '▁दूसरे',
#  'ते',
#  '▁प्रभाव',
#  '▁उसकी',
#  '▁जबकि',
#  '▁चाहिए',
#  '▁शिक्षा',
#  '▁तौर',
#  '▁वाला',
#  '▁गये',
#  '▁आम',
#  '▁कुल',
#  '▁अर्थ',
#  '▁स्थापित',
#  '▁दिल्ली',
#  '▁हर',
#  'ब',
#  '▁:',
#  '▁ऐसे',
#  '▁उच्च',
#  '▁सिंह',
#  '▁बड़ा',
#  '▁बड़ी',
#  '▁संयुक्त',
#  '▁बात',
#  '▁ऐसा',
#  '▁चार',
#  '▁स्थापना',
#  '▁आज',
#  '▁पहली',
#  '▁तहसील',
#  '▁मण्डल',
#  '▁देने',
#  '▁अथवा',
#  '▁देशों',
#  '▁वर्तमान',
#  '▁बनाया',
#  '▁इतिहास',
#  '▁किये',
#  '▁यदि',
#  '▁रखा',
#  '▁काफी',
#  '▁समूह',
#  '▁विश्वविद्यालय',
#  'य',
#  'जी',
#  'सी',
#  '▁जिससे',
#  '▁of',
#  'िया',
#  '▁करके',
#  'नी',
#  'ती',
#  '▁स्थिति',
#  '▁उसने',
#  '▁सी',
#  'रा',
#  '▁बनाने',
#  '▁बारे',
#  '▁प्रत्येक',
#  '▁रंग',
#  '▁वर्षों',
#  '▁लेकर',
#  '▁इनके',
#  '▁स्तर',
#  'वीं',
#  '▁सेना',
#  '▁10',
#  'री',
#  'ें',
#  '▁श्री',
#  '▁क्षेत्रों',
#  '▁उसका',
#  '▁स',
#  'का',
#  '▁उपलब्ध',
#  '▁शरीर',
#  '▁सभा',
#  '▁अधिकांश',
#  '▁सामाजिक',
#  '▁वर्ग',
#  '2',
#  '▁दे',
#  '▁लगा',
#  '▁सेवा',
#  '▁रहता',
#  'श',
#  '▁3',
#  '▁दूर',
#  '▁सदस्य',
#  '▁माध्यम',
#  '▁देता',
#  'ु',
#  'ज़',
#  '▁उत्पन्न',
#  '▁इससे',
#  '▁फ़िल्म',
#  '▁15',
#  '▁दुनिया',
#  '▁इस्तेमाल',
#  'िंग',
#  '▁8',
#  '▁जहां',
#  '▁ब्रिटिश',
#  'ड',
#  '▁जहाँ',
#  '▁इसलिए',
#  '▁पानी',
#  'ली',
#  '▁समाज',
#  '▁मानव',
#  '▁अंत',
#  '▁समान',
#  '▁परिवार',
#  '▁पाकिस्तान',
#  '▁शक्ति',
#  '▁संगीत',
#  '▁प्रणाली',
#  'ग',
#  '▁संघ',
#  '▁5',
#  '▁होगा',
#  '▁पुरस्कार',
#  '▁आधुनिक',
#  '▁सामान्य',
#  'या',
#  '▁थीं',
#  '▁आगे',
#  '▁बने',
#  '▁छोटे',
#  '▁अतिरिक्त',
#  '▁उदाहरण',
#  '▁होकर',
#  '▁रहते',
#  '▁अधिकार',
#  'ला',
#  'ण',
#  '▁स्टेशन',
#  '▁शासन',
#  '▁चीन',
#  '▁जिनमें',
#  '▁क',
#  '▁4',
#  'ह',
#  '▁जिस',
#  'ंग',
#  '▁‘',
#  '▁16',
#  '▁भूमिका',
#  '▁देते',
#  '▁शताब्दी',
#  '▁जारी',
#  '▁विकसित',
#  '▁ज्ञान',
#  '▁पिता',
#  '▁मृत्यु',
#  '▁बाहर',
#  '▁कंपनी',
#  '’',
#  '▁ली',
#  '▁पश्चिम',
#  '▁प्रकाशित',
#  '▁रेलवे',
#  '▁कला',
#  'के',
#  '▁प्रकाश',
#  '▁राजधानी',
#  '▁7',
#  '▁ध्यान',
#  '▁मात्रा',
#  '▁संबंध',
#  '▁विचार',
#  '▁उत्तराखण्ड',
#  '▁आधारित',
#  '▁ऑफ',
#  '▁बनी',
#  '▁ऊपर',
#  '▁आप',
#  '▁20',
#  'की',
#  '▁पद',
#  '▁बिहार',
#  '▁देखा',
#  'ओ',
#  '▁चुनाव',
#  '▁सब',
#  '▁पता',
#  '▁6',
#  '▁पहला',
#  '▁घर',
#  '▁प्रक्रिया',
#  '▁पूरी',
#  '▁नए',
#  '▁मार्ग',
#  '▁उत्तरी',
#  '▁विषय',
#  '़',
#  '▁स्वयं',
#  '▁इनमें',
#  '▁रचना',
#  '▁राज',
#  'च',
#  '▁रोग',
#  '▁तैयार',
#  '▁नीचे',
#  '▁भगवान',
#  'वा',
#  '▁12',
#  '▁ऐसी',
#  '▁यात्रा',
#  '▁जनसंख्या',
#  '▁साम्राज्य',
#  '▁पश्चिमी',
#  '▁17',
#  '▁दृष्टि',
#  '▁होना',
#  '▁भिन्न',
#  '▁दशक',
#  '▁दूसरी',
#  '▁सहायता',
#  '▁सीमा',
#  '▁उत्पादन',
#  '▁अक्सर',
#  '▁पृथ्वी',
#  '▁किलोमीटर',
#  '▁व्यवस्था',
#  'बी',
#  '▁मिला',
#  '▁सिद्धांत',
#  '▁वहाँ',
#  '▁स्',
#  '▁भर',
#  '▁हिस्सा',
#  '▁आने',
#  '1',
#  '▁जगह',
#  '▁आवश्यक',
#  '▁पुत्र',
#  '▁टीम',
#  '▁लिखा',
#  '▁राम',
#  '▁सन',
#  '▁आर्थिक',
#  '▁पार्टी',
#  'मा',
#  '▁हेतु',
#  'टी',
#  '▁उप',
#  '▁लगे',
#  '▁बिना',
#  '▁पूर्वी',
#  '▁वो',
#  'वी',
#  '▁तुलना',
#  'ू',
#  '▁पाया',
#  '▁विभाग',
#  '▁ज्यादा',
#  '▁9',
#  'अ',
#  'ले',
#  '▁सदी',
#  '▁गति',
#  '▁लोक',
#  '▁इनका',
#  '▁संगठन',
#  '▁रहती',
#  '▁नई',
#  '▁पूरा',
#  '▁द्वीप',
#  '▁मिलता',
#  '▁अंग्रेजी',
#  '▁अभी',
#  '▁उसी',
#  '▁पूर्ण',
#  '▁केंद्र',
#  'से',
#  '▁प्रदर्शन',
#  '▁रहने',
#  'डी',
#  '▁वि',
#  '▁सु',
#  '▁वृद्धि',
#  '▁अवधि',
#  '▁संस्कृत',
#  '▁क्रिकेट',
#  '▁स्थानीय',
#  '▁प्र',
#  '▁आते',
#  '▁वर्णन',
#  '▁अंतर्राष्ट्रीय',
#  '▁मिल',
#  '▁ऑफ़',
#  '▁अमेरिकी',
#  '▁प्रभावित',
#  '▁हम',
#  '▁किंतु',
#  '▁युग',
#  '▁पूरे',
#  '▁आकार',
#  '▁राष्ट्र',
#  '▁अंतिम',
#  '▁कोड',
#  '▁पड़ा',
#  'निर्देशांक',
#  '▁आई',
#  '▁विशिष्ट',
#  '▁भूमि',
#  '▁योजना',
#  '▁खेल',
#  'को',
#  '▁परिवर्तन',
#  '▁व्यापार',
#  '▁दर्शन',
#  '▁बल',
#  '▁and',
#  '▁बी',
#  '▁स्पष्ट',
#  '▁14',
#  '▁जाति',
#  '▁प्रयास',
#  '▁दर',
#  '▁राजनीतिक',
#  '▁राष्ट्रपति',
#  'म्',
#  'थ',
#  'ed',
#  '▁क्षमता',
#  '▁हिन्दू',
#  '▁कार्यक्रम',
#  '▁एशिया',
#  '▁लाल',
#  '▁म',
#  '▁डी',
#  '▁शुरुआत',
#  '▁11',
#  '▁धार्मिक',
#  '▁संबंधित',
#  'मी',
#  '▁लोकप्रिय',
#  '▁=',
#  '▁प्रवेश',
#  '्य',
#  '▁सं',
#  '▁आता',
#  '▁रखने',
#  '▁सके',
#  '▁18',
#  '▁यूरोप',
#  '▁शक',
#  '▁शिव',
#  '▁माता',
#  '▁उद्देश्य',
#  '▁आवश्यकता',
#  '▁खोज',
#  '▁श्रेणी',
#  '▁दूरी',
#  '▁बजे',
#  '▁नियंत्रण',
#  '▁दूसरा',
#  '▁लेने',
#  '▁ट्रेन',
#  '▁विस्तार',
#  '▁प्रतिशत',
#  '▁in',
#  '▁विधि',
#  '▁हिंदी',
#  '▁ऐतिहासिक',
#  '▁इन्हें',
#  '▁पदार्थ',
#  '▁रेल',
#  '▁बैंक',
#  'वाद',
#  '▁मीटर',
#  'एँ',
#  '▁आया',
#  '▁इन्होंने',
#  '▁व्यापक',
#  '▁विशाल',
#  'रे',
#  '▁दिखाई',
#  '▁2008',
#  '▁ओ',
#  '▁रह',
#  '▁कांग्रेस',
#  '▁30',
#  '▁प्रस्तुत',
#  '▁13',
#  '▁आबादी',
#  '▁सा',
#  '▁द्वितीय',
#  'सा',
#  '▁प्राकृतिक',
#  '▁शैली',
#  '▁जिन्हें',
#  '▁प्रदर्शित',
#  '▁जनता',
#  '▁सुरक्षा',
#  '▁कृष्ण',
#  '▁संस्थान',
#  '▁लाख',
#  '▁मन',
#  '▁मई',
#  '▁जनवरी',
#  '▁निम्न',
#  '▁वैज्ञानिक',
#  '▁2007',
#  '▁दिए',
#  '▁संस्कृति',
#  '▁इनकी',
#  '▁बौद्ध',
#  '▁य',
#  '▁दल',
#  '▁विवाह',
#  '▁बनाए',
#  'वे',
#  '▁क्रिया',
#  '▁स्थल',
#  '▁खिलाफ',
#  'फ',
#  '▁स्कूल',
#  '▁बताया',
#  '▁ऊर्जा',
#  '▁उल्लेख',
#  'बा',
#  '▁संस्करण',
#  '▁वजह',
#  '▁सामने',
#  '▁गांधी',
#  'एस',
#  '▁मिली',
#  'पर',
#  '▁अल',
#  '▁जाए',
#  '▁सहित',
#  'इ',
#  '▁अंतर्गत',
#  '▁a',
#  'यों',
#  '▁परन्तु',
#  '▁.',
#  '▁पुस्तक',
#  '▁समाप्त',
#  '▁पुराने',
#  '▁पैदा',
#  '▁व्यवहार',
#  '▁हाथ',
#  'स्',
#  '▁स्वतंत्रता',
#  '▁नेतृत्व',
#  '▁निर्मित',
#  '▁सम्मानित',
#  '▁रक्त',
#  '▁देव',
#  '▁मार्च',
#  '▁परंतु',
#  '▁पड़ता',
#  '▁भीतर',
#  'दा',
#  '▁अफ्रीका',
#  '▁घोषणा',
#  '▁चला',
#  'आ',
#  '▁दिशा',
#  '▁उद्योग',
#  '▁2009',
#  '▁च',
#  '▁कुमाऊँ',
#  '▁कवि',
#  '▁समर्थन',
#  '▁परिणाम',
#  '▁ब',
#  '▁स्वीकार',
#  '▁अप्रैल',
#  '▁मैं',
#  '▁देवी',
#  '▁पहचान',
#  '▁अवस्था',
#  '4',
#  '▁सफल',
#  '|',
#  '▁जून',
#  '▁प्रचलित',
#  '▁पर्वत',
#  '▁जानकारी',
#  '▁किन्तु',
#  '▁वंश',
#  '▁देती',
#  'एं',
#  '▁तहत',
#  'वर',
#  'िका',
#  '▁जिसकी',
#  '▁अरब',
#  'ख',
#  '▁दक्षिणी',
#  '*',
#  '▁बाल',
#  '▁लगता',
#  '▁महत्व',
#  '▁स्वतंत्र',
#  '▁प',
#  '▁किमी',
#  'गा',
#  '▁यही',
#  '▁महान',
#  '▁दिनों',
#  '▁पत्र',
#  '3',
#  '▁जुलाई',
#  '▁ना',
#  '▁मदद',
#  '▁छोटी',
#  '▁नि',
#  '▁भाई',
#  '▁चिकित्सा',
#  '▁महिला',
#  '▁पांच',
#  '▁इंग्लैंड',
#  '▁to',
#  '▁2006',
#  '▁जीव',
#  '▁लाभ',
#  '▁श्रृंखला',
#  '▁बंद',
#  '▁उपचार',
#  '▁कमी',
#  '▁मौजूद',
#  '▁19',
#  '▁अगस्त',
#  '▁मिलती',
#  '▁एस',
#  '▁हवाई',
#  '▁अक्टूबर',
#  '▁गुरु',
#  '▁जनगणना',
#  '▁भागों',
#  '▁विधान',
#  '▁शासक',
#  '▁आरम्भ',
#  '▁फ्रांस',
#  'साथ',
#  'जा',
#  '▁चीनी',
#  '▁25',
#  '▁भाषाओं',
#  '5',
#  '▁मुस्लिम',
#  '▁एम',
#  '▁मान',
#  '▁जिसने',
#  '▁अगर',
#  '▁कृषि',
#  '▁निम्नलिखित',
#  '▁मानते',
#  '▁करोड़',
#  '▁सात',
#  'ीकरण',
#  '▁योगदान',
#  '▁समुदाय',
#  '▁कहानी',
#  '▁बंगाल',
#  '▁मनुष्य',
#  '▁मत',
#  '▁परीक्षण',
#  '▁पीछे',
#  '▁अध्यक्ष',
#  '▁अंग',
#  '▁वस्तु',
#  'कार',
#  '▁समुद्र',
#  '▁राज्यों',
#  '▁उनमें',
#  '▁केन्द्र',
#  '▁संविधान',
#  '▁कानून',
#  '▁इ',
#  '▁अंतर',
#  '▁विमानक्षेत्र',
#  '▁सागर',
#  'रो',
#  '▁सरकारी',
#  '▁गांव',
#  '▁क्या',
#  '▁बढ़',
#  '▁बल्कि',
#  '▁वापस',
#  '▁मेल',
#  'दार',
#  '▁सर',
#  '▁सुधार',
#  '▁जैसा',
#  '▁संचालित',
#  '▁मैच',
#  'पी',
#  '▁अनुसंधान',
#  '▁हाल',
#  '▁महा',
#  '▁रक्षा',
#  '▁लेखक',
#  '▁पाए',
#  '▁जन',
#  '▁आरंभ',
#  'ियाँ',
#  '▁शब्दों',
#  '▁गैर',
#  '▁सूची',
#  '▁जैसी',
#  '▁आयोजित',
#  '▁जैन',
#  '▁चुके',
#  '▁इतन',
#  'न्',
#  '▁प्रयुक्त',
#  '▁मन्दिर',
#  '▁विश्वास',
#  '▁सार्वजनिक',
#  '!',
#  '▁ग्रंथ',
#  '▁भोजन',
#  '▁अत',
#  '▁सहायक',
#  '▁घंटे',
#  'उ',
#  '▁देखने',
#  '▁नेपाल',
#  '▁मिनट',
#  '▁उसमें',
#  '▁गीत',
#  '▁मुंबई',
#  '▁एंड',
#  '▁घटना',
#  '▁कॉलेज',
#  'फ़',
#  '▁ब्रिटेन',
#  '▁मुक्त',
#  '▁चुका',
#  'प्र',
#  '▁औसत',
#  '▁बच्चों',
#  '▁2010',
#  'भारत',
#  '▁सूर्य',
#  'पूर्ण',
#  '▁निर्भर',
#  '▁अतः',
#  '▁छोड़',
#  '▁ज्ञात',
#  'ति',
#  '▁धन',
#  '▁ठीक',
#  '▁दस',
#  '▁विरोध',
#  '▁टी',
#  'वें',
#  '▁बदल',
#  '▁नीति',
#  '▁न्यायालय',
#  '▁निर्णय',
#  '▁पंजाब',
#  '▁सर्वाधिक',
#  'al',
#  '▁त',
#  '▁मान्यता',
#  'सर',
#  '▁नियम',
#  '▁आक्रमण',
#  '▁डिग्री',
#  'मान',
#  '▁अली',
#  '▁स्वास्थ्य',
#  '▁बस',
#  '▁वहां',
#  '▁चल',
#  '▁चरण',
#  'िन',
#  '▁पुलिस',
#  '▁यूरोपीय',
#  '▁निर्वाचन',
#  '▁काव्य',
#  '▁उन्होने',
#  '▁संकेत',
#  '▁विस्तृत',
#  'a',
#  ')',
#  '▁पी',
#  '▁एक्स्प्रेस',
#  '▁सदस्यों',
#  '▁लेख',
#  '▁पक्ष',
#  '▁प्रबंधन',
#  '▁इत्यादि',
#  'राज',
#  '▁अंग्रेज़ी',
#  '▁पे',
#  '▁संसद',
#  '▁गंगा',
#  '▁जाएगा',
#  '▁पाँच',
#  '▁कहीं',
#  'ः',
#  '▁चित्र',
#  '▁एन',
#  'र्स',
#  '▁वायु',
#  '▁कविता',
#  '▁निश्चित',
#  '▁पद्धति',
#  '▁डॉ॰',
#  'n',
#  ...]

# %%
# class HindiVocab():
# #     dummy thing
#     def __init__(self, itos:Collection[str]):
#         self.itos = itos
#         self.stoi = collections.defaultdict(int,{v:k for k,v in enumerate(self.itos)})
#         self.sp = spm.SentencePieceProcessor()
#         self.sp.Load(str(path/"hindi_lm.model"))

#     def numericalize(self, t:Collection[str]) -> List[int]:
#         "Convert a list of tokens `t` to their ids."
#         print(t)
#         return [self.sp.PieceToId(w) for w in t]

# #     Sentence piece has its own separator in tokens i.e _
#     def textify(self, nums:Collection[int], sep='') -> List[str]:
#         "Convert a list of `nums` to their tokens."
#         if isinstance(nums, Text):
#             return nums
#         else:
#             return sep.join([self.sp.IdToPiece(int(i)) for i in nums])

# #     def __getstate__(self):
# #         return {'itos':self.itos}

# #     def __setstate__(self, state:dict):
# #         self.itos = state['itos']
# #         self.stoi = collections.defaultdict(int,{v:k for k,v in enumerate(self.itos)})

#     @classmethod
#     def create(cls, tokens:Tokens, max_vocab:int, min_freq:int) -> 'Vocab':
#         "Create a vocabulary from a set of `tokens`."
#         freq = Counter(p for o in tokens for p in o)
#         itos = [o for o,c in freq.most_common(max_vocab) if c > min_freq]
#         for o in reversed(defaults.text_spec_tok):
#             if o in itos: itos.remove(o)
#             itos.insert(0, o)
#         return cls(itos)

# %%
# 30,000 is the vocab size that we chose in sentencepiece
hindi_vocab = Vocab(itos)

# %%
tokenizer = Tokenizer(tok_func=HindiTokenizer, lang='hi')

# %%
tokenizer.special_cases
# Out:
# ['xxunk', 'xxpad', 'xxbos', 'xxfld', 'xxmaj', 'xxup', 'xxrep', 'xxwrep']

# %%
# data_lm = TextDataBunch.from_folder(path=path/'HindiDataset', tokenizer=tokenizer, vocab=hindi_vocab)

# %%
# %debug

# %%
data_lm = TextLMDataBunch.from_folder(path=path/'HindiDataset', tokenizer=tokenizer, vocab=hindi_vocab)

# %%
data_lm.batch_size
# Out:
# 64

# %%
data_lm.save()

# %%
# data_lm = TextLMDataBunch.load(path/'HindiDataset', 'tmp', bs=bs)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-100-a2ba9ee30aa9> in <module>
# ----> 1 data_lm = TextLMDataBunch.load(path/'HindiDataset', 'tmp', bs=bs)
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/data.py in load(cls, path, cache_name, processor, **kwargs)
#     134         test_ids = np.load(cache_path/f'test_ids.npy') if os.path.isfile(cache_path/f'test_ids.npy') else None
#     135         classes = loadtxt_str(cache_path/'classes.txt') if os.path.isfile(cache_path/'classes.txt') else None
# --> 136         return cls.from_ids(path, vocab, train_ids, valid_ids, test_ids, train_lbls, valid_lbls, classes, processor, **kwargs)
#     137
#     138     @classmethod#TODO: test
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/data.py in from_ids(cls, path, vocab, train_ids, valid_ids, test_ids, train_lbls, valid_lbls, classes, processor, **kwargs)
#     123         if test_ids is not None: src.add_test(TextList(test_ids, vocab, path=path), label=train_lbls[0])
#     124         src.valid.x.processor = ifnone(processor, [TokenizeProcessor(), NumericalizeProcessor(vocab=vocab)])
# --> 125         return src.databunch(**kwargs)
#     126
#     127     @classmethod
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/data_block.py in databunch(self, path, **kwargs)
#     478         "Create an `DataBunch` from self, `path` will override `self.path`, `kwargs` are passed to `DataBunch.create`."
#     479         path = Path(ifnone(path, self.path))
# --> 480         data = self.x._bunch.create(self.train, self.valid, test_ds=self.test, path=path, **kwargs)
#     481         if getattr(self, 'normalize', False):#In case a normalization was serialized
#     482             norm = self.normalize
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/data.py in create(cls, train_ds, valid_ds, test_ds, path, bs, pad_idx, pad_first, no_check, **kwargs)
#     217             sampler = SortSampler(ds.x, key=lengths.__getitem__)
#     218             dataloaders.append(DataLoader(ds, batch_size=bs, sampler=sampler, **kwargs))
# --> 219         return cls(*dataloaders, path=path, collate_fn=collate_fn, no_check=no_check)
#     220
#     221 def open_text(fn:PathOrStr, enc='utf-8'):
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/basic_data.py in __init__(self, train_dl, valid_dl, fix_dl, test_dl, device, tfms, path, collate_fn, no_check)
#      94         self.single_dl = _create_dl(DataLoader(valid_dl.dataset, batch_size=1, num_workers=0))
#      95         self.path = Path(path)
# ---> 96         if not no_check: self.sanity_check()
#      97
#      98     def __repr__(self)->str:
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/basic_data.py in sanity_check(self)
#     210             print(final_message)
#     211             return
# --> 212         idx = next(iter(self.train_dl.batch_sampler))
#     213         samples,fails = [],[]
#     214         for i in idx:
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/torch/utils/data/sampler.py in __iter__(self)
#     158     def __iter__(self):
#     159         batch = []
# --> 160         for idx in self.sampler:
#     161             batch.append(idx)
#     162             if len(batch) == self.batch_size:
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/data.py in __iter__(self)
#      73         sz = self.bs*50
#      74         ck_idx = [idxs[i:i+sz] for i in range(0, len(idxs), sz)]
# ---> 75         sort_idx = np.concatenate([sorted(s, key=self.key, reverse=True) for s in ck_idx])
#      76         sz = self.bs
#      77         ck_idx = [sort_idx[i:i+sz] for i in range(0, len(sort_idx), sz)]
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/data.py in <listcomp>(.0)
#      73         sz = self.bs*50
#      74         ck_idx = [idxs[i:i+sz] for i in range(0, len(idxs), sz)]
# ---> 75         sort_idx = np.concatenate([sorted(s, key=self.key, reverse=True) for s in ck_idx])
#      76         sz = self.bs
#      77         ck_idx = [sort_idx[i:i+sz] for i in range(0, len(sort_idx), sz)]
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/data.py in <lambda>(t)
#     210         datasets = cls._init_ds(train_ds, valid_ds, test_ds)
#     211         collate_fn = partial(pad_collate, pad_idx=pad_idx, pad_first=pad_first)
# --> 212         train_sampler = SortishSampler(datasets[0].x, key=lambda t: len(datasets[0][t][0].data), bs=bs//2)
#     213         train_dl = DataLoader(datasets[0], batch_size=bs//2, sampler=train_sampler, drop_last=True, **kwargs)
#     214         dataloaders = [train_dl]
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/data_block.py in __getitem__(self, idxs)
#     561         idxs = try_int(idxs)
#     562         if isinstance(idxs, numbers.Integral):
# --> 563             if self.item is None: x,y = self.x[idxs],self.y[idxs]
#     564             else:                 x,y = self.item   ,0
#     565             if self.tfms:
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/data_block.py in __getitem__(self, idxs)
#      92     def __getitem__(self,idxs:int)->Any:
#      93         idxs = try_int(idxs)
# ---> 94         if isinstance(idxs, numbers.Integral): return self.get(idxs)
#      95         else: return self.new(self.items[idxs], xtra=index_row(self.xtra, idxs))
#      96
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/data.py in get(self, i)
#     273         if isinstance(o, Text):
#     274             return o
# --> 275         return Text(o, self.vocab.textify(o))
#     276
#     277     def label_for_lm(self, **kwargs):
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/transform.py in textify(self, nums, sep)
#     128     def textify(self, nums:Collection[int], sep=' ') -> List[str]:
#     129         "Convert a list of `nums` to their tokens."
# --> 130         return sep.join([self.itos[i] for i in nums])
#     131
#     132     def __getstate__(self):
#
# ~/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/transform.py in <listcomp>(.0)
#     128     def textify(self, nums:Collection[int], sep=' ') -> List[str]:
#     129         "Convert a list of `nums` to their tokens."
# --> 130         return sep.join([self.itos[i] for i in nums])
#     131
#     132     def __getstate__(self):
#
# IndexError: list index out of range

# %%
data_lm.show_batch()
# Out:
# <table>  <col width='5%'>  <col width='95%'>  <tr>
#     <th>idx</th>
#     <th>text</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>▁x x bo s ▁ज्ञानपीठ ▁पुरस्कार ▁भाल चंद्र ▁ने मा डे ▁भारतीय ▁मराठी ▁लेखक , ▁उपन्यासकार , ▁कवि , ▁समीक्षक ▁तथा ▁शिक्षाविद ▁हैं । ▁1963 ▁में ▁केवल ▁25 ▁वर्ष ▁की ▁आयु ▁में ▁प्रकाशित ▁' कोस ला ' ▁नामक ▁उपन्यास ▁से ▁उन्हें ▁अपार ▁सफलता ▁मिली । ▁सन ▁1991 ▁में ▁उनकी ▁टीका स्वयं वर ▁इस ▁कृति ▁के ▁लिए ▁उन्हें ▁साहित्य ▁अकादमी ▁पुरस्कार ▁से ▁सम्मानित ▁किया ▁गया । ▁उन्हें ▁वर्ष ▁2014 ▁का ▁प्रतिष्ठित</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>ा ▁नामित ▁किया ▁है ▁ओर ुंग ो -1 , ओ रु ंगो -2 , ▁ओर ुंग ो -3 , ▁ओर ुंग ो -4 । ▁व्यक्ति ▁से ▁व्यक्ति ▁अरब ो ▁विश ाणु ▁के ▁संचरण ▁आम ▁नहीं ▁है , ▁लेकिन ▁हो ▁सकता ▁है । ▁रक्ताधान , ▁अंग ▁प्रत्यारोपण , ▁और ▁रक्त ▁उत्पादों ▁के ▁उपयोग ▁अरब ो ▁विश ाणु ▁हस्तांतरित ▁कर ▁सकते ▁हैं , ▁तो ▁वायरस ▁दाता ▁के ▁रक्त ▁या ▁अंगों ▁में ▁मौजूद</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>▁लगे ▁तो ▁लंबे , ▁सँकर े , ▁डा ँ ड़ों ▁से ▁चलने ▁और ▁सरलता ▁से ▁इधर - उधर ▁घूमने वाले ▁जहाज ▁बनाए ▁गए । ▁माल ▁ढोने वाले , ▁या ▁व्यापारी ▁जहाज ▁चौड़े , ▁गहरे ▁और ▁पाल ▁से ▁यात्रा ▁करनेवाले ▁होते ▁थे । ▁इनकी ▁चाल ▁मंद ▁होती ▁थी ▁और ▁इनको ▁घुमाने ▁में ▁देर ▁लगती ▁थी । ▁इन ▁जहाजों ▁में ▁डा ँ ड़ों ▁का ▁उपयोग ▁सहायता कारी ▁होता ▁था । ▁साधारणत :</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>ल्म िन िक ▁अम्ल ▁की ▁गंध ▁बहुत ▁कुछ ▁हाइड्रो साय निक ▁अम्ल ▁के ▁समान ▁होती ▁है । ▁यह ▁अम्ल ▁एवं ▁इसके ▁लवण ▁बहुत ▁विषैले ▁होते ▁हैं । ▁फ़ ल्म िन िक ▁अम्ल ▁के ▁लवण ▁व्यापारिक ▁दृष्टि ▁से ▁महत्व ▁के ▁हैं । ▁इसका ▁पारद ▁लवण ▁2 h 2 o ) ▁प्रारंभिक ▁विस्फोटक ▁एवं ▁अन्य ▁विस्फोटक ों ▁के ▁बनाने ▁में ▁प्रयुक्त ▁होता ▁है । ▁पारद ▁का ▁फ़ ल् मिनेट ▁आघात , ▁घर्षण</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>▁का ▁नोबेल ▁पुरस्कार ▁प्राप्त ▁नहीं ▁हुआ , ▁हालाँकि ▁उनको ▁1937 ▁से ▁1948 ▁के ▁बीच , ▁पाँच ▁बार ▁मनोनीत ▁किया ▁गया ▁जिसमे ▁अमेरिकन ▁फ्रेंड्स ▁सर्विस ▁कमिटी ▁द्वारा ▁दिया ▁गया ▁नामांकन ▁भी ▁शामिल ▁है ▁. ▁दशक ो ▁उपरांत ▁नोबेल ▁समिति ▁ने ▁सार्वज ानिक ▁रूप ▁में ▁यह ▁घोषित ▁किया ▁कि ▁उन्हें ▁अपनी ▁इस ▁भूल ▁पर ▁खेद ▁है ▁और ▁यह ▁स्वीकार ▁किया ▁कि ▁पुरूस्कार ▁न ▁देने ▁की ▁वजह ▁विभाजित ▁राष्ट्रीय ▁विचार ▁थे । ▁महात्मा</th>
#   </tr>
# </table>

# %%
??language_model_learner

# %%
len(data_lm.vocab.itos)
# Out:
# 30000

# %%
data_lm.vocab.stoi
# Out:
# defaultdict(int,
#             {'<unk>': 0,
#              '<s>': 1,
#              '</s>': 2,
#              '▁के': 3,
#              '।': 4,
#              '▁में': 5,
#              '▁है': 6,
#              ',': 7,
#              '▁': 8,
#              '▁की': 9,
#              '▁और': 10,
#              '▁से': 11,
#              '▁का': 12,
#              '▁को': 13,
#              '▁हैं': 14,
#              '▁एक': 15,
#              '▁पर': 16,
#              '.': 17,
#              '-': 18,
#              '▁भी': 19,
#              '▁ने': 20,
#              '▁किया': 21,
#              '▁·': 22,
#              '▁यह': 23,
#              '▁था': 24,
#              '▁लिए': 25,
#              '▁इस': 26,
#              '▁गया': 27,
#              'ों': 28,
#              '▁कि': 29,
#              'ी': 30,
#              '▁जाता': 31,
#              '▁जो': 32,
#              '▁रूप': 33,
#              '▁ही': 34,
#              '▁q': 35,
#              '▁�': 36,
#              '▁कर': 37,
#              '▁हो': 38,
#              '▁करने': 39,
#              '▁तथा': 40,
#              '▁नहीं': 41,
#              '▁द्वारा': 42,
#              '▁या': 43,
#              'X': 44,
#              '▁थे': 45,
#              '▁साथ': 46,
#              '▁•': 47,
#              'ा': 48,
#              '▁भारत': 49,
#              '▁होता': 50,
#              '▁बाद': 51,
#              '▁तक': 52,
#              ':': 53,
#              '▁"': 54,
#              '▁दिया': 55,
#              '▁अपने': 56,
#              '▁थी': 57,
#              '▁हुआ': 58,
#              'न': 59,
#              '▁कुछ': 60,
#              '"': 61,
#              '▁जिला': 62,
#              '�': 63,
#              '▁एवं': 64,
#              '▁इसके': 65,
#              '▁वे': 66,
#              '▁वह': 67,
#              '▁|': 68,
#              "'": 69,
#              '▁नाम': 70,
#              '▁जा': 71,
#              '▁राज्य': 72,
#              '▁समय': 73,
#              '▁होती': 74,
#              '▁करते': 75,
#              '▁हुए': 76,
#              '▁तो': 77,
#              '▁कई': 78,
#              "▁'": 79,
#              '▁अन्य': 80,
#              '▁अधिक': 81,
#              '▁क्षेत्र': 82,
#              '▁कारण': 83,
#              'े': 84,
#              '▁सबसे': 85,
#              '▁प्रकार': 86,
#              '▁होने': 87,
#              'क': 88,
#              '▁सकता': 89,
#              '▁स्थित': 90,
#              'र': 91,
#              '▁उनके': 92,
#              '▁भारतीय': 93,
#              '▁उन्होंने': 94,
#              '▁किसी': 95,
#              '▁वर्ष': 96,
#              '▁जाती': 97,
#              '▁वाले': 98,
#              '▁बहुत': 99,
#              '▁होते': 100,
#              '▁करता': 101,
#              'ता': 102,
#              '▁दो': 103,
#              '▁व': 104,
#              'ं': 105,
#              '▁अपनी': 106,
#              '▁कहा': 107,
#              '▁पूर्व': 108,
#              '▁पहले': 109,
#              '▁गए': 110,
#              '▁इन': 111,
#              '▁हुई': 112,
#              '▁जैसे': 113,
#              '▁जब': 114,
#              '▁ये': 115,
#              '▁कम': 116,
#              'ल': 117,
#              'स': 118,
#              '▁/': 119,
#              '▁गई': 120,
#              'ो': 121,
#              '▁न': 122,
#              '▁लेकिन': 123,
#              'म': 124,
#              '▁उन्हें': 125,
#              '▁आदि': 126,
#              '▁अनुसार': 127,
#              '▁भाषा': 128,
#              '▁इसका': 129,
#              '▁प्राप्त': 130,
#              '▁रहे': 131,
#              '▁उत्तर': 132,
#              '▁लिये': 133,
#              '▁-': 134,
#              '▁रहा': 135,
#              '▁शामिल': 136,
#              ';': 137,
#              '▁उसके': 138,
#              '▁सभी': 139,
#              '▁जाने': 140,
#              '▁इसे': 141,
#              '▁बीच': 142,
#              '▁तरह': 143,
#              '▁उस': 144,
#              '▁लिया': 145,
#              '▁गाँव': 146,
#              '▁जाते': 147,
#              '▁उनकी': 148,
#              '▁कोई': 149,
#              '▁प्रमुख': 150,
#              '▁भाग': 151,
#              '▁प्रयोग': 152,
#              '▁जिले': 153,
#              '्स': 154,
#              'ित': 155,
#              '▁देश': 156,
#              '▁कार्य': 157,
#              '▁करना': 158,
#              '▁जिसमें': 159,
#              '▁प्रदेश': 160,
#              '▁मुख्य': 161,
#              '▁यहाँ': 162,
#              '▁निर्माण': 163,
#              '▁ओर': 164,
#              '▁जन्म': 165,
#              '▁दी': 166,
#              '▁लगभग': 167,
#              '▁लोगों': 168,
#              'ने': 169,
#              '▁दोनों': 170,
#              'ना': 171,
#              '▁काम': 172,
#              '▁स्थान': 173,
#              '▁उपयोग': 174,
#              '▁उसे': 175,
#              '▁सकते': 176,
#              '▁विश्व': 177,
#              '▁अ': 178,
#              '▁शहर': 179,
#              '▁सरकार': 180,
#              'ियों': 181,
#              '▁इसकी': 182,
#              's': 183,
#              '▁बार': 184,
#              'पुर': 185,
#              '▁विकास': 186,
#              '▁इसी': 187,
#              '▁वाली': 188,
#              '▁दक्षिण': 189,
#              '▁नगर': 190,
#              '▁तीन': 191,
#              '▁आ': 192,
#              'E': 193,
#              '▁केवल': 194,
#              'N': 195,
#              '▁कहते': 196,
#              '▁धर्म': 197,
#              '▁2': 198,
#              'ई': 199,
#              '▁माना': 200,
#              '▁करती': 201,
#              '▁विशेष': 202,
#              '▁फिर': 203,
#              '▁लोग': 204,
#              'ीय': 205,
#              'त': 206,
#              '▁फिल्म': 207,
#              '▁जीवन': 208,
#              '▁प्राचीन': 209,
#              '्': 210,
#              '▁दौरान': 211,
#              '▁अलग': 212,
#              '▁इसमें': 213,
#              '▁मे': 214,
#              '▁1': 215,
#              '▁जिसे': 216,
#              'कर': 217,
#              '▁आधार': 218,
#              'िक': 219,
#              '▁बना': 220,
#              '▁विभिन्न': 221,
#              '°': 222,
#              '▁ई': 223,
#              '▁अब': 224,
#              '▁द': 225,
#              '▁मंदिर': 226,
#              '▁उनका': 227,
#              '▁प्रसिद्ध': 228,
#              '▁जी': 229,
#              '▁प्रति': 230,
#              '▁शब्द': 231,
#              '▁दिन': 232,
#              '▁क्योंकि': 233,
#              '▁राष्ट्रीय': 234,
#              '▁यहां': 235,
#              '▁शुरू': 236,
#              '▁अनेक': 237,
#              '▁काल': 238,
#              '▁पास': 239,
#              '0': 240,
#              '▁रही': 241,
#              '▁संवत': 242,
#              '▁जाना': 243,
#              '▁युद्ध': 244,
#              'ए': 245,
#              '▁अन्तर्गत': 246,
#              '▁बन': 247,
#              '▁तब': 248,
#              '▁अपना': 249,
#              '▁जिसके': 250,
#              '▁हालांकि': 251,
#              '▁ईसा': 252,
#              'ज': 253,
#              '▁अलावा': 254,
#              '▁नदी': 255,
#              '▁व्यक्ति': 256,
#              '▁मध्य': 257,
#              '▁गयी': 258,
#              '▁सन्': 259,
#              '▁महत्वपूर्ण': 260,
#              '▁राजा': 261,
#              'द': 262,
#              '▁जल': 263,
#              'ि': 264,
#              '▁मूल': 265,
#              '▁बड़े': 266,
#              '▁संख्या': 267,
#              '▁कभी': 268,
#              'ट': 269,
#              '▁विज्ञान': 270,
#              '/': 271,
#              '▁अध्ययन': 272,
#              '▁उन': 273,
#              '▁ले': 274,
#              '▁साल': 275,
#              '▁प्रथम': 276,
#              '▁किए': 277,
#              '▁ए': 278,
#              '▁the': 279,
#              '▁नामक': 280,
#              '▁हिन्दी': 281,
#              'ओं': 282,
#              'प': 283,
#              '▁साहित्य': 284,
#              'व': 285,
#              '▁प्रदान': 286,
#              '▁सकती': 287,
#              '▁जिसका': 288,
#              '▁अमेरिका': 289,
#              '▁दूसरे': 290,
#              'ते': 291,
#              '▁प्रभाव': 292,
#              '▁उसकी': 293,
#              '▁जबकि': 294,
#              '▁चाहिए': 295,
#              '▁शिक्षा': 296,
#              '▁तौर': 297,
#              '▁वाला': 298,
#              '▁गये': 299,
#              '▁आम': 300,
#              '▁कुल': 301,
#              '▁अर्थ': 302,
#              '▁स्थापित': 303,
#              '▁दिल्ली': 304,
#              '▁हर': 305,
#              'ब': 306,
#              '▁:': 307,
#              '▁ऐसे': 308,
#              '▁उच्च': 309,
#              '▁सिंह': 310,
#              '▁बड़ा': 311,
#              '▁बड़ी': 312,
#              '▁संयुक्त': 313,
#              '▁बात': 314,
#              '▁ऐसा': 315,
#              '▁चार': 316,
#              '▁स्थापना': 317,
#              '▁आज': 318,
#              '▁पहली': 319,
#              '▁तहसील': 320,
#              '▁मण्डल': 321,
#              '▁देने': 322,
#              '▁अथवा': 323,
#              '▁देशों': 324,
#              '▁वर्तमान': 325,
#              '▁बनाया': 326,
#              '▁इतिहास': 327,
#              '▁किये': 328,
#              '▁यदि': 329,
#              '▁रखा': 330,
#              '▁काफी': 331,
#              '▁समूह': 332,
#              '▁विश्वविद्यालय': 333,
#              'य': 334,
#              'जी': 335,
#              'सी': 336,
#              '▁जिससे': 337,
#              '▁of': 338,
#              'िया': 339,
#              '▁करके': 340,
#              'नी': 341,
#              'ती': 342,
#              '▁स्थिति': 343,
#              '▁उसने': 344,
#              '▁सी': 345,
#              'रा': 346,
#              '▁बनाने': 347,
#              '▁बारे': 348,
#              '▁प्रत्येक': 349,
#              '▁रंग': 350,
#              '▁वर्षों': 351,
#              '▁लेकर': 352,
#              '▁इनके': 353,
#              '▁स्तर': 354,
#              'वीं': 355,
#              '▁सेना': 356,
#              '▁10': 357,
#              'री': 358,
#              'ें': 359,
#              '▁श्री': 360,
#              '▁क्षेत्रों': 361,
#              '▁उसका': 362,
#              '▁स': 363,
#              'का': 364,
#              '▁उपलब्ध': 365,
#              '▁शरीर': 366,
#              '▁सभा': 367,
#              '▁अधिकांश': 368,
#              '▁सामाजिक': 369,
#              '▁वर्ग': 370,
#              '2': 371,
#              '▁दे': 372,
#              '▁लगा': 373,
#              '▁सेवा': 374,
#              '▁रहता': 375,
#              'श': 376,
#              '▁3': 377,
#              '▁दूर': 378,
#              '▁सदस्य': 379,
#              '▁माध्यम': 380,
#              '▁देता': 381,
#              'ु': 382,
#              'ज़': 383,
#              '▁उत्पन्न': 384,
#              '▁इससे': 385,
#              '▁फ़िल्म': 386,
#              '▁15': 387,
#              '▁दुनिया': 388,
#              '▁इस्तेमाल': 389,
#              'िंग': 390,
#              '▁8': 391,
#              '▁जहां': 392,
#              '▁ब्रिटिश': 393,
#              'ड': 394,
#              '▁जहाँ': 395,
#              '▁इसलिए': 396,
#              '▁पानी': 397,
#              'ली': 398,
#              '▁समाज': 399,
#              '▁मानव': 400,
#              '▁अंत': 401,
#              '▁समान': 402,
#              '▁परिवार': 403,
#              '▁पाकिस्तान': 404,
#              '▁शक्ति': 405,
#              '▁संगीत': 406,
#              '▁प्रणाली': 407,
#              'ग': 408,
#              '▁संघ': 409,
#              '▁5': 410,
#              '▁होगा': 411,
#              '▁पुरस्कार': 412,
#              '▁आधुनिक': 413,
#              '▁सामान्य': 414,
#              'या': 415,
#              '▁थीं': 416,
#              '▁आगे': 417,
#              '▁बने': 418,
#              '▁छोटे': 419,
#              '▁अतिरिक्त': 420,
#              '▁उदाहरण': 421,
#              '▁होकर': 422,
#              '▁रहते': 423,
#              '▁अधिकार': 424,
#              'ला': 425,
#              'ण': 426,
#              '▁स्टेशन': 427,
#              '▁शासन': 428,
#              '▁चीन': 429,
#              '▁जिनमें': 430,
#              '▁क': 431,
#              '▁4': 432,
#              'ह': 433,
#              '▁जिस': 434,
#              'ंग': 435,
#              '▁‘': 436,
#              '▁16': 437,
#              '▁भूमिका': 438,
#              '▁देते': 439,
#              '▁शताब्दी': 440,
#              '▁जारी': 441,
#              '▁विकसित': 442,
#              '▁ज्ञान': 443,
#              '▁पिता': 444,
#              '▁मृत्यु': 445,
#              '▁बाहर': 446,
#              '▁कंपनी': 447,
#              '’': 448,
#              '▁ली': 449,
#              '▁पश्चिम': 450,
#              '▁प्रकाशित': 451,
#              '▁रेलवे': 452,
#              '▁कला': 453,
#              'के': 454,
#              '▁प्रकाश': 455,
#              '▁राजधानी': 456,
#              '▁7': 457,
#              '▁ध्यान': 458,
#              '▁मात्रा': 459,
#              '▁संबंध': 460,
#              '▁विचार': 461,
#              '▁उत्तराखण्ड': 462,
#              '▁आधारित': 463,
#              '▁ऑफ': 464,
#              '▁बनी': 465,
#              '▁ऊपर': 466,
#              '▁आप': 467,
#              '▁20': 468,
#              'की': 469,
#              '▁पद': 470,
#              '▁बिहार': 471,
#              '▁देखा': 472,
#              'ओ': 473,
#              '▁चुनाव': 474,
#              '▁सब': 475,
#              '▁पता': 476,
#              '▁6': 477,
#              '▁पहला': 478,
#              '▁घर': 479,
#              '▁प्रक्रिया': 480,
#              '▁पूरी': 481,
#              '▁नए': 482,
#              '▁मार्ग': 483,
#              '▁उत्तरी': 484,
#              '▁विषय': 485,
#              '़': 486,
#              '▁स्वयं': 487,
#              '▁इनमें': 488,
#              '▁रचना': 489,
#              '▁राज': 490,
#              'च': 491,
#              '▁रोग': 492,
#              '▁तैयार': 493,
#              '▁नीचे': 494,
#              '▁भगवान': 495,
#              'वा': 496,
#              '▁12': 497,
#              '▁ऐसी': 498,
#              '▁यात्रा': 499,
#              '▁जनसंख्या': 500,
#              '▁साम्राज्य': 501,
#              '▁पश्चिमी': 502,
#              '▁17': 503,
#              '▁दृष्टि': 504,
#              '▁होना': 505,
#              '▁भिन्न': 506,
#              '▁दशक': 507,
#              '▁दूसरी': 508,
#              '▁सहायता': 509,
#              '▁सीमा': 510,
#              '▁उत्पादन': 511,
#              '▁अक्सर': 512,
#              '▁पृथ्वी': 513,
#              '▁किलोमीटर': 514,
#              '▁व्यवस्था': 515,
#              'बी': 516,
#              '▁मिला': 517,
#              '▁सिद्धांत': 518,
#              '▁वहाँ': 519,
#              '▁स्': 520,
#              '▁भर': 521,
#              '▁हिस्सा': 522,
#              '▁आने': 523,
#              '1': 524,
#              '▁जगह': 525,
#              '▁आवश्यक': 526,
#              '▁पुत्र': 527,
#              '▁टीम': 528,
#              '▁लिखा': 529,
#              '▁राम': 530,
#              '▁सन': 531,
#              '▁आर्थिक': 532,
#              '▁पार्टी': 533,
#              'मा': 534,
#              '▁हेतु': 535,
#              'टी': 536,
#              '▁उप': 537,
#              '▁लगे': 538,
#              '▁बिना': 539,
#              '▁पूर्वी': 540,
#              '▁वो': 541,
#              'वी': 542,
#              '▁तुलना': 543,
#              'ू': 544,
#              '▁पाया': 545,
#              '▁विभाग': 546,
#              '▁ज्यादा': 547,
#              '▁9': 548,
#              'अ': 549,
#              'ले': 550,
#              '▁सदी': 551,
#              '▁गति': 552,
#              '▁लोक': 553,
#              '▁इनका': 554,
#              '▁संगठन': 555,
#              '▁रहती': 556,
#              '▁नई': 557,
#              '▁पूरा': 558,
#              '▁द्वीप': 559,
#              '▁मिलता': 560,
#              '▁अंग्रेजी': 561,
#              '▁अभी': 562,
#              '▁उसी': 563,
#              '▁पूर्ण': 564,
#              '▁केंद्र': 565,
#              'से': 566,
#              '▁प्रदर्शन': 567,
#              '▁रहने': 568,
#              'डी': 569,
#              '▁वि': 570,
#              '▁सु': 571,
#              '▁वृद्धि': 572,
#              '▁अवधि': 573,
#              '▁संस्कृत': 574,
#              '▁क्रिकेट': 575,
#              '▁स्थानीय': 576,
#              '▁प्र': 577,
#              '▁आते': 578,
#              '▁वर्णन': 579,
#              '▁अंतर्राष्ट्रीय': 580,
#              '▁मिल': 581,
#              '▁ऑफ़': 582,
#              '▁अमेरिकी': 583,
#              '▁प्रभावित': 584,
#              '▁हम': 585,
#              '▁किंतु': 586,
#              '▁युग': 587,
#              '▁पूरे': 588,
#              '▁आकार': 589,
#              '▁राष्ट्र': 590,
#              '▁अंतिम': 591,
#              '▁कोड': 592,
#              '▁पड़ा': 593,
#              'निर्देशांक': 594,
#              '▁आई': 595,
#              '▁विशिष्ट': 596,
#              '▁भूमि': 597,
#              '▁योजना': 598,
#              '▁खेल': 599,
#              'को': 600,
#              '▁परिवर्तन': 601,
#              '▁व्यापार': 602,
#              '▁दर्शन': 603,
#              '▁बल': 604,
#              '▁and': 605,
#              '▁बी': 606,
#              '▁स्पष्ट': 607,
#              '▁14': 608,
#              '▁जाति': 609,
#              '▁प्रयास': 610,
#              '▁दर': 611,
#              '▁राजनीतिक': 612,
#              '▁राष्ट्रपति': 613,
#              'म्': 614,
#              'थ': 615,
#              'ed': 616,
#              '▁क्षमता': 617,
#              '▁हिन्दू': 618,
#              '▁कार्यक्रम': 619,
#              '▁एशिया': 620,
#              '▁लाल': 621,
#              '▁म': 622,
#              '▁डी': 623,
#              '▁शुरुआत': 624,
#              '▁11': 625,
#              '▁धार्मिक': 626,
#              '▁संबंधित': 627,
#              'मी': 628,
#              '▁लोकप्रिय': 629,
#              '▁=': 630,
#              '▁प्रवेश': 631,
#              '्य': 632,
#              '▁सं': 633,
#              '▁आता': 634,
#              '▁रखने': 635,
#              '▁सके': 636,
#              '▁18': 637,
#              '▁यूरोप': 638,
#              '▁शक': 639,
#              '▁शिव': 640,
#              '▁माता': 641,
#              '▁उद्देश्य': 642,
#              '▁आवश्यकता': 643,
#              '▁खोज': 644,
#              '▁श्रेणी': 645,
#              '▁दूरी': 646,
#              '▁बजे': 647,
#              '▁नियंत्रण': 648,
#              '▁दूसरा': 649,
#              '▁लेने': 650,
#              '▁ट्रेन': 651,
#              '▁विस्तार': 652,
#              '▁प्रतिशत': 653,
#              '▁in': 654,
#              '▁विधि': 655,
#              '▁हिंदी': 656,
#              '▁ऐतिहासिक': 657,
#              '▁इन्हें': 658,
#              '▁पदार्थ': 659,
#              '▁रेल': 660,
#              '▁बैंक': 661,
#              'वाद': 662,
#              '▁मीटर': 663,
#              'एँ': 664,
#              '▁आया': 665,
#              '▁इन्होंने': 666,
#              '▁व्यापक': 667,
#              '▁विशाल': 668,
#              'रे': 669,
#              '▁दिखाई': 670,
#              '▁2008': 671,
#              '▁ओ': 672,
#              '▁रह': 673,
#              '▁कांग्रेस': 674,
#              '▁30': 675,
#              '▁प्रस्तुत': 676,
#              '▁13': 677,
#              '▁आबादी': 678,
#              '▁सा': 679,
#              '▁द्वितीय': 680,
#              'सा': 681,
#              '▁प्राकृतिक': 682,
#              '▁शैली': 683,
#              '▁जिन्हें': 684,
#              '▁प्रदर्शित': 685,
#              '▁जनता': 686,
#              '▁सुरक्षा': 687,
#              '▁कृष्ण': 688,
#              '▁संस्थान': 689,
#              '▁लाख': 690,
#              '▁मन': 691,
#              '▁मई': 692,
#              '▁जनवरी': 693,
#              '▁निम्न': 694,
#              '▁वैज्ञानिक': 695,
#              '▁2007': 696,
#              '▁दिए': 697,
#              '▁संस्कृति': 698,
#              '▁इनकी': 699,
#              '▁बौद्ध': 700,
#              '▁य': 701,
#              '▁दल': 702,
#              '▁विवाह': 703,
#              '▁बनाए': 704,
#              'वे': 705,
#              '▁क्रिया': 706,
#              '▁स्थल': 707,
#              '▁खिलाफ': 708,
#              'फ': 709,
#              '▁स्कूल': 710,
#              '▁बताया': 711,
#              '▁ऊर्जा': 712,
#              '▁उल्लेख': 713,
#              'बा': 714,
#              '▁संस्करण': 715,
#              '▁वजह': 716,
#              '▁सामने': 717,
#              '▁गांधी': 718,
#              'एस': 719,
#              '▁मिली': 720,
#              'पर': 721,
#              '▁अल': 722,
#              '▁जाए': 723,
#              '▁सहित': 724,
#              'इ': 725,
#              '▁अंतर्गत': 726,
#              '▁a': 727,
#              'यों': 728,
#              '▁परन्तु': 729,
#              '▁.': 730,
#              '▁पुस्तक': 731,
#              '▁समाप्त': 732,
#              '▁पुराने': 733,
#              '▁पैदा': 734,
#              '▁व्यवहार': 735,
#              '▁हाथ': 736,
#              'स्': 737,
#              '▁स्वतंत्रता': 738,
#              '▁नेतृत्व': 739,
#              '▁निर्मित': 740,
#              '▁सम्मानित': 741,
#              '▁रक्त': 742,
#              '▁देव': 743,
#              '▁मार्च': 744,
#              '▁परंतु': 745,
#              '▁पड़ता': 746,
#              '▁भीतर': 747,
#              'दा': 748,
#              '▁अफ्रीका': 749,
#              '▁घोषणा': 750,
#              '▁चला': 751,
#              'आ': 752,
#              '▁दिशा': 753,
#              '▁उद्योग': 754,
#              '▁2009': 755,
#              '▁च': 756,
#              '▁कुमाऊँ': 757,
#              '▁कवि': 758,
#              '▁समर्थन': 759,
#              '▁परिणाम': 760,
#              '▁ब': 761,
#              '▁स्वीकार': 762,
#              '▁अप्रैल': 763,
#              '▁मैं': 764,
#              '▁देवी': 765,
#              '▁पहचान': 766,
#              '▁अवस्था': 767,
#              '4': 768,
#              '▁सफल': 769,
#              '|': 770,
#              '▁जून': 771,
#              '▁प्रचलित': 772,
#              '▁पर्वत': 773,
#              '▁जानकारी': 774,
#              '▁किन्तु': 775,
#              '▁वंश': 776,
#              '▁देती': 777,
#              'एं': 778,
#              '▁तहत': 779,
#              'वर': 780,
#              'िका': 781,
#              '▁जिसकी': 782,
#              '▁अरब': 783,
#              'ख': 784,
#              '▁दक्षिणी': 785,
#              '*': 786,
#              '▁बाल': 787,
#              '▁लगता': 788,
#              '▁महत्व': 789,
#              '▁स्वतंत्र': 790,
#              '▁प': 791,
#              '▁किमी': 792,
#              'गा': 793,
#              '▁यही': 794,
#              '▁महान': 795,
#              '▁दिनों': 796,
#              '▁पत्र': 797,
#              '3': 798,
#              '▁जुलाई': 799,
#              '▁ना': 800,
#              '▁मदद': 801,
#              '▁छोटी': 802,
#              '▁नि': 803,
#              '▁भाई': 804,
#              '▁चिकित्सा': 805,
#              '▁महिला': 806,
#              '▁पांच': 807,
#              '▁इंग्लैंड': 808,
#              '▁to': 809,
#              '▁2006': 810,
#              '▁जीव': 811,
#              '▁लाभ': 812,
#              '▁श्रृंखला': 813,
#              '▁बंद': 814,
#              '▁उपचार': 815,
#              '▁कमी': 816,
#              '▁मौजूद': 817,
#              '▁19': 818,
#              '▁अगस्त': 819,
#              '▁मिलती': 820,
#              '▁एस': 821,
#              '▁हवाई': 822,
#              '▁अक्टूबर': 823,
#              '▁गुरु': 824,
#              '▁जनगणना': 825,
#              '▁भागों': 826,
#              '▁विधान': 827,
#              '▁शासक': 828,
#              '▁आरम्भ': 829,
#              '▁फ्रांस': 830,
#              'साथ': 831,
#              'जा': 832,
#              '▁चीनी': 833,
#              '▁25': 834,
#              '▁भाषाओं': 835,
#              '5': 836,
#              '▁मुस्लिम': 837,
#              '▁एम': 838,
#              '▁मान': 839,
#              '▁जिसने': 840,
#              '▁अगर': 841,
#              '▁कृषि': 842,
#              '▁निम्नलिखित': 843,
#              '▁मानते': 844,
#              '▁करोड़': 845,
#              '▁सात': 846,
#              'ीकरण': 847,
#              '▁योगदान': 848,
#              '▁समुदाय': 849,
#              '▁कहानी': 850,
#              '▁बंगाल': 851,
#              '▁मनुष्य': 852,
#              '▁मत': 853,
#              '▁परीक्षण': 854,
#              '▁पीछे': 855,
#              '▁अध्यक्ष': 856,
#              '▁अंग': 857,
#              '▁वस्तु': 858,
#              'कार': 859,
#              '▁समुद्र': 860,
#              '▁राज्यों': 861,
#              '▁उनमें': 862,
#              '▁केन्द्र': 863,
#              '▁संविधान': 864,
#              '▁कानून': 865,
#              '▁इ': 866,
#              '▁अंतर': 867,
#              '▁विमानक्षेत्र': 868,
#              '▁सागर': 869,
#              'रो': 870,
#              '▁सरकारी': 871,
#              '▁गांव': 872,
#              '▁क्या': 873,
#              '▁बढ़': 874,
#              '▁बल्कि': 875,
#              '▁वापस': 876,
#              '▁मेल': 877,
#              'दार': 878,
#              '▁सर': 879,
#              '▁सुधार': 880,
#              '▁जैसा': 881,
#              '▁संचालित': 882,
#              '▁मैच': 883,
#              'पी': 884,
#              '▁अनुसंधान': 885,
#              '▁हाल': 886,
#              '▁महा': 887,
#              '▁रक्षा': 888,
#              '▁लेखक': 889,
#              '▁पाए': 890,
#              '▁जन': 891,
#              '▁आरंभ': 892,
#              'ियाँ': 893,
#              '▁शब्दों': 894,
#              '▁गैर': 895,
#              '▁सूची': 896,
#              '▁जैसी': 897,
#              '▁आयोजित': 898,
#              '▁जैन': 899,
#              '▁चुके': 900,
#              '▁इतन': 901,
#              'न्': 902,
#              '▁प्रयुक्त': 903,
#              '▁मन्दिर': 904,
#              '▁विश्वास': 905,
#              '▁सार्वजनिक': 906,
#              '!': 907,
#              '▁ग्रंथ': 908,
#              '▁भोजन': 909,
#              '▁अत': 910,
#              '▁सहायक': 911,
#              '▁घंटे': 912,
#              'उ': 913,
#              '▁देखने': 914,
#              '▁नेपाल': 915,
#              '▁मिनट': 916,
#              '▁उसमें': 917,
#              '▁गीत': 918,
#              '▁मुंबई': 919,
#              '▁एंड': 920,
#              '▁घटना': 921,
#              '▁कॉलेज': 922,
#              'फ़': 923,
#              '▁ब्रिटेन': 924,
#              '▁मुक्त': 925,
#              '▁चुका': 926,
#              'प्र': 927,
#              '▁औसत': 928,
#              '▁बच्चों': 929,
#              '▁2010': 930,
#              'भारत': 931,
#              '▁सूर्य': 932,
#              'पूर्ण': 933,
#              '▁निर्भर': 934,
#              '▁अतः': 935,
#              '▁छोड़': 936,
#              '▁ज्ञात': 937,
#              'ति': 938,
#              '▁धन': 939,
#              '▁ठीक': 940,
#              '▁दस': 941,
#              '▁विरोध': 942,
#              '▁टी': 943,
#              'वें': 944,
#              '▁बदल': 945,
#              '▁नीति': 946,
#              '▁न्यायालय': 947,
#              '▁निर्णय': 948,
#              '▁पंजाब': 949,
#              '▁सर्वाधिक': 950,
#              'al': 951,
#              '▁त': 952,
#              '▁मान्यता': 953,
#              'सर': 954,
#              '▁नियम': 955,
#              '▁आक्रमण': 956,
#              '▁डिग्री': 957,
#              'मान': 958,
#              '▁अली': 959,
#              '▁स्वास्थ्य': 960,
#              '▁बस': 961,
#              '▁वहां': 962,
#              '▁चल': 963,
#              '▁चरण': 964,
#              'िन': 965,
#              '▁पुलिस': 966,
#              '▁यूरोपीय': 967,
#              '▁निर्वाचन': 968,
#              '▁काव्य': 969,
#              '▁उन्होने': 970,
#              '▁संकेत': 971,
#              '▁विस्तृत': 972,
#              'a': 973,
#              ')': 974,
#              '▁पी': 975,
#              '▁एक्स्प्रेस': 976,
#              '▁सदस्यों': 977,
#              '▁लेख': 978,
#              '▁पक्ष': 979,
#              '▁प्रबंधन': 980,
#              '▁इत्यादि': 981,
#              'राज': 982,
#              '▁अंग्रेज़ी': 983,
#              '▁पे': 984,
#              '▁संसद': 985,
#              '▁गंगा': 986,
#              '▁जाएगा': 987,
#              '▁पाँच': 988,
#              '▁कहीं': 989,
#              'ः': 990,
#              '▁चित्र': 991,
#              '▁एन': 992,
#              'र्स': 993,
#              '▁वायु': 994,
#              '▁कविता': 995,
#              '▁निश्चित': 996,
#              '▁पद्धति': 997,
#              '▁डॉ॰': 998,
#              'n': 999,
#              ...})

# %%
learn = language_model_learner(data_lm, drop_mult=0.3)

# %%
# %debug
# Out:
# > /home/gaurav/anaconda3/envs/fastai-1/lib/python3.6/site-packages/torch/nn/modules/sparse.py(91)__init__()
#      89         if padding_idx is not None:
#      90             if padding_idx > 0:
# ---> 91                 assert padding_idx < self.num_embeddings, 'Padding_idx must be within num_embeddings'
#      92             elif padding_idx < 0:
#      93                 assert padding_idx >= -self.num_embeddings, 'Padding_idx must be within num_embeddings'
#
# ipdb> self.num_embeddings
# 0
# ipdb> u
# > /home/gaurav/anaconda3/envs/fastai-1/lib/python3.6/site-packages/fastai/text/models.py(84)__init__()
#      82         self.bs,self.qrnn,self.ndir = 1, qrnn,(2 if bidir else 1)
#      83         self.emb_sz,self.n_hid,self.n_layers = emb_sz,n_hid,n_layers
# ---> 84         self.encoder = nn.Embedding(vocab_sz, emb_sz, padding_idx=pad_token)
#      85         self.encoder_dp = EmbeddingDropout(self.encoder, embed_p)
#      86         if self.qrnn:
#
# ipdb> vocab_sz
# 0
# ipdb> emb_sz
# 400
# ipdb> q

# %%
gc.collect()
# Out:
# 56

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7))
# Out:
# Total time: 10:44 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>4.583374</th>
#     <th>4.510166</th>
#     <th>0.284611</th>
#   </tr>
# </table>

# %%
learn.save('first', with_opt=True)

# %%
learn.load('first', with_opt=True);

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, 1e-2, moms=(0.8,0.7))
# Out:
# Total time: 53:57 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>4.531020</th>
#     <th>4.600397</th>
#     <th>0.273127</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>4.412257</th>
#     <th>4.545438</th>
#     <th>0.278273</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>4.289746</th>
#     <th>4.330606</th>
#     <th>0.296877</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>3.984632</th>
#     <th>4.101499</th>
#     <th>0.320357</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>3.952471</th>
#     <th>4.020261</th>
#     <th>0.330837</th>
#   </tr>
# </table>

# %%
learn.save('second_hi_lm', with_opt=True)

# %%
learn.load('second_hi_lm', with_opt=True);

# %%
learn.fit_one_cycle(50, 1e-3, moms=(0.8,0.7))
# Out:
# Total time: 9:01:14 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>3.795025</th>
#     <th>4.015812</th>
#     <th>0.331498</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>3.785783</th>
#     <th>4.010739</th>
#     <th>0.332162</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>3.813966</th>
#     <th>4.005096</th>
#     <th>0.332968</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>3.794297</th>
#     <th>3.998023</th>
#     <th>0.334002</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>3.760452</th>
#     <th>3.990803</th>
#     <th>0.335287</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>3.814984</th>
#     <th>3.980825</th>
#     <th>0.336857</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>3.740529</th>
#     <th>3.970397</th>
#     <th>0.338513</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>3.686065</th>
#     <th>3.959991</th>
#     <th>0.340315</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>3.796157</th>
#     <th>3.944941</th>
#     <th>0.342453</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>3.693871</th>
#     <th>3.930822</th>
#     <th>0.344465</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>3.643148</th>
#     <th>3.915772</th>
#     <th>0.346718</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>3.708372</th>
#     <th>3.898594</th>
#     <th>0.349277</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>3.631965</th>
#     <th>3.887406</th>
#     <th>0.351106</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>3.694658</th>
#     <th>3.871791</th>
#     <th>0.353609</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>3.640197</th>
#     <th>3.858117</th>
#     <th>0.355666</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>3.660488</th>
#     <th>3.840567</th>
#     <th>0.358403</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>3.600901</th>
#     <th>3.823602</th>
#     <th>0.361069</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>3.505162</th>
#     <th>3.806640</th>
#     <th>0.363566</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>3.663603</th>
#     <th>3.796405</th>
#     <th>0.365829</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>3.552254</th>
#     <th>3.779457</th>
#     <th>0.368338</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>3.577936</th>
#     <th>3.770793</th>
#     <th>0.369557</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>3.591934</th>
#     <th>3.754148</th>
#     <th>0.372816</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>3.471553</th>
#     <th>3.746699</th>
#     <th>0.373760</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>3.380468</th>
#     <th>3.728380</th>
#     <th>0.376890</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>3.424661</th>
#     <th>3.726033</th>
#     <th>0.377251</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>3.289428</th>
#     <th>3.712467</th>
#     <th>0.379720</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>3.356182</th>
#     <th>3.698744</th>
#     <th>0.382226</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>3.480407</th>
#     <th>3.692361</th>
#     <th>0.383332</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>3.376394</th>
#     <th>3.680634</th>
#     <th>0.385476</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>3.273366</th>
#     <th>3.674285</th>
#     <th>0.387604</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>3.274911</th>
#     <th>3.662539</th>
#     <th>0.389407</th>
#   </tr>
#   <tr>
#     <th>32</th>
#     <th>3.156277</th>
#     <th>3.652551</th>
#     <th>0.390768</th>
#   </tr>
#   <tr>
#     <th>33</th>
#     <th>3.406089</th>
#     <th>3.644308</th>
#     <th>0.391994</th>
#   </tr>
#   <tr>
#     <th>34</th>
#     <th>3.096523</th>
#     <th>3.637095</th>
#     <th>0.393816</th>
#   </tr>
#   <tr>
#     <th>35</th>
#     <th>3.299030</th>
#     <th>3.630367</th>
#     <th>0.394665</th>
#   </tr>
#   <tr>
#     <th>36</th>
#     <th>3.303152</th>
#     <th>3.624498</th>
#     <th>0.395692</th>
#   </tr>
#   <tr>
#     <th>37</th>
#     <th>3.242475</th>
#     <th>3.618684</th>
#     <th>0.396945</th>
#   </tr>
#   <tr>
#     <th>38</th>
#     <th>3.250781</th>
#     <th>3.617028</th>
#     <th>0.397970</th>
#   </tr>
#   <tr>
#     <th>39</th>
#     <th>3.242863</th>
#     <th>3.607447</th>
#     <th>0.399163</th>
#   </tr>
#   <tr>
#     <th>40</th>
#     <th>3.260922</th>
#     <th>3.607255</th>
#     <th>0.400028</th>
#   </tr>
#   <tr>
#     <th>41</th>
#     <th>3.232101</th>
#     <th>3.602268</th>
#     <th>0.400549</th>
#   </tr>
#   <tr>
#     <th>42</th>
#     <th>3.154963</th>
#     <th>3.597780</th>
#     <th>0.401527</th>
#   </tr>
#   <tr>
#     <th>43</th>
#     <th>3.194193</th>
#     <th>3.594461</th>
#     <th>0.401932</th>
#   </tr>
#   <tr>
#     <th>44</th>
#     <th>3.152243</th>
#     <th>3.592574</th>
#     <th>0.402354</th>
#   </tr>
#   <tr>
#     <th>45</th>
#     <th>3.107828</th>
#     <th>3.591086</th>
#     <th>0.402771</th>
#   </tr>
#   <tr>
#     <th>46</th>
#     <th>3.188294</th>
#     <th>3.590571</th>
#     <th>0.402956</th>
#   </tr>
#   <tr>
#     <th>47</th>
#     <th>3.136473</th>
#     <th>3.588930</th>
#     <th>0.403082</th>
#   </tr>
#   <tr>
#     <th>48</th>
#     <th>3.128983</th>
#     <th>3.588563</th>
#     <th>0.403181</th>
#   </tr>
#   <tr>
#     <th>49</th>
#     <th>3.153137</th>
#     <th>3.589152</th>
#     <th>0.403156</th>
#   </tr>
#   <tr>
#     <th>50</th>
#     <th>3.052490</th>
#     <th>3.588458</th>
#     <th>0.403258</th>
#   </tr>
# </table>

# %%
learn.save('third_hi_lm', with_opt=True)

# %%
learn.load('third_hi_lm', with_opt=True);

# %%
TEXT = "जिसके लिये उन्हें "
N_WORDS = 40
N_SENTENCES = 2

# %%
print("\n".join(learn.predict(TEXT, N_WORDS, temperature=0.75) for _ in range(N_SENTENCES)))
# Out:
# जिसके लिये उन्हें  ▁अत्यधिक ▁सम्मान ▁मिला , कार्य वाहक ▁अधिकारियों ▁ने ▁भी ▁उनकी ▁कई ▁सेवा यें ▁हासिल ▁की ं ▁साथ ▁ही ▁उसको ▁अपने ▁पिता ▁के ▁मुख्य ▁कार्य ▁और ▁नाना ▁पाट े कार ▁में ▁अपने ▁साथी ▁के ▁साथ ▁रहने ▁का ▁मौका ▁मिला ▁ ▁और
# जिसके लिये उन्हें  ▁विभिन्न ▁सम्मान ▁दिए ▁गए , ये ▁सभी ▁पुरस्कार ▁उन्हें ▁प्रदान ▁करते ▁हैं ▁| ▁कई ▁पुरस्कार ▁प्राप्त ▁किये ▁जा ▁चुके ▁हैं ▁| 19 ▁वीं ▁शताब्दी ▁के ▁शुरुआती ▁दशकों ▁में ▁आधुनिक ▁मानव ▁संसाधन ो ▁के ▁रूप ▁में , विकास ▁आज ▁भी ▁चल

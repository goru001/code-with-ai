# %%
from fastai.text import *
import numpy as np
from sklearn.model_selection import train_test_split
import pickle
import sentencepiece as spm
import re
import pdb

# %%
import fastai, torch
fastai.__version__ , torch.__version__
# Out:
# ('1.0.40', '1.0.0')

# %%
torch.cuda.set_device(0)

# %%
path = Path('/home/gaurav/Downloads/HindiClassificationModel-2')

# %%
df_train = pd.read_csv(path/'bbc-hindiv01'/'hindi-train.csv', sep="\t", encoding='utf-8', header=None)
df_train.head()
# Out:
#           0                                                  1
# 0     india  मेट्रो की इस लाइन के चलने से दक्षिणी दिल्ली से...
# 1  pakistan  नेटिजन यानि इंटरनेट पर सक्रिय नागरिक अब ट्विटर...
# 2      news  इसमें एक फ़्लाइट एटेनडेंट की मदद की गुहार है औ...
# 3     india  प्रतीक खुलेपन का, आज़ाद ख्याली का और भीड़ से अ...
# 4     india  ख़ासकर पिछले 10 साल तक प्रधानमंत्री रहे मनमोहन...

# %%
df_test = pd.read_csv(path/'bbc-hindiv01'/'hindi-test.csv', sep="\t", encoding='utf-8', header=None)
df_test.head()
# Out:
#                0                                                  1
# 0          india  बुधवार को राज्य सभा में विपक्ष के सवालों के जव...
# 1          india  लखनऊ स्थित पत्रकार समीरात्मज मिश्र को बुलंदशहर...
# 2          india  लगभग 1300 हेक्टेयर ज़मीन का अधिग्रहण किया जा च...
# 3  international  हालांकि उनके अंगरक्षकों को बमों को जाम करने वा...
# 4          india  आयोग का कहना है कि इस तरह के परीक्षण से महिलाओ...

# %%
all_classes = df_train[0].unique()

# %%
for c in all_classes:
    print(c, (df_train[0] == c).sum())
# Out:
# india 1390
# pakistan 43
# news 230
# international 904
# entertainment 285
# sport 258
# science 194
# china 14
# learningenglish 5
# social 18
# southasia 42
# business 54
# institutional 19
# multimedia 12

# %%
df_train.shape, df_test.shape
# Out:
# ((3468, 2), (867, 2))

# %%
df_train[df_train[1].isnull()]
# Out:
#          0    1
# 718  india  NaN

# %%
df_train = df_train.dropna()

# %%
df_test[df_test[1].isnull()]
# Out:
#          0    1
# 265  sport  NaN

# %%
df_test = df_test.dropna()

# %%
label_cols = [0]

# %%
class HindiTokenizer(BaseTokenizer):
    def __init__(self, lang:str):
        self.lang = lang
        self.sp = spm.SentencePieceProcessor()
        self.sp.Load(str('/home/gaurav/Downloads/LanguageModel/hindi_lm.model'))
        
    def tokenizer(self, t:str) -> List[str]:
        return self.sp.EncodeAsPieces(t)

# %%
sp = spm.SentencePieceProcessor()
sp.Load('/home/gaurav/Downloads/LanguageModel/hindi_lm.model')
itos = [sp.IdToPiece(int(i)) for i in range(30000)]

# %%
itos
# Out:
# ['<unk>',
#  '<s>',
#  '</s>',
#  '▁के',
#  '।',
#  '▁में',
#  '▁है',
#  ',',
#  '▁',
#  '▁की',
#  '▁और',
#  '▁से',
#  '▁का',
#  '▁को',
#  '▁हैं',
#  '▁एक',
#  '▁पर',
#  '.',
#  '-',
#  '▁भी',
#  '▁ने',
#  '▁किया',
#  '▁·',
#  '▁यह',
#  '▁था',
#  '▁लिए',
#  '▁इस',
#  '▁गया',
#  'ों',
#  '▁कि',
#  'ी',
#  '▁जाता',
#  '▁जो',
#  '▁रूप',
#  '▁ही',
#  '▁q',
#  '▁�',
#  '▁कर',
#  '▁हो',
#  '▁करने',
#  '▁तथा',
#  '▁नहीं',
#  '▁द्वारा',
#  '▁या',
#  'X',
#  '▁थे',
#  '▁साथ',
#  '▁•',
#  'ा',
#  '▁भारत',
#  '▁होता',
#  '▁बाद',
#  '▁तक',
#  ':',
#  '▁"',
#  '▁दिया',
#  '▁अपने',
#  '▁थी',
#  '▁हुआ',
#  'न',
#  '▁कुछ',
#  '"',
#  '▁जिला',
#  '�',
#  '▁एवं',
#  '▁इसके',
#  '▁वे',
#  '▁वह',
#  '▁|',
#  "'",
#  '▁नाम',
#  '▁जा',
#  '▁राज्य',
#  '▁समय',
#  '▁होती',
#  '▁करते',
#  '▁हुए',
#  '▁तो',
#  '▁कई',
#  "▁'",
#  '▁अन्य',
#  '▁अधिक',
#  '▁क्षेत्र',
#  '▁कारण',
#  'े',
#  '▁सबसे',
#  '▁प्रकार',
#  '▁होने',
#  'क',
#  '▁सकता',
#  '▁स्थित',
#  'र',
#  '▁उनके',
#  '▁भारतीय',
#  '▁उन्होंने',
#  '▁किसी',
#  '▁वर्ष',
#  '▁जाती',
#  '▁वाले',
#  '▁बहुत',
#  '▁होते',
#  '▁करता',
#  'ता',
#  '▁दो',
#  '▁व',
#  'ं',
#  '▁अपनी',
#  '▁कहा',
#  '▁पूर्व',
#  '▁पहले',
#  '▁गए',
#  '▁इन',
#  '▁हुई',
#  '▁जैसे',
#  '▁जब',
#  '▁ये',
#  '▁कम',
#  'ल',
#  'स',
#  '▁/',
#  '▁गई',
#  'ो',
#  '▁न',
#  '▁लेकिन',
#  'म',
#  '▁उन्हें',
#  '▁आदि',
#  '▁अनुसार',
#  '▁भाषा',
#  '▁इसका',
#  '▁प्राप्त',
#  '▁रहे',
#  '▁उत्तर',
#  '▁लिये',
#  '▁-',
#  '▁रहा',
#  '▁शामिल',
#  ';',
#  '▁उसके',
#  '▁सभी',
#  '▁जाने',
#  '▁इसे',
#  '▁बीच',
#  '▁तरह',
#  '▁उस',
#  '▁लिया',
#  '▁गाँव',
#  '▁जाते',
#  '▁उनकी',
#  '▁कोई',
#  '▁प्रमुख',
#  '▁भाग',
#  '▁प्रयोग',
#  '▁जिले',
#  '्स',
#  'ित',
#  '▁देश',
#  '▁कार्य',
#  '▁करना',
#  '▁जिसमें',
#  '▁प्रदेश',
#  '▁मुख्य',
#  '▁यहाँ',
#  '▁निर्माण',
#  '▁ओर',
#  '▁जन्म',
#  '▁दी',
#  '▁लगभग',
#  '▁लोगों',
#  'ने',
#  '▁दोनों',
#  'ना',
#  '▁काम',
#  '▁स्थान',
#  '▁उपयोग',
#  '▁उसे',
#  '▁सकते',
#  '▁विश्व',
#  '▁अ',
#  '▁शहर',
#  '▁सरकार',
#  'ियों',
#  '▁इसकी',
#  's',
#  '▁बार',
#  'पुर',
#  '▁विकास',
#  '▁इसी',
#  '▁वाली',
#  '▁दक्षिण',
#  '▁नगर',
#  '▁तीन',
#  '▁आ',
#  'E',
#  '▁केवल',
#  'N',
#  '▁कहते',
#  '▁धर्म',
#  '▁2',
#  'ई',
#  '▁माना',
#  '▁करती',
#  '▁विशेष',
#  '▁फिर',
#  '▁लोग',
#  'ीय',
#  'त',
#  '▁फिल्म',
#  '▁जीवन',
#  '▁प्राचीन',
#  '्',
#  '▁दौरान',
#  '▁अलग',
#  '▁इसमें',
#  '▁मे',
#  '▁1',
#  '▁जिसे',
#  'कर',
#  '▁आधार',
#  'िक',
#  '▁बना',
#  '▁विभिन्न',
#  '°',
#  '▁ई',
#  '▁अब',
#  '▁द',
#  '▁मंदिर',
#  '▁उनका',
#  '▁प्रसिद्ध',
#  '▁जी',
#  '▁प्रति',
#  '▁शब्द',
#  '▁दिन',
#  '▁क्योंकि',
#  '▁राष्ट्रीय',
#  '▁यहां',
#  '▁शुरू',
#  '▁अनेक',
#  '▁काल',
#  '▁पास',
#  '0',
#  '▁रही',
#  '▁संवत',
#  '▁जाना',
#  '▁युद्ध',
#  'ए',
#  '▁अन्तर्गत',
#  '▁बन',
#  '▁तब',
#  '▁अपना',
#  '▁जिसके',
#  '▁हालांकि',
#  '▁ईसा',
#  'ज',
#  '▁अलावा',
#  '▁नदी',
#  '▁व्यक्ति',
#  '▁मध्य',
#  '▁गयी',
#  '▁सन्',
#  '▁महत्वपूर्ण',
#  '▁राजा',
#  'द',
#  '▁जल',
#  'ि',
#  '▁मूल',
#  '▁बड़े',
#  '▁संख्या',
#  '▁कभी',
#  'ट',
#  '▁विज्ञान',
#  '/',
#  '▁अध्ययन',
#  '▁उन',
#  '▁ले',
#  '▁साल',
#  '▁प्रथम',
#  '▁किए',
#  '▁ए',
#  '▁the',
#  '▁नामक',
#  '▁हिन्दी',
#  'ओं',
#  'प',
#  '▁साहित्य',
#  'व',
#  '▁प्रदान',
#  '▁सकती',
#  '▁जिसका',
#  '▁अमेरिका',
#  '▁दूसरे',
#  'ते',
#  '▁प्रभाव',
#  '▁उसकी',
#  '▁जबकि',
#  '▁चाहिए',
#  '▁शिक्षा',
#  '▁तौर',
#  '▁वाला',
#  '▁गये',
#  '▁आम',
#  '▁कुल',
#  '▁अर्थ',
#  '▁स्थापित',
#  '▁दिल्ली',
#  '▁हर',
#  'ब',
#  '▁:',
#  '▁ऐसे',
#  '▁उच्च',
#  '▁सिंह',
#  '▁बड़ा',
#  '▁बड़ी',
#  '▁संयुक्त',
#  '▁बात',
#  '▁ऐसा',
#  '▁चार',
#  '▁स्थापना',
#  '▁आज',
#  '▁पहली',
#  '▁तहसील',
#  '▁मण्डल',
#  '▁देने',
#  '▁अथवा',
#  '▁देशों',
#  '▁वर्तमान',
#  '▁बनाया',
#  '▁इतिहास',
#  '▁किये',
#  '▁यदि',
#  '▁रखा',
#  '▁काफी',
#  '▁समूह',
#  '▁विश्वविद्यालय',
#  'य',
#  'जी',
#  'सी',
#  '▁जिससे',
#  '▁of',
#  'िया',
#  '▁करके',
#  'नी',
#  'ती',
#  '▁स्थिति',
#  '▁उसने',
#  '▁सी',
#  'रा',
#  '▁बनाने',
#  '▁बारे',
#  '▁प्रत्येक',
#  '▁रंग',
#  '▁वर्षों',
#  '▁लेकर',
#  '▁इनके',
#  '▁स्तर',
#  'वीं',
#  '▁सेना',
#  '▁10',
#  'री',
#  'ें',
#  '▁श्री',
#  '▁क्षेत्रों',
#  '▁उसका',
#  '▁स',
#  'का',
#  '▁उपलब्ध',
#  '▁शरीर',
#  '▁सभा',
#  '▁अधिकांश',
#  '▁सामाजिक',
#  '▁वर्ग',
#  '2',
#  '▁दे',
#  '▁लगा',
#  '▁सेवा',
#  '▁रहता',
#  'श',
#  '▁3',
#  '▁दूर',
#  '▁सदस्य',
#  '▁माध्यम',
#  '▁देता',
#  'ु',
#  'ज़',
#  '▁उत्पन्न',
#  '▁इससे',
#  '▁फ़िल्म',
#  '▁15',
#  '▁दुनिया',
#  '▁इस्तेमाल',
#  'िंग',
#  '▁8',
#  '▁जहां',
#  '▁ब्रिटिश',
#  'ड',
#  '▁जहाँ',
#  '▁इसलिए',
#  '▁पानी',
#  'ली',
#  '▁समाज',
#  '▁मानव',
#  '▁अंत',
#  '▁समान',
#  '▁परिवार',
#  '▁पाकिस्तान',
#  '▁शक्ति',
#  '▁संगीत',
#  '▁प्रणाली',
#  'ग',
#  '▁संघ',
#  '▁5',
#  '▁होगा',
#  '▁पुरस्कार',
#  '▁आधुनिक',
#  '▁सामान्य',
#  'या',
#  '▁थीं',
#  '▁आगे',
#  '▁बने',
#  '▁छोटे',
#  '▁अतिरिक्त',
#  '▁उदाहरण',
#  '▁होकर',
#  '▁रहते',
#  '▁अधिकार',
#  'ला',
#  'ण',
#  '▁स्टेशन',
#  '▁शासन',
#  '▁चीन',
#  '▁जिनमें',
#  '▁क',
#  '▁4',
#  'ह',
#  '▁जिस',
#  'ंग',
#  '▁‘',
#  '▁16',
#  '▁भूमिका',
#  '▁देते',
#  '▁शताब्दी',
#  '▁जारी',
#  '▁विकसित',
#  '▁ज्ञान',
#  '▁पिता',
#  '▁मृत्यु',
#  '▁बाहर',
#  '▁कंपनी',
#  '’',
#  '▁ली',
#  '▁पश्चिम',
#  '▁प्रकाशित',
#  '▁रेलवे',
#  '▁कला',
#  'के',
#  '▁प्रकाश',
#  '▁राजधानी',
#  '▁7',
#  '▁ध्यान',
#  '▁मात्रा',
#  '▁संबंध',
#  '▁विचार',
#  '▁उत्तराखण्ड',
#  '▁आधारित',
#  '▁ऑफ',
#  '▁बनी',
#  '▁ऊपर',
#  '▁आप',
#  '▁20',
#  'की',
#  '▁पद',
#  '▁बिहार',
#  '▁देखा',
#  'ओ',
#  '▁चुनाव',
#  '▁सब',
#  '▁पता',
#  '▁6',
#  '▁पहला',
#  '▁घर',
#  '▁प्रक्रिया',
#  '▁पूरी',
#  '▁नए',
#  '▁मार्ग',
#  '▁उत्तरी',
#  '▁विषय',
#  '़',
#  '▁स्वयं',
#  '▁इनमें',
#  '▁रचना',
#  '▁राज',
#  'च',
#  '▁रोग',
#  '▁तैयार',
#  '▁नीचे',
#  '▁भगवान',
#  'वा',
#  '▁12',
#  '▁ऐसी',
#  '▁यात्रा',
#  '▁जनसंख्या',
#  '▁साम्राज्य',
#  '▁पश्चिमी',
#  '▁17',
#  '▁दृष्टि',
#  '▁होना',
#  '▁भिन्न',
#  '▁दशक',
#  '▁दूसरी',
#  '▁सहायता',
#  '▁सीमा',
#  '▁उत्पादन',
#  '▁अक्सर',
#  '▁पृथ्वी',
#  '▁किलोमीटर',
#  '▁व्यवस्था',
#  'बी',
#  '▁मिला',
#  '▁सिद्धांत',
#  '▁वहाँ',
#  '▁स्',
#  '▁भर',
#  '▁हिस्सा',
#  '▁आने',
#  '1',
#  '▁जगह',
#  '▁आवश्यक',
#  '▁पुत्र',
#  '▁टीम',
#  '▁लिखा',
#  '▁राम',
#  '▁सन',
#  '▁आर्थिक',
#  '▁पार्टी',
#  'मा',
#  '▁हेतु',
#  'टी',
#  '▁उप',
#  '▁लगे',
#  '▁बिना',
#  '▁पूर्वी',
#  '▁वो',
#  'वी',
#  '▁तुलना',
#  'ू',
#  '▁पाया',
#  '▁विभाग',
#  '▁ज्यादा',
#  '▁9',
#  'अ',
#  'ले',
#  '▁सदी',
#  '▁गति',
#  '▁लोक',
#  '▁इनका',
#  '▁संगठन',
#  '▁रहती',
#  '▁नई',
#  '▁पूरा',
#  '▁द्वीप',
#  '▁मिलता',
#  '▁अंग्रेजी',
#  '▁अभी',
#  '▁उसी',
#  '▁पूर्ण',
#  '▁केंद्र',
#  'से',
#  '▁प्रदर्शन',
#  '▁रहने',
#  'डी',
#  '▁वि',
#  '▁सु',
#  '▁वृद्धि',
#  '▁अवधि',
#  '▁संस्कृत',
#  '▁क्रिकेट',
#  '▁स्थानीय',
#  '▁प्र',
#  '▁आते',
#  '▁वर्णन',
#  '▁अंतर्राष्ट्रीय',
#  '▁मिल',
#  '▁ऑफ़',
#  '▁अमेरिकी',
#  '▁प्रभावित',
#  '▁हम',
#  '▁किंतु',
#  '▁युग',
#  '▁पूरे',
#  '▁आकार',
#  '▁राष्ट्र',
#  '▁अंतिम',
#  '▁कोड',
#  '▁पड़ा',
#  'निर्देशांक',
#  '▁आई',
#  '▁विशिष्ट',
#  '▁भूमि',
#  '▁योजना',
#  '▁खेल',
#  'को',
#  '▁परिवर्तन',
#  '▁व्यापार',
#  '▁दर्शन',
#  '▁बल',
#  '▁and',
#  '▁बी',
#  '▁स्पष्ट',
#  '▁14',
#  '▁जाति',
#  '▁प्रयास',
#  '▁दर',
#  '▁राजनीतिक',
#  '▁राष्ट्रपति',
#  'म्',
#  'थ',
#  'ed',
#  '▁क्षमता',
#  '▁हिन्दू',
#  '▁कार्यक्रम',
#  '▁एशिया',
#  '▁लाल',
#  '▁म',
#  '▁डी',
#  '▁शुरुआत',
#  '▁11',
#  '▁धार्मिक',
#  '▁संबंधित',
#  'मी',
#  '▁लोकप्रिय',
#  '▁=',
#  '▁प्रवेश',
#  '्य',
#  '▁सं',
#  '▁आता',
#  '▁रखने',
#  '▁सके',
#  '▁18',
#  '▁यूरोप',
#  '▁शक',
#  '▁शिव',
#  '▁माता',
#  '▁उद्देश्य',
#  '▁आवश्यकता',
#  '▁खोज',
#  '▁श्रेणी',
#  '▁दूरी',
#  '▁बजे',
#  '▁नियंत्रण',
#  '▁दूसरा',
#  '▁लेने',
#  '▁ट्रेन',
#  '▁विस्तार',
#  '▁प्रतिशत',
#  '▁in',
#  '▁विधि',
#  '▁हिंदी',
#  '▁ऐतिहासिक',
#  '▁इन्हें',
#  '▁पदार्थ',
#  '▁रेल',
#  '▁बैंक',
#  'वाद',
#  '▁मीटर',
#  'एँ',
#  '▁आया',
#  '▁इन्होंने',
#  '▁व्यापक',
#  '▁विशाल',
#  'रे',
#  '▁दिखाई',
#  '▁2008',
#  '▁ओ',
#  '▁रह',
#  '▁कांग्रेस',
#  '▁30',
#  '▁प्रस्तुत',
#  '▁13',
#  '▁आबादी',
#  '▁सा',
#  '▁द्वितीय',
#  'सा',
#  '▁प्राकृतिक',
#  '▁शैली',
#  '▁जिन्हें',
#  '▁प्रदर्शित',
#  '▁जनता',
#  '▁सुरक्षा',
#  '▁कृष्ण',
#  '▁संस्थान',
#  '▁लाख',
#  '▁मन',
#  '▁मई',
#  '▁जनवरी',
#  '▁निम्न',
#  '▁वैज्ञानिक',
#  '▁2007',
#  '▁दिए',
#  '▁संस्कृति',
#  '▁इनकी',
#  '▁बौद्ध',
#  '▁य',
#  '▁दल',
#  '▁विवाह',
#  '▁बनाए',
#  'वे',
#  '▁क्रिया',
#  '▁स्थल',
#  '▁खिलाफ',
#  'फ',
#  '▁स्कूल',
#  '▁बताया',
#  '▁ऊर्जा',
#  '▁उल्लेख',
#  'बा',
#  '▁संस्करण',
#  '▁वजह',
#  '▁सामने',
#  '▁गांधी',
#  'एस',
#  '▁मिली',
#  'पर',
#  '▁अल',
#  '▁जाए',
#  '▁सहित',
#  'इ',
#  '▁अंतर्गत',
#  '▁a',
#  'यों',
#  '▁परन्तु',
#  '▁.',
#  '▁पुस्तक',
#  '▁समाप्त',
#  '▁पुराने',
#  '▁पैदा',
#  '▁व्यवहार',
#  '▁हाथ',
#  'स्',
#  '▁स्वतंत्रता',
#  '▁नेतृत्व',
#  '▁निर्मित',
#  '▁सम्मानित',
#  '▁रक्त',
#  '▁देव',
#  '▁मार्च',
#  '▁परंतु',
#  '▁पड़ता',
#  '▁भीतर',
#  'दा',
#  '▁अफ्रीका',
#  '▁घोषणा',
#  '▁चला',
#  'आ',
#  '▁दिशा',
#  '▁उद्योग',
#  '▁2009',
#  '▁च',
#  '▁कुमाऊँ',
#  '▁कवि',
#  '▁समर्थन',
#  '▁परिणाम',
#  '▁ब',
#  '▁स्वीकार',
#  '▁अप्रैल',
#  '▁मैं',
#  '▁देवी',
#  '▁पहचान',
#  '▁अवस्था',
#  '4',
#  '▁सफल',
#  '|',
#  '▁जून',
#  '▁प्रचलित',
#  '▁पर्वत',
#  '▁जानकारी',
#  '▁किन्तु',
#  '▁वंश',
#  '▁देती',
#  'एं',
#  '▁तहत',
#  'वर',
#  'िका',
#  '▁जिसकी',
#  '▁अरब',
#  'ख',
#  '▁दक्षिणी',
#  '*',
#  '▁बाल',
#  '▁लगता',
#  '▁महत्व',
#  '▁स्वतंत्र',
#  '▁प',
#  '▁किमी',
#  'गा',
#  '▁यही',
#  '▁महान',
#  '▁दिनों',
#  '▁पत्र',
#  '3',
#  '▁जुलाई',
#  '▁ना',
#  '▁मदद',
#  '▁छोटी',
#  '▁नि',
#  '▁भाई',
#  '▁चिकित्सा',
#  '▁महिला',
#  '▁पांच',
#  '▁इंग्लैंड',
#  '▁to',
#  '▁2006',
#  '▁जीव',
#  '▁लाभ',
#  '▁श्रृंखला',
#  '▁बंद',
#  '▁उपचार',
#  '▁कमी',
#  '▁मौजूद',
#  '▁19',
#  '▁अगस्त',
#  '▁मिलती',
#  '▁एस',
#  '▁हवाई',
#  '▁अक्टूबर',
#  '▁गुरु',
#  '▁जनगणना',
#  '▁भागों',
#  '▁विधान',
#  '▁शासक',
#  '▁आरम्भ',
#  '▁फ्रांस',
#  'साथ',
#  'जा',
#  '▁चीनी',
#  '▁25',
#  '▁भाषाओं',
#  '5',
#  '▁मुस्लिम',
#  '▁एम',
#  '▁मान',
#  '▁जिसने',
#  '▁अगर',
#  '▁कृषि',
#  '▁निम्नलिखित',
#  '▁मानते',
#  '▁करोड़',
#  '▁सात',
#  'ीकरण',
#  '▁योगदान',
#  '▁समुदाय',
#  '▁कहानी',
#  '▁बंगाल',
#  '▁मनुष्य',
#  '▁मत',
#  '▁परीक्षण',
#  '▁पीछे',
#  '▁अध्यक्ष',
#  '▁अंग',
#  '▁वस्तु',
#  'कार',
#  '▁समुद्र',
#  '▁राज्यों',
#  '▁उनमें',
#  '▁केन्द्र',
#  '▁संविधान',
#  '▁कानून',
#  '▁इ',
#  '▁अंतर',
#  '▁विमानक्षेत्र',
#  '▁सागर',
#  'रो',
#  '▁सरकारी',
#  '▁गांव',
#  '▁क्या',
#  '▁बढ़',
#  '▁बल्कि',
#  '▁वापस',
#  '▁मेल',
#  'दार',
#  '▁सर',
#  '▁सुधार',
#  '▁जैसा',
#  '▁संचालित',
#  '▁मैच',
#  'पी',
#  '▁अनुसंधान',
#  '▁हाल',
#  '▁महा',
#  '▁रक्षा',
#  '▁लेखक',
#  '▁पाए',
#  '▁जन',
#  '▁आरंभ',
#  'ियाँ',
#  '▁शब्दों',
#  '▁गैर',
#  '▁सूची',
#  '▁जैसी',
#  '▁आयोजित',
#  '▁जैन',
#  '▁चुके',
#  '▁इतन',
#  'न्',
#  '▁प्रयुक्त',
#  '▁मन्दिर',
#  '▁विश्वास',
#  '▁सार्वजनिक',
#  '!',
#  '▁ग्रंथ',
#  '▁भोजन',
#  '▁अत',
#  '▁सहायक',
#  '▁घंटे',
#  'उ',
#  '▁देखने',
#  '▁नेपाल',
#  '▁मिनट',
#  '▁उसमें',
#  '▁गीत',
#  '▁मुंबई',
#  '▁एंड',
#  '▁घटना',
#  '▁कॉलेज',
#  'फ़',
#  '▁ब्रिटेन',
#  '▁मुक्त',
#  '▁चुका',
#  'प्र',
#  '▁औसत',
#  '▁बच्चों',
#  '▁2010',
#  'भारत',
#  '▁सूर्य',
#  'पूर्ण',
#  '▁निर्भर',
#  '▁अतः',
#  '▁छोड़',
#  '▁ज्ञात',
#  'ति',
#  '▁धन',
#  '▁ठीक',
#  '▁दस',
#  '▁विरोध',
#  '▁टी',
#  'वें',
#  '▁बदल',
#  '▁नीति',
#  '▁न्यायालय',
#  '▁निर्णय',
#  '▁पंजाब',
#  '▁सर्वाधिक',
#  'al',
#  '▁त',
#  '▁मान्यता',
#  'सर',
#  '▁नियम',
#  '▁आक्रमण',
#  '▁डिग्री',
#  'मान',
#  '▁अली',
#  '▁स्वास्थ्य',
#  '▁बस',
#  '▁वहां',
#  '▁चल',
#  '▁चरण',
#  'िन',
#  '▁पुलिस',
#  '▁यूरोपीय',
#  '▁निर्वाचन',
#  '▁काव्य',
#  '▁उन्होने',
#  '▁संकेत',
#  '▁विस्तृत',
#  'a',
#  ')',
#  '▁पी',
#  '▁एक्स्प्रेस',
#  '▁सदस्यों',
#  '▁लेख',
#  '▁पक्ष',
#  '▁प्रबंधन',
#  '▁इत्यादि',
#  'राज',
#  '▁अंग्रेज़ी',
#  '▁पे',
#  '▁संसद',
#  '▁गंगा',
#  '▁जाएगा',
#  '▁पाँच',
#  '▁कहीं',
#  'ः',
#  '▁चित्र',
#  '▁एन',
#  'र्स',
#  '▁वायु',
#  '▁कविता',
#  '▁निश्चित',
#  '▁पद्धति',
#  '▁डॉ॰',
#  'n',
#  ...]

# %%
# 30,000 is the vocab size that we chose in sentencepiece
hindi_vocab = Vocab(itos)

# %%
tokenizer = Tokenizer(tok_func=HindiTokenizer, lang='hi')

# %%
tokenizer.special_cases
# Out:
# ['xxunk', 'xxpad', 'xxbos', 'xxfld', 'xxmaj', 'xxup', 'xxrep', 'xxwrep']

# %%
data_lm = TextDataBunch.from_df(path=path, train_df=df_train, valid_df=df_test, tokenizer=tokenizer, vocab=hindi_vocab)

# %%
data_lm.save()

# %%
bs=32

# %%
data_lm = TextLMDataBunch.load(path, 'tmp', bs=bs)

# %%
data_lm.show_batch()
# Out:
# <table>  <col width='5%'>  <col width='95%'>  <tr>
#     <th>idx</th>
#     <th>text</th>
#   </tr>
#   <tr>
#     <th>0</th>
#     <th>▁x x bo s ▁अहमद ▁व ली ▁कर ज़ ई ▁को ▁बुधवार ▁को ▁कंद हार ▁स्थित ▁उनके ▁पैतृक ▁गांव ▁में ▁दफ़न ाया ▁गया ▁और ▁उसी ▁दिन ▁वहां ▁दो ▁अलग ▁अलग ▁धमाके ▁भी ▁हुए ▁हैं . माना ▁जा ▁रहा ▁है ▁कि ▁पड़ोस ▁के ▁हेल मंद ▁प्रांत ▁के ▁गवर्नर ▁गुलाब ▁मंगल ▁इस ▁जन ा ज़े ▁में ▁शामिल ▁होने ▁के ▁लिए ▁सड़क ▁के ▁रास्ते ▁आ ▁रहे ▁थे ▁और ▁उन्हें ▁निशाना ▁बनाने ▁के ▁लिए</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>▁है . मु ठ ् ठी ▁बनाने ▁के ▁क्रम ▁में ▁जो ▁हाथों ▁में ▁अ कड़ न ▁होती ▁है , उस से ▁हाथों ▁के ▁जोड़ों ▁को ▁सुरक्षात्मक ▁सहारा ▁मिलता ▁है . उ टा ▁विश्विद्यालय ▁के ▁प्रोफेसर ▁करियर ▁और ▁माइकल ▁एच ▁मुर गन ▁का ▁कहना ▁है ▁कि ▁मानव ▁हथेली ▁का ▁निर्माण ▁कुछ ▁इस ▁तरह ▁से ▁हुआ ▁है ▁कि ▁वो ▁‘ हस्त ▁कौशल ’ ▁का ▁इस्तेमाल ▁कर ▁सके . हालांकि ▁इन ▁वैज्ञानिकों ▁ने</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>▁सा ▁गया ▁है . लेकिन ▁अजय ▁राय ▁केजरीवाल ▁को ▁अपने ▁लिए ▁ख़तरा ▁मानने ▁से ▁साफ़ ▁इनकार ▁करते ▁हैं . उन्होंने ▁कहा , ▁" के जर ी वाल ▁तो ▁दिल्ली ▁से ▁भाग े ▁हुए ▁हैं ▁और ▁जब ▁दिल्ली ▁की ▁जनता ▁का ▁दिल ▁नहीं ▁जीत ▁सके . ▁बनारस ▁की ▁जनता ▁क्या ▁भरोसा ▁करेगी ▁उन ▁पर ". इस ▁त्रिकोणीय ▁मुक़ाबल े ▁मैं ▁ऊँट ▁किस ▁कर वट ▁बैठे गा ▁इस ▁बात ▁का ▁फ़ैसला ▁करने</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>▁उनकी ▁पत्नी ▁प्रतिभा ▁सिंह ▁के ▁खिलाफ ▁एक ▁23 ▁साल ▁पुराने ▁मामले ▁में ▁आपराधिक ▁षड़यंत्र ▁रचने ▁और ▁रिश्वत खोर ी ▁से ▁संबंधित ▁आरोप ▁तय ▁किए ▁गए ▁है . ▁x x bo s ▁इस ▁जीत ▁के ▁साथ ▁चेन्नई ▁सुपर ▁किंग्स ▁पांचवी ▁बार ▁आईपीएल ▁ फ़ाइनल ▁में ▁पहुंचने ▁वाली ▁टीम ▁बनी ▁है . मंगल वार ▁को ▁खेले ▁गए ▁आईपीएल ▁के ▁इस ▁पहले ▁प्ले ऑफ ▁में ▁चेन्नई ▁ने ▁जीत ▁के ▁लिए ▁मुंबई ▁इंडियंस ▁के</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>▁पहुंचे ▁और ▁उन्होंने ▁खुद ▁को ▁ केमिकल ▁इंजीनियर ▁बताया ▁और ▁इसीलिए ▁जर्मन ▁खुफिया ▁सेवा ▁बी एन डी ▁का ▁उनकी ▁तरफ ▁ध्यान ▁गया . उन्होंने ▁कहा ▁कि ▁उन्होंने ▁ट्रक ों ▁पर ▁बनी ▁चलती ▁फिर ती ▁बायोलॉज िकल ▁प्रयोगशाला एं ▁देखी ं . ▁उनके ▁मुताबिक ▁किसी ▁को ▁पता ▁न ▁चले , ▁इसलिए ▁इन्हें ▁एक ▁जगह ▁से ▁दूसरी ▁जगह ▁भेजा ▁जाता ▁था . जर्मन ों ▁को ▁जन ा बी ▁की ▁बातों ▁पर ▁शक</th>
#   </tr>
# </table>

# %%
learn = language_model_learner(data_lm, drop_mult=0.3)

# %%
# Loading the pretrained language model on hindi wikipedia
learn.load('/home/gaurav/Downloads/LanguageModel/HindiDataset/models/third_hi_lm', with_opt=True)
# Out:
# LanguageLearner(data=TextLMDataBunch;
#
# Train: LabelList
# y: LMLabel (3467 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path:
�अपनी ▁आजीविका ▁के ▁लिए ▁इन ▁खेतों ▁पर ▁ही ▁आश्रित ▁हैं . पी ढ़ी ▁दर ▁पीढ़ी ▁वह ▁इन ▁खेतों ▁के ▁सहारे ▁अपना ▁पेट ▁पाल ते ▁आ ▁रहे ▁हैं . ▁पहले ▁निजी ▁कंपनियों ▁ने ▁औ ने ▁पौ ने ▁में ▁ज़मीन ों ▁को ▁खरीदा ▁मगर ▁अब ▁छत्तीसगढ़ ▁की ▁सरकार ▁ने ▁ज़मीन ों ▁का ▁खुद ▁ही ▁अधिग्रहण ▁करना ▁शुरू ▁कर ▁दिया ▁है . ▁अब ▁सरकार ▁ज़मीन ▁अधिग्रहित ▁कर ▁उसे ▁निजी ▁कंपनियों ▁को ▁दे ▁रही ▁है . औद्योगिक ीकरण ▁की ▁आंधी सरकार ▁का ▁तर्क ▁है ▁कि ▁पहले ▁कम्पनियाँ ▁औ ने ▁पौ ने ▁में ▁ज़मीन ▁खरीदा ▁करती ▁थीं . ▁सरकार ▁की ▁नई ▁भूमि ▁अधिग्रहण ▁और ▁पुनर्वास ▁नीति ▁के ▁तहत ▁किसानों ▁को ▁साल ▁में ▁दो ▁फसल ▁देने ▁वाली ▁खेत ि हर ▁ज़मीन ▁के ▁प्रति ▁एकड़ ▁दस ▁लाख ▁रूप ए ▁देने ▁का ▁प्रावधान ▁किया ▁गया ▁है . कहा ▁जा ▁सकता ▁है ▁कि ▁छत्तीसगढ़ ▁में ▁औद्योगिक ीकरण ▁की ▁आंधी ▁चल ▁रही ▁है . ▁राज्य ▁सरकार ▁ने ▁सूबे ▁में ▁इस्पात ▁और ▁विद्युत ▁संयंत्रों ▁के ▁लिए ▁कई ▁सौ ▁कंपनियों ▁के ▁साथ ▁एम ओ यू ▁यानी ▁साझा ▁करार ▁पर ▁हस्ताक्षर ▁किए ▁हैं . इन में ▁ज़्यादा तर ▁इस्पात ▁और ▁विद्युत् ▁संयंत्र ▁राज्य ▁के ▁रायपुर , ▁रायगढ़  ...
# Path: /home/gaurav/Downloads/HindiClassificationModel-2;
#
# Test: None, model=SequentialRNN(
#   (0): RNNCore(
#     (encoder): Embedding(30000, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(30000, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1150, batch_first=True)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1150, 1150, batch_first=True)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1150, 400, batch_first=True)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=30000, bias=True)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<fastai.layers.FlattenedLoss object at 0x7f414bda0d30>, metrics=[<function accuracy at 0x7f415fb89268>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/home/gaurav/Downloads/HindiClassificationModel-2'), model_dir='models', callback_fns=[<class 'fastai.basic_train.Recorder'>], callbacks=[RNNTrainer
# learn: LanguageLearner(data=TextLMDataBunch;
#
# Train: LabelList
# y: LMLabel (3467 items)
# [Category 0, Category 0, Category 0, Category 0, Category 0]...
# Path: /home/gaurav/Downloads/HindiClassificationModel-2
# x: LMTextList (3467 items)
्योगिक ीकरण ▁की ▁आंधी सरकार ▁का ▁तर्क ▁है ▁कि ▁पहले ▁कम्पनियाँ ▁औ ने ▁पौ ने ▁में ▁ज़मीन ▁खरीदा ▁करती ▁थीं . ▁सरकार ▁की ▁नई ▁भूमि ▁अधिग्रहण ▁और ▁पुनर्वास ▁नीति ▁के ▁तहत ▁किसानों ▁को ▁साल ▁में ▁दो ▁फसल ▁देने ▁वाली ▁खेत ि हर ▁ज़मीन ▁के ▁प्रति ▁एकड़ ▁दस ▁लाख ▁रूप ए ▁देने ▁का ▁प्रावधान ▁किया ▁गया ▁है . कहा ▁जा ▁सकता ▁है ▁कि ▁छत्तीसगढ़ ▁में ▁औद्योगिक ीकरण ▁की ▁आंधी ▁चल ▁रही ▁है . ▁राज्य ▁सरकार ▁ने ▁सूबे ▁में ▁इस्पात ▁और ▁विद्युत ▁संयंत्रों ▁के ▁लिए ▁कई ▁सौ ▁कंपनियों ▁के ▁साथ ▁एम ओ यू ▁यानी ▁साझा ▁करार ▁पर ▁हस्ताक्षर ▁किए ▁हैं . इन में ▁ज़्यादा तर ▁इस्पात ▁और ▁विद्युत् ▁संयंत्र ▁राज्य ▁के ▁रायपुर , ▁रायगढ़  ...
# Path: /home/gaurav/Downloads/HindiClassificationModel-2;
#
# Test: None, model=SequentialRNN(
#   (0): RNNCore(
#     (encoder): Embedding(30000, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(30000, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1150, batch_first=True)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1150, 1150, batch_first=True)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1150, 400, batch_first=True)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=30000, bias=True)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=<fastai.layers.FlattenedLoss object at 0x7f414bda0d30>, metrics=[<function accuracy at 0x7f415fb89268>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/home/gaurav/Downloads/HindiClassificationModel-2'), model_dir='models', callback_fns=[<class 'fastai.basic_train.Recorder'>], callbacks=[...], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(30000, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(30000, 400, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=30000, bias=True)
#     (output_dp): RNNDropout()
#   )
# )])
# bptt: 70
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 1150, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1150, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(30000, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(30000, 400, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=30000, bias=True)
#     (output_dp): RNNDropout()
#   )
# )])

# %%
# Fine tuning the prtrained LM on current dataset

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.freeze()

# %%
learn.fit_one_cycle(1, 1e-2, moms=(0.8,0.7))
# Out:
# Total time: 01:16 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>4.247648</th>
#     <th>4.168564</th>
#     <th>0.304325</th>
#   </tr>
# </table>

# %%
learn.save('fit_head', with_opt=True)

# %%
learn.load('fit_head', with_opt=True);

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, 1e-3, moms=(0.8,0.7))
# Out:
# Total time: 07:33 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>3.900113</th>
#     <th>4.077443</th>
#     <th>0.313353</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>3.847647</th>
#     <th>3.996696</th>
#     <th>0.322327</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>3.685540</th>
#     <th>3.957085</th>
#     <th>0.327560</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>3.467052</th>
#     <th>3.949986</th>
#     <th>0.329593</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>3.386163</th>
#     <th>3.955272</th>
#     <th>0.329418</th>
#   </tr>
# </table>

# %%
learn.save('fine_tuned', with_opt=True)

# %%
learn.load('fine_tuned', with_opt=True);

# %%
learn.predict('▁इस ▁लाइन ▁के ▁चलने ▁से ▁दक्षिणी ',n_words=10)
# Out:
# '▁इस ▁लाइन ▁के ▁चलने ▁से ▁दक्षिणी  ▁कोरिया ▁ईस ▁- धे पा ▁ ▁लक्षद्वीप s ▁ g'

# %%
learn.save_encoder('fine_tuned_enc')

# %%
data_clas = TextClasDataBunch.from_df(path=path, train_df=df_train, valid_df=df_test, tokenizer=tokenizer, vocab=hindi_vocab)

# %%
data_clas.show_batch()
# Out:
# <table>  <col width='90%'>  <col width='10%'>  <tr>
#     <th>text</th>
#     <th>target</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁1920 ▁के ▁दशक ▁में ▁फ़ी फ़ा ▁के ▁अध्यक्ष ▁जूल ्स ▁रि मे ▁और ▁फ़्रांस ▁के ▁फ़ुटबॉल ▁प्रशासकों ▁ने ▁दुनिया ▁की ▁बेहतरीन ▁फ़ुटबॉल ▁टीम ▁तय ▁करने ▁के ▁लिए ▁प्रतियोगिता ▁कराने ▁का ▁विचार ▁किया . ▁1929 ▁में ▁फ़ी फ़ा ▁ने ▁एक ▁प्रस्ताव ▁पारित ▁करके ▁विश्व ▁कप ▁फ़ुटबॉल ▁आयोजित ▁कराने ▁का ▁फ़ैसला ▁किया . 19 30 ▁में ▁शुरू ▁हुई ▁ये ▁प्रतियोगिता ▁हर ▁चार ▁साल ▁पर ▁आयोजित ▁होती ▁है .</th>
#     <th>sport</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁खिलाड़ियों ▁ने ▁रंगीन ▁पोशाक ें ▁पहन नी ▁शुरू ▁की , ▁गेंद ▁उ जल ी ▁हो ▁गई ▁और ▁अंपायर ▁तक ▁रंगीन ▁पोशाक ▁में ▁नज़र ▁आने ▁लगे . ▁मैच ▁दिन - रात ▁के ▁होने ▁लगे ▁और ▁50 -50 ▁ओवर ों ▁के ▁मैच ▁होने ▁लगे . पहले ▁तीन ▁विश्व ▁कप ▁इंग्लैंड ▁में ▁आयोजित ▁हुए ▁और ▁तीन ▁में ▁दो ▁विश्व ▁कप ▁का ▁ख़िताब ▁वेस्टइंडीज ़ ▁ने ▁जीता . ▁लेकिन ▁1983</th>
#     <th>sport</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁शुभ ्रा ं शु ▁चौधरी ▁ने ▁सात ▁वर्षों ▁के ▁लंबे ▁शोध ▁के ▁बाद ▁ये ▁किताब ▁लिखी ▁है . अं ग्रे ज़ी ▁और ▁हिंदी ▁दोनों ▁भाषाओं ▁में ▁प्रकाशित ▁इस ▁किताब ▁का ▁एक ▁अंश ▁हम ▁अपने ▁पाठकों ▁के ▁लिए ▁प्रकाशित ▁कर ▁रहे ▁हैं . समय ▁जैसे ▁उड़ ▁गया . ▁फिर ▁विदा ▁लेने ▁का ▁समय ▁हो ▁गया . ▁कैंप ▁में ▁सभी ▁कतार ▁बांध ▁कर ▁हाथ ▁मिलाने ▁और ▁लाल ▁सलाम</th>
#     <th>india</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁30 ▁जनवरी ▁1948 ▁को ▁शाम ▁पाँच ▁बज कर ▁पंद्रह ▁मिनट ▁पर ▁जब ▁गाँधी ▁लगभग ▁भाग ते ▁हुए ▁बिरला ▁हाउस ▁के ▁प्रार्थना ▁स्थल ▁की ▁तरफ़ ▁बढ़ ▁रहे ▁थे , ▁तो ▁उनके ▁स्टाफ ़ ▁के ▁एक ▁सदस्य ▁गुर ब चन ▁सिंह ▁ने ▁अपनी ▁घड़ी ▁की ▁तरफ़ ▁देखते ▁हुए ▁कहा ▁था , ▁" बा पू ▁आज ▁आपको ▁थोड़ी ▁देर ▁हो ▁गई ." गाँधी ▁ने ▁चलते - चल ते ▁ही</th>
#     <th>india</th>
#   </tr>
#   <tr>
#     <th>▁x x bo s ▁गोरखा ▁जन मुक्ति ▁मोर्चा ▁की ▁अपील ▁पर ▁जारी ▁बे मिया दी ▁बंद ▁के ▁विरोध ▁में ▁आवाज़ ें ▁तो ▁पहले ▁से ▁ही ▁उठ ▁रही ▁थीं . ▁लेकिन ▁अब ▁विरोध ▁के ▁स्वर ▁तेज़ ▁होने ▁लगे ▁हैं . दिल्ली ▁में ▁केंद्रीय ▁गृह ▁मंत्री ▁राज नाथ ▁सिंह ▁से ▁गोरखा लैंड ▁मांग ▁समन्वय ▁समिति ▁के ▁प्रतिनिधिमंडल ▁की ▁मुलाक़ात ▁और ▁उसके ▁बाद ▁25 ▁दिनों ▁से ▁जारी ▁आमरण ▁अनशन ▁वापस ▁लेने ▁से ▁इलाके</th>
#     <th>india</th>
#   </tr>
# </table>

# %%
data_clas.sanity_check()

# %%
learn = text_classifier_learner(data_clas, drop_mult=0.5)

# %%
learn.load_encoder('fine_tuned_enc')

# %%
learn.freeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.loss_func.func
# Out:
# CrossEntropyLoss()

# %%
kappa = KappaScore()

# %%
learn.metrics = [kappa, accuracy]

# %%
learn.fit_one_cycle(1, 1e-1, moms=(0.8,0.7))
# Out:
# Total time: 00:38 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>kappa_score</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.941050</th>
#     <th>0.726321</th>
#     <th>0.680364</th>
#     <th>0.762125</th>
#   </tr>
# </table>

# %%
learn.save('first-full')

# %%
learn.load('first-full');

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(5, slice(1e-2/(2.6**4),1e-2), moms=(0.8,0.7))
# Out:
# Total time: 03:36 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>kappa_score</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.789799</th>
#     <th>0.710388</th>
#     <th>0.676020</th>
#     <th>0.759815</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.732932</th>
#     <th>0.669218</th>
#     <th>0.693219</th>
#     <th>0.771363</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.634361</th>
#     <th>0.732959</th>
#     <th>0.688695</th>
#     <th>0.767898</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.539749</th>
#     <th>0.724365</th>
#     <th>0.723996</th>
#     <th>0.794457</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.468473</th>
#     <th>0.688864</th>
#     <th>0.723996</th>
#     <th>0.793303</th>
#   </tr>
# </table>

# %%
learn.save('second-full')

# %%
learn.unfreeze()
learn.fit_one_cycle(5, slice(1e-3/(2.6**4),1e-3), moms=(0.8,0.7))
# Out:
# Total time: 06:11 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>kappa_score</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.442207</th>
#     <th>0.697293</th>
#     <th>0.721172</th>
#     <th>0.790993</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.450484</th>
#     <th>0.700575</th>
#     <th>0.730180</th>
#     <th>0.797921</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.435430</th>
#     <th>0.720634</th>
#     <th>0.725239</th>
#     <th>0.794457</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.416370</th>
#     <th>0.720026</th>
#     <th>0.716100</th>
#     <th>0.786374</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.417079</th>
#     <th>0.729395</th>
#     <th>0.724238</th>
#     <th>0.793303</th>
#   </tr>
# </table>

# %%
learn.save('final')
